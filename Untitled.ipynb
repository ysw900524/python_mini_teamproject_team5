# %%
aa = []
bb = []
value =0

for i in range(0, 100):
    aa.append(value)
    value += 2
#     print(aa)
    
for i in range(0, 100):
    bb.append(aa[99-i])
    print(bb)
    
print("bb[0]은 %d, bb[99]는 %d 입력됨" %(bb[0], bb[99]))
# Out:
# [198]
# [198, 196]
# [198, 196, 194]
# [198, 196, 194, 192]
# [198, 196, 194, 192, 190]
# [198, 196, 194, 192, 190, 188]
# [198, 196, 194, 192, 190, 188, 186]
# [198, 196, 194, 192, 190, 188, 186, 184]
# [198, 196, 194, 192, 190, 188, 186, 184, 182]
# [198, 196, 194, 192, 190, 188, 186, 184, 182, 180]
# [198, 196, 194, 192, 190, 188, 186, 184, 182, 180, 178]
# [198, 196, 194, 192, 190, 188, 186, 184, 182, 180, 178, 176]
# [198, 196, 194, 192, 190, 188, 186, 184, 182, 180, 178, 176, 174]
# [198, 196, 194, 192, 190, 188, 186, 184, 182, 180, 178, 176, 174, 172]
# [198, 196, 194, 192, 190, 188, 186, 184, 182, 180, 178, 176, 174, 172, 170]
# [198, 196, 194, 192, 190, 188, 186, 184, 182, 180, 178, 176, 174, 172, 170, 168]
# [198, 196, 194, 192, 190, 188, 186, 184, 182, 180, 178, 176, 174, 172, 170, 168, 166]
# [198, 196, 194, 192, 190, 188, 186, 184, 182, 180, 178, 176, 174, 172, 170, 168, 166, 164]
# ...
