# %% [markdown]
# # 주요 라이브러리 활용
#
#
# > - 라이브러리 설치
# - 웹 페이지 간단하게 추출
# - HTML 스크레이핑
# - RSS 스크레이핑하기
# - 데이터베이스에 저장
# - 크롤러와 URL
# - 파이썬으로 크롤러 만들기

# %% [markdown]
# ## 라이브러리 설치
# > - pip 설치
# - (venv) C:\> pip install <module_name>
# - (venv) C:\> pip install <module_name>=1.0
# - (venv) C:\> pip freeze

# %% [markdown]
# ## 웹 페이지 간단하게 추출
# > urllib.Request : GET, POST 요청 처리
#
# > - get(), post(), put(), delete(), head(), option()
# - 위 함수는 HTTP 메소드 GET, POST, PUT, DELETE, HEAD, OPTIONS 에 대응

# %% [markdown]
# > cf> http와 https의 차이점은 https는 security 처리가 내부적으로 된 사이트라는 것.
# https가 더 안전하다고 볼 수 있다.

# %% [markdown]
# ## HTML 스크레이핑
# > - HTML 요소를 지정하는 방식 : XPath / CSS 선택자
# - lxml 스크래이핑 : C언어로 작성된 XML 처리와 관련된 libxml2와 libxslt의 파이썬 바인딩
# - BeautifuSoup 스크래이핑 : 아주 쉽고 간단한 공개 API (cf. Current Version : BeautifulSoup4 since 2012)
# - pyquery 스크래이핑 : jQuery와 같은 사용법으로 HTML에서 스크래이핑 할 수 있게 해주는 라이브러리

# %% [markdown]
# > cf> lxml은 c언어로 구성되어 있어 처리속도가 가장 빠르고 거의 다 활용되므로,
# 웬만하면 lxml로 지정하면 된다.

# %%
! wget http://www.hanbit.co.kr/store/books/full_book_list.html -O ./data/full_book_list.html
# Out:
# --2018-11-14 09:25:29--  http://www.hanbit.co.kr/store/books/full_book_list.html
# Resolving www.hanbit.co.kr (www.hanbit.co.kr)... 218.38.58.195
# Connecting to www.hanbit.co.kr (www.hanbit.co.kr)|218.38.58.195|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: './data/full_book_list.html'
#
#      0K .......... .......... .......... .......... .....       936K=0.05s
#
# 2018-11-14 09:25:29 (936 KB/s) - './data/full_book_list.html' saved [46428]

# %% [markdown]
# **c3-01_scrape_by_lxml**
# > lxml 로 스크레이핑

# %%
# ! pip install cssselect
# Out:
# Collecting cssselect
#   Downloading https://files.pythonhosted.org/packages/7b/44/25b7283e50585f0b4156960691d951b05d061abf4a714078393e51929b30/cssselect-1.0.3-py2.py3-none-any.whl
# Installing collected packages: cssselect
# Successfully installed cssselect-1.0.3

# %%
import lxml.html
import pandas as pd

# HTML 파일을 읽어 들이고, getroot() 메서드로 HtmlElement 객체를 생성합니다.
tree = lxml.html.parse('./data/full_book_list.html')
html = tree.getroot()

A_Tag_Text = []
A_Tag_Link = []

# cssselect() 메서드로 a 요소의 리스트를 추출하고 반복을 돌립니다.
for a in html.cssselect('a'):
    # href 속성과 글자를 추출합니다.
    # print(a.get('href'), a.text)
    
    if a.text is not None:
        A_Tag_Text.append(a.text)
        A_Tag_Link.append(a.get('href'))

book_df = pd.DataFrame({'Text' : A_Tag_Text, 
                        'Link' : A_Tag_Link},
                      columns = ['Text', 'Link'])
book_df.head(10)
# Out:
#       Text                                              Link
# 0    한빛미디어                    http://www.hanbit.co.kr/media/
# 1   한빛아카데미                  http://www.hanbit.co.kr/academy/
# 2     한빛비즈                      http://www.hanbit.co.kr/biz/
# 3    한빛라이프                     http://www.hanbit.co.kr/life/
# 4     한빛에듀                      http://www.hanbit.co.kr/edu/
# 5     리얼타임                 http://www.hanbit.co.kr/realtime/
# 6  한빛정보교과서                 http://www.hanbit.co.kr/textbook/
# 7  한빛대관서비스                     http://www.hanbit.co.kr/rent/
# 8      로그인         http://www.hanbit.co.kr/member/login.html
# 9     회원가입  http://www.hanbit.co.kr/member/member_agree.html

# %% [markdown]
# **c3-02_scrape_by_bs4**
# > BeautifulSopu 로 스크래이핑

# %%
# encoding type 확인 : <meta charset=''> 정보
# ! type data\full_book_list.html

# %%
from bs4 import BeautifulSoup
import pandas as pd

# HTML 파일을 읽어 들이고 BeautifulSoup 객체를 생성합니다.
with open('data/full_book_list.html', encoding='utf-8') as f:
    soup = BeautifulSoup(f, 'html.parser')

category_tag = soup.find('ul', 'lnb_depth1_category')

# find_all() 메서드로 a 요소를 추출하고 반복을 돌립니다.
for a_tag in category_tag.find_all('a'):
    if len(a_tag['href']) > 1:
        print("href 속성 : {} \t, 글자 : {}, ".format(a_tag['href'], a_tag.text))
# Out:
# href 속성 : /store/books/category_list.html?cate_cd=001 	, 글자 : IT/모바일,
# href 속성 : /store/books/category_list.html?cate_cd=001001 	, 글자 : 프로그래밍,
# href 속성 : /store/books/category_list.html?cate_cd=001002 	, 글자 : 웹,
# href 속성 : /store/books/category_list.html?cate_cd=001003 	, 글자 : 모바일/스마트기기,
# href 속성 : /store/books/category_list.html?cate_cd=001013 	, 글자 : 데이터베이스,
# href 속성 : /store/books/category_list.html?cate_cd=001005 	, 글자 : 운영체제,
# href 속성 : /store/books/category_list.html?cate_cd=001014 	, 글자 : 하드웨어,
# href 속성 : /store/books/category_list.html?cate_cd=001015 	, 글자 : 시스템/네트워크,
# href 속성 : /store/books/category_list.html?cate_cd=001016 	, 글자 : 보안,
# href 속성 : /store/books/category_list.html?cate_cd=001009 	, 글자 : 비즈니스/문화,
# href 속성 : /store/books/category_list.html?cate_cd=001010 	, 글자 : 게임,
# href 속성 : /store/books/category_list.html?cate_cd=001017 	, 글자 : IT에세이,
# href 속성 : /store/books/category_list.html?cate_cd=001012 	, 글자 : 자격증,
# href 속성 : /store/books/category_list.html?cate_cd=002 	, 글자 : MAKE,
# href 속성 : /store/books/category_list.html?cate_cd=002001 	, 글자 : Make 매거진,
# href 속성 : /store/books/category_list.html?cate_cd=002002 	, 글자 : Make 프로젝트 북,
# href 속성 : /store/books/category_list.html?cate_cd=003 	, 글자 : IT활용,
# href 속성 : /store/books/category_list.html?cate_cd=003001 	, 글자 : 오피스/OA,
# href 속성 : /store/books/category_list.html?cate_cd=003002 	, 글자 : 그래픽/멀티미디어,
# href 속성 : /store/books/category_list.html?cate_cd=003003 	, 글자 : 사진/예술,
# href 속성 : /store/books/category_list.html?cate_cd=003004 	, 글자 : 컴퓨터입문/IT교양,
# href 속성 : /store/books/category_list.html?cate_cd=004 	, 글자 : 대학교재,
# href 속성 : /store/books/category_list.html?cate_cd=004007 	, 글자 : 컴퓨터공학,
# href 속성 : /store/books/category_list.html?cate_cd=004008 	, 글자 : 정보통신/전기/전자,
# href 속성 : /store/books/category_list.html?cate_cd=004003 	, 글자 : 수학/과학/공학,
# href 속성 : /store/books/category_list.html?cate_cd=004004 	, 글자 : 프로그래밍/웹,
# href 속성 : /store/books/category_list.html?cate_cd=004005 	, 글자 : 그래픽/디자인,
# href 속성 : /store/books/category_list.html?cate_cd=004006 	, 글자 : OA/활용,
# href 속성 : /store/books/category_list.html?cate_cd=005 	, 글자 : 수험서,
# href 속성 : /store/books/category_list.html?cate_cd=005005 	, 글자 : 전기기본서,
# href 속성 : /store/books/category_list.html?cate_cd=005001 	, 글자 : 전기기사,
# href 속성 : /store/books/category_list.html?cate_cd=005002 	, 글자 : 전기산업기사,
# href 속성 : /store/books/category_list.html?cate_cd=005003 	, 글자 : 전기공사기사,
# href 속성 : /store/books/category_list.html?cate_cd=005004 	, 글자 : 전기공사산업기사,
# href 속성 : /store/books/category_list.html?cate_cd=006 	, 글자 : 실용서,
# href 속성 : /store/books/category_list.html?cate_cd=006001 	, 글자 : 취미/실용,
# href 속성 : /store/books/category_list.html?cate_cd=006002 	, 글자 : 여행,
# href 속성 : /store/books/category_list.html?cate_cd=006003 	, 글자 : 건강,
# href 속성 : /store/books/category_list.html?cate_cd=006004 	, 글자 : 유아/육아,
# href 속성 : /store/books/category_list.html?cate_cd=007 	, 글자 : 경제/경영/인문,
# href 속성 : /store/books/category_list.html?cate_cd=007001 	, 글자 : 경제/경영,
# href 속성 : /store/books/category_list.html?cate_cd=007002 	, 글자 : 자기계발,
# href 속성 : /store/books/category_list.html?cate_cd=007003 	, 글자 : 인문/교양,
# href 속성 : /store/books/category_list.html?cate_cd=007004 	, 글자 : 마케팅,
# href 속성 : /store/books/category_list.html?cate_cd=007005 	, 글자 : 에세이,
# href 속성 : /store/books/category_list.html?cate_cd=008 	, 글자 : 유아/어린이/초등,
# href 속성 : /store/books/category_list.html?cate_cd=008001 	, 글자 : 4~6세,
# href 속성 : /store/books/category_list.html?cate_cd=008002 	, 글자 : 5~7세,
# href 속성 : /store/books/category_list.html?cate_cd=008003 	, 글자 : 예비초등,
# href 속성 : /store/books/category_list.html?cate_cd=008004 	, 글자 : 초등교과연계 1~12영역,
# href 속성 : /store/books/category_list.html?cate_cd=008005 	, 글자 : 초등 전학년,
# href 속성 : http://www.hanbit.co.kr/store/books/series_list.html 	, 글자 : 시리즈,
# href 속성 : http://www.hanbit.co.kr/store/books/reservations_list.html 	, 글자 : 예약도서,

# %% [markdown]
# ## RSS 스크레이핑
# > - feedparser 모듈 사용
# - 표준 라이브러리인 ElementTree보다 간단한 방법으로 RSS 피드에서 데이터 추출 가능

# %% [markdown]
# **c3-03_scrape_by_feedparser **
# > feedparser 로 RSS 스크래이핑
#
# > - 모듈설치 : pip install feedparser

# %%
! pip install feedparser
# Out:
# Collecting feedparser
#   Downloading https://files.pythonhosted.org/packages/91/d8/7d37fec71ff7c9dbcdd80d2b48bcdd86d6af502156fc93846fb0102cb2c4/feedparser-5.2.1.tar.bz2 (192kB)
# Building wheels for collected packages: feedparser
#   Running setup.py bdist_wheel for feedparser: started
#   Running setup.py bdist_wheel for feedparser: finished with status 'done'
#   Stored in directory: C:\Users\student\AppData\Local\pip\Cache\wheels\8c\69\b7\f52763c41c5471df57703a0ef718a32a5e81ee35dcf6d4f97f
# Successfully built feedparser
# Installing collected packages: feedparser
# Successfully installed feedparser-5.2.1

# %%
import feedparser
import pandas as pd

Title = []
Link  = [] 

# 알라딘 도서 RSS를 읽어 들입니다.
d = feedparser.parse('http://www.aladin.co.kr/rss/special_new/351')

# 항목을 순회합니다.
for entry in d.entries:
    Title.append(entry.title)
    Link.append(entry.link)
    
    # print('제목:', entry.title)
    # print('링크:', entry.link)
    # print()
    
rss_df = pd.DataFrame({'제목': Title, '링크':Link}, columns=['제목', '링크'])

# %%
rss_df.head(10)
# Out:
#                                                   제목  \
# 0                   마인크래프트와 함께 즐겁게 파이썬/최일선 지음/비제이퍼블릭
# 1  2019 이기적 미니족보 컴퓨터활용능력 2급 필기/영진정보연구소 지음/영진.com(...
# 2                         빅데이터 활용사전 419/윤종식 지음/데이터에듀
# 3                    보안관제와 윈도우 포렌식 실무/오재헌 지음/홍릉과학출판사
# 4        정보 보안 개론과 실습 - 시스템 해킹과 보안/양대일 지음/한빛아카데미(교재)
# 5  2019 이기적 정보처리산업기사 필기 기본서 & 무료 동영상 (전강 제공)/최희준....
# 6  2019 이기적 사무자동화산업기사 필기 기본서 - 전2권/신면철.영진정보연구소 지음...
# 7                          네이버 포스트가 답이다/바이컴퍼니 지음/앤써북
# 8  오늘부터 나도 미니컴퓨터 메이커 + 워크북 세트 - 전2권/장성균 외 지음/바이플러...
# 9                               리눅스의 정석/배동규 지음/다올미디어
#
#                                                   링크
# 0  http://www.aladin.co.kr/rsscenter/go.aspx?rssT...
# 1  http://www.aladin.co.kr/rsscenter/go.aspx?rssT...
# 2  http://www.aladin.co.kr/rsscenter/go.aspx?rssT...
# 3  http://www.aladin.co.kr/rsscenter/go.aspx?rssT...
# 4  http://www.aladin.co.kr/rsscenter/go.aspx?rssT...
# 5  http://www.aladin.co.kr/rsscenter/go.aspx?rssT...
# 6  http://www.aladin.co.kr/rsscenter/go.aspx?rssT...
# 7  http://www.aladin.co.kr/rsscenter/go.aspx?rssT...
# 8  http://www.aladin.co.kr/rsscenter/go.aspx?rssT...
# 9  http://www.aladin.co.kr/rsscenter/go.aspx?rssT...

# %%
d = feedparser.parse('http://www.aladin.co.kr/rss/special_new/351')
# type(d), len(d.entries)
d
# Out:
# {'feed': {'title': '분야별 신간 특선 - 컴퓨터/모바일',
#   'title_detail': {'type': 'text/plain',
#    'language': None,
#    'base': 'http://www.aladin.co.kr/rss/special_new/351',
#    'value': '분야별 신간 특선 - 컴퓨터/모바일'},
#   'links': [{'rel': 'alternate',
#     'type': 'text/html',
#     'href': 'http://www.aladin.co.kr/rsscenter/go.aspx/www.aladin.co.kr/shop/book/wspecialnew.aspx?cid=351&rssType=1&type=title'}],
#   'link': 'http://www.aladin.co.kr/rsscenter/go.aspx/www.aladin.co.kr/shop/book/wspecialnew.aspx?cid=351&rssType=1&type=title',
#   'language': 'ko-kr',
#   'subtitle': '분야별 신간 특선',
#   'subtitle_detail': {'type': 'text/html',
#    'language': None,
#    'base': 'http://www.aladin.co.kr/rss/special_new/351',
#    'value': '분야별 신간 특선'},
#   'rights': 'Copyright 1999 - 2018 Aladdin communications Inc. Corporation All Rights Reserved.',
#   'rights_detail': {'type': 'text/plain',
#    'language': None,
#    'base': 'http://www.aladin.co.kr/rss/special_new/351',
#    'value': 'Copyright 1999 - 2018 Aladdin communications Inc. Corporation All Rights Reserved.'},
#   'generator_detail': {'name': 'Aladdin RSS(Alss) v0.9'},
#   'generator': 'Aladdin RSS(Alss) v0.9',
#   'updated': 'Wed, 14 Nov 2018 07:01:38 +0900',
#   'updated_parsed': time.struct_time(tm_year=2018, tm_mon=11, tm_mday=13, tm_hour=22, tm_min=1, tm_sec=38, tm_wday=1, tm_yday=317, tm_isdst=0),
#   'image': {'title': 'aladin',
#    'title_detail': {'type': 'text/plain',
#     'language': None,
#     'base': 'http://www.aladin.co.kr/rss/special_new/351',
#     'value': 'aladin'},
#    'href': 'http://image.aladin.co.kr/img/footer/2011/aladin_logo.gif',
#    'links': [{'rel': 'alternate',
#      'type': 'text/html',
#      'href': 'http://www.aladin.co.kr/rsscenter/go.aspx/www.aladin.co.kr/shop/book/wspecialnew.aspx?cid=351&rssType=1&type=title'}],
#    'link': 'http://www.aladin.co.kr/rsscenter/go.aspx/www.aladin.co.kr/shop/book/wspecialnew.aspx?cid=351&rssType=1&type=title',
#    'width': 138,
#    'height': 124,
#    'subtitle': 'aladin',
#    'subtitle_detail': {'type': 'text/html',
#     'language': None,
#     'base': 'http://www.aladin.co.kr/rss/special_new/351',
#     'value': 'aladin'}}},
#  'entries': [{'authors': [{'name': '알라딘',
#      'email': 'noSpam.rss@aladdin.co.kr'}],
#    'author': '알라딘 <noSpam.rss@aladdin.co.kr>',
#    'author_detail': {'name': '알라딘', 'email': 'noSpam.rss@aladdin.co.kr'},
#    'tags': [{'term': '국내도서>컴퓨터/모바일>프로그래밍 언어>파이썬',
#      'scheme': None,
#      'label': None}],
#    'title': '마인크래프트와 함께 즐겁게 파이썬/최일선 지음/비제이퍼블릭',
#    'title_detail': {'type': 'text/plain',
#     'language': None,
#     'base': 'http://www.aladin.co.kr/rss/special_new/351',
#     'value': '마인크래프트와 함께 즐겁게 파이썬/최일선 지음/비제이퍼블릭'},
#    'links': [{'rel': 'alternate',
#      'type': 'text/html',
#      'href': 'http://www.aladin.co.kr/rsscenter/go.aspx?rssType=1&type=item&itemId=173766231'}],
#    'link': 'http://www.aladin.co.kr/rsscenter/go.aspx?rssType=1&type=item&itemId=173766231',
#    'published': 'Mon, 12 Nov 2018 17:35:00 +0900',
#    'published_parsed': time.struct_time(tm_year=2018, tm_mon=11, tm_mday=12, tm_hour=8, tm_min=35, tm_sec=0, tm_wday=0, tm_yday=316, tm_isdst=0),
#    'id': 'http://www.aladin.co.kr/shop/wproduct.aspx?itemID=173766231',
#    'guidislink': False,
#    'summary': '<br/><table border=\'0\' cellpadding=\'0\' cellspacing=\'0\'><tr><td align=\'left\' valign=\'top\'><table cellspacing=\'1\' cellpadding=\'5\' border=\'0\' bgcolor=\'#dddddd\' style=\'margin-right:10px;\'><tbody><tr><td bgcolor=\'#ffffff\'><a href=\'http://www.aladin.co.kr/rsscenter/go.aspx?rssType=1&type=item&itemId=173766231\'><img src=\'https://image.aladin.co.kr/product/17376/62/cover/k492534698_1.jpg\' border=\'0\' /></a></td></tr></tbody></table><h2><a href=\'http://www.aladin.co.kr/rsscenter/go.aspx?rssType=1&type=item&itemId=173766231\'>마인크래프트와 함께 즐겁게 파이썬</a></h2>최일선 지음 / 비제이퍼블릭 / 2018년 11월 / ISBN:<span class=\'isbn13\'>9791186697733</span><br/>정가: <span style=\'color:#FF0202\'>26,000</span>원 / 판매가: <span style=\'color:#FF0202\'>23,400</span>원 / 마일리지: <span style=\'color:#FF0202\'>94</span>원<br/><span style=\'color:#FF0202\'>이벤트</span>: 수험서.외국어.컴퓨터.전문서적 - 슬림 텀블러/핀버튼 에코백(택1)<br/><table border=\'0\' cellpadding=\'3\' cellspacing=\'0\' height=\'20\'><tr><td width=\'113\' align=\'left\'><a href=\'http://www.aladin.co.kr/rsscenter/go.aspx?type=basket&itemId=173766231&rssType=1\' target=\'_blank\'><img src=\'http://www.aladin.co.kr/img/rss/bu_basket.gif\' border=\'0\' alt=\'장바구니담기\'/></a></td><td width=\'101\' align=\'left\'><a href=\'http://www.aladin.co.kr/rsscenter/go.aspx?type=safebasket&itemId=173766231&rssType=1\' target=\'_blank\'><img src=\'http://www.aladin.co.kr/img/rss/bu_safebasket.gif\' border=\'0\' alt=\'보관함담기\'/></a></td><td width=\'83\' align=\'left\'></td><td width=\'113\' align=\'left\'></td></tr></table></td></tr><tr><td valign=\'top\' align=\'left\'><img src="http://www.aladin.co.kr/img/book/intro_t.gif" border="0" /><br/>게임을 하면서 코딩도 배우는 일석이조의 경험을 제공한다. 실제 업무에서 사용하는 파이썬을 초등학생 때부터 공부할 수 있다. 파이썬은 전 세계적으로 가장 많이 쓰이는 프로그래밍 언어 중 하나이면서 초등학생도 익힐 수 있는 쉬운 문법을 지니고 있다.<br/><br/><img src="http://www.aladin.co.kr/img/book/content_t.gif" border="0" /><br/><p>1장 마인크래프트 만나기<BR>\n<BR>\n1-1 마인크래프트와 파이썬의 만남<BR>\n<BR>\n1-2 마인크래프트 설치하기<BR>\n<BR>\n1-3 마인크래프트 1.12.1 서버 설치하기<BR>\n<BR>\n1-4 서버설정<BR>\n<BR>\n1-5 파이썬과 MCPI 설치하기<BR>\n<BR>\n1-6 헬로, 마인크래프트!<BR>\n<BR>\n1-7 멀티플레이로 MCPI 즐기기<BR>\n<BR>\n1-8 게임 접속하기<BR>\n<BR>\n1-9 게임 인터페이스<BR>\n<BR>\n1-10 게임 단축키<BR>\n<BR>\n1-11 아이템 조합 튜토리얼<BR>\n<BR>\n1-12 첫날밤 생존 계획<BR>\n<BR>\n1-13 꼭 알아야 하는 마인크래프트 명령어<BR>\n<BR>\n <BR>\n<BR>\n2장 파이썬 시작하기<BR>\n<BR>\n           2-1 헬로, 파이썬!<BR>\n<BR>\n           2-2 파이썬, 덧셈과 뺄셈을 부탁해!<BR>\n<BR>\n           2-3 간단한 계산기 프로그램 만들기<BR>\n<BR>\n <BR>\n<BR>\n3장 마인크래프트 파이썬 입문<BR>\n<BR>\n           3-1 postToChat:파이썬으로 마인크래프트에 외치다!<BR>\n<BR>\n           3-2 getPos:플레이어 위치 조회 서비스<BR>\n<BR>\n           3-3 setPos:플레이어 위치 변경 서비스<BR>\n<BR>\n           3-4 setBlock:블록 생성하기<BR>\n<BR>\n           3-5 setBlocks:블록 여러 개 생성하기<BR>\n<BR>\n           3-6 getBlock:블록 데이터 얻기<BR>\n<BR>\n3-7 getBlockWithData:블록 데이터 얻기<BR>\n<BR>\n3-8 정리<BR>\n<BR>\n <BR>\n<BR>\n4장 초급 텔레포트<BR>\n<BR>\n           4-1 더하기 함수 만들기<BR>\n<BR>\n           4-2 위치 보정 함수 만들기<BR>\n<BR>\n           4-3 집으로 텔레포트 함수 만들기<BR>\n<BR>\n           4-4 단거리 이동 텔레포트<BR>\n<BR>\n           4-5 타이밍 텔레포트<BR>\n<BR>\n           4-6 마인크래프트 건축물 일일투어!<BR>\n<BR>\n <BR>\n<BR>\n5장 고급 텔레포트<BR>\n<BR>\n           5-1 반복 작업 자동화를 위한 list<BR>\n<BR>\n           5-2 반복 작업 자동화를 위한 for문<BR>\n<BR>\n           5-3 자동 텔레포트<BR>\n<BR>\n           5-4 If를 활용한 제어:만약에<BR>\n<BR>\n           5-5 while문을 사용한 반복 작업 수행하기<BR>\n<BR>\n           5-6 집으로 가는 워프 만들기<BR>\n<BR>\n           5-7 감옥 만들기<BR>\n<BR>\n5-8 지하 탈출 텔레포트<BR>\n<BR>\n5-9 자석 텔레포트:다른 모든 플레이어 소환하기<BR>\n<BR>\n <...<br/><br/><img src="http://www.aladin.co.kr/img/book/subject_t.gif" border="0" /><br/><a href=\'http://www.aladin.co.kr/home/wbookmain.aspx\' class=\'ml\'>국내도서</a>&nbsp;>&nbsp;<a href=\'http://www.aladin.co.kr/shop/wbrowse.aspx?CID=351\' class=\'ml\'>컴퓨터/모바일</a>&nbsp;>&nbsp;<a href=\'http://www.aladin.co.kr/shop/wbrowse.aspx?CID=2613\' class=\'ml\'>PC/게임/디지털 카메라</a>&nbsp;>&nbsp;<a href=\'http://www.aladin.co.kr/shop/wbrowse.aspx?CID=6346&BrowseTarget=List\' class=\'ml\'><b>게임</b></a><br ...
#    'summary_detail': {'type': 'text/html',
#     'language': None,
#     'base': 'http://www.aladin.co.kr/rss/special_new/351',
#     'value': '<br/><table border=\'0\' cellpadding=\'0\' cellspacing=\'0\'><tr><td align=\'left\' valign=\'top\'><table cellspacing=\'1\' cellpadding=\'5\' border=\'0\' bgcolor=\'#dddddd\' style=\'margin-right:10px;\'><tbody><tr><td bgcolor=\'#ffffff\'><a href=\'http://www.aladin.co.kr/rsscenter/go.aspx?rssType=1&type=item&itemId=173766231\'><img src=\'https://image.aladin.co.kr/product/17376/62/cover/k492534698_1.jpg\' border=\'0\' /></a></td></tr></tbody></table><h2><a href=\'http://www.aladin.co.kr/rsscenter/go.aspx?rssType=1&type=item&itemId=173766231\'>마인크래프트와 함께 즐겁게 파이썬</a></h2>최일선 지음 / 비제이퍼블릭 / 2018년 11월 / ISBN:<span class=\'isbn13\'>9791186697733</span><br/>정가: <span style=\'color:#FF0202\'>26,000</span>원 / 판매가: <span style=\'color:#FF0202\'>23,400</span>원 / 마일리지: <span style=\'color:#FF0202\'>94</span>원<br/><span style=\'color:#FF0202\'>이벤트</span>: 수험서.외국어.컴퓨터.전문서적 - 슬림 텀블러/핀버튼 에코백(택1)<br/><table border=\'0\' cellpadding=\'3\' cellspacing=\'0\' height=\'20\'><tr><td width=\'113\' align=\'left\'><a href=\'http://www.aladin.co.kr/rsscenter/go.aspx?type=basket&itemId=173766231&rssType=1\' target=\'_blank\'><img src=\'http://www.aladin.co.kr/img/rss/bu_basket.gif\' border=\'0\' alt=\'장바구니담기\'/></a></td><td width=\'101\' align=\'left\'><a href=\'http://www.aladin.co.kr/rsscenter/go.aspx?type=safebasket&itemId=173766231&rssType=1\' target=\'_blank\'><img src=\'http://www.aladin.co.kr/img/rss/bu_safebasket.gif\' border=\'0\' alt=\'보관함담기\'/></a></td><td width=\'83\' align=\'left\'></td><td width=\'113\' align=\'left\'></td></tr></table></td></tr><tr><td valign=\'top\' align=\'left\'><img src="http://www.aladin.co.kr/img/book/intro_t.gif" border="0" /><br/>게임을 하면서 코딩도 배우는 일석이조의 경험을 제공한다. 실제 업무에서 사용하는 파이썬을 초등학생 때부터 공부할 수 있다. 파이썬은 전 세계적으로 가장 많이 쓰이는 프로그래밍 언어 중 하나이면서 초등학생도 익힐 수 있는 쉬운 문법을 지니고 있다.<br/><br/><img src="http://www.aladin.co.kr/img/book/content_t.gif" border="0" /><br/><p>1장 마인크래프트 만나기<BR>\n<BR>\n1-1 마인크래프트와 파이썬의 만남<BR>\n<BR>\n1-2 마인크래프트 설치하기<BR>\n<BR>\n1-3 마인크래프트 1.12.1 서버 설치하기<BR>\n<BR>\n1-4 서버설정<BR>\n<BR>\n1-5 파이썬과 MCPI 설치하기<BR>\n<BR>\n1-6 헬로, 마인크래프트!<BR>\n<BR>\n1-7 멀티플레이로 MCPI 즐기기<BR>\n<BR>\n1-8 게임 접속하기<BR>\n<BR>\n1-9 게임 인터페이스<BR>\n<BR>\n1-10 게임 단축키<BR>\n<BR>\n1-11 아이템 조합 튜토리얼<BR>\n<BR>\n1-12 첫날밤 생존 계획<BR>\n<BR>\n1-13 꼭 알아야 하는 마인크래프트 명령어<BR>\n<BR>\n <BR>\n<BR>\n2장 파이썬 시작하기<BR>\n<BR>\n           2-1 헬로, 파이썬!<BR>\n<BR>\n           2-2 파이썬, 덧셈과 뺄셈을 부탁해!<BR>\n<BR>\n           2-3 간단한 계산기 프로그램 만들기<BR>\n<BR>\n <BR>\n<BR>\n3장 마인크래프트 파이썬 입문<BR>\n<BR>\n           3-1 postToChat:파이썬으로 마인크래프트에 외치다!<BR>\n<BR>\n           3-2 getPos:플레이어 위치 조회 서비스<BR>\n<BR>\n           3-3 setPos:플레이어 위치 변경 서비스<BR>\n<BR>\n           3-4 setBlock:블록 생성하기<BR>\n<BR>\n           3-5 setBlocks:블록 여러 개 생성하기<BR>\n<BR>\n           3-6 getBlock:블록 데이터 얻기<BR>\n<BR>\n3-7 getBlockWithData:블록 데이터 얻기<BR>\n<BR>\n3-8 정리<BR>\n<BR>\n <BR>\n<BR>\n4장 초급 텔레포트<BR>\n<BR>\n           4-1 더하기 함수 만들기<BR>\n<BR>\n           4-2 위치 보정 함수 만들기<BR>\n<BR>\n           4-3 집으로 텔레포트 함수 만들기<BR>\n<BR>\n           4-4 단거리 이동 텔레포트<BR>\n<BR>\n           4-5 타이밍 텔레포트<BR>\n<BR>\n           4-6 마인크래프트 건축물 일일투어!<BR>\n<BR>\n <BR>\n<BR>\n5장 고급 텔레포트<BR>\n<BR>\n           5-1 반복 작업 자동화를 위한 list<BR>\n<BR>\n           5-2 반복 작업 자동화를 위한 for문<BR>\n<BR>\n           5-3 자동 텔레포트<BR>\n<BR>\n           5-4 If를 활용한 제어:만약에<BR>\n<BR>\n           5-5 while문을 사용한 반복 작업 수행하기<BR>\n<BR>\n           5-6 집으로 가는 워프 만들기<BR>\n<BR>\n           5-7 감옥 만들기<BR>\n<BR>\n5-8 지하 탈출 텔레포트<BR>\n<BR>\n5-9 자석 텔레포트:다른 모든 플레이어 소환하기<BR>\n<BR>\n <...<br/><br/><img src="http://www.aladin.co.kr/img/book/subject_t.gif" border="0" /><br/><a href=\'http://www.aladin.co.kr/home/wbookmain.aspx\' class=\'ml\'>국내도서</a>&nbsp;>&nbsp;<a href=\'http://www.aladin.co.kr/shop/wbrowse.aspx?CID=351\' class=\'ml\'>컴퓨터/모바일</a>&nbsp;>&nbsp;<a href=\'http://www.aladin.co.kr/shop/wbrowse.aspx?CID=2613\' class=\'ml\'>PC/게임/디지털 카메라</a>&nbsp;>&nbsp;<a href=\'http://www.aladin.co.kr/shop/wbrowse.aspx?CID=6346&BrowseTarget=List\' class=\'ml\'><b>게임</b></a><br/ ...
#   {'authors': [{'name': '알라딘', 'email': 'noSpam.rss@aladdin.co.kr'}],
#    'author': '알라딘 <noSpam.rss@aladdin.co.kr>',
#    'author_detail': {'name': '알라딘', 'email': 'noSpam.rss@aladdin.co.kr'},
#    'tags': [{'term': '국내도서>컴퓨터/모바일>활용능력>컴퓨터활용능력>컴퓨터활용능력 필기',
#      'scheme': None,
#      'label': None}],
#    'title': '2019 이기적 미니족보 컴퓨터활용능력 2급 필기/영진정보연구소 지음/영진.com(영진닷컴)',
#    'title_detail': {'type': 'text/plain',
#     'language': None,
#     'base': 'http://www.aladin.co.kr/rss/special_new/351',
#     'value': '2019 이기적 미니족보 컴퓨터활용능력 2급 필기/영진정보연구소 지음/영진.com(영진닷컴)'},
#    'links': [{'rel': 'alternate',
#      'type': 'text/html',
#      'href': 'http://www.aladin.co.kr/rsscenter/go.aspx?rssType=1&type=item&itemId=173765745'}],
#    'link': 'http://www.aladin.co.kr/rsscenter/go.aspx?rssType=1&type=item&itemId=173765745',
#    'published': 'Mon, 12 Nov 2018 17:29:00 +0900',
#    'published_parsed': time.struct_time(tm_year=2018, tm_mon=11, tm_mday=12, tm_hour=8, tm_min=29, tm_sec=0, tm_wday=0, tm_yday=316, tm_isdst=0),
#    'id': 'http://www.aladin.co.kr/shop/wproduct.aspx?itemID=173765745',
#    'guidislink': False,
#    'summary': '<br/><table border=\'0\' cellpadding=\'0\' cellspacing=\'0\'><tr><td align=\'left\' valign=\'top\'><table cellspacing=\'1\' cellpadding=\'5\' border=\'0\' bgcolor=\'#dddddd\' style=\'margin-right:10px;\'><tbody><tr><td bgcolor=\'#ffffff\'><a href=\'http://www.aladin.co.kr/rsscenter/go.aspx?rssType=1&type=item&itemId=173765745\'><img src=\'https://image.aladin.co.kr/product/17376/57/cover/8931457359_1.jpg\' border=\'0\' /></a></td></tr></tbody></table><h2><a href=\'http://www.aladin.co.kr/rsscenter/go.aspx?rssType=1&type=item&itemId=173765745\'>2019 이기적 미니족보 컴퓨터활용능력 2급 필기</a></h2>영진정보연구소 지음 / 영진.com(영진닷컴) / 2018년 11월 / ISBN:<span class=\'isbn13\'>9788931457353</span><br/>정가: <span style=\'color:#FF0202\'>14,000</span>원 / 판매가: <span style=\'color:#FF0202\'>12,600</span>원 / 마일리지: <span style=\'color:#FF0202\'>49</span>원<br/><span style=\'color:#FF0202\'>이벤트</span>: 수험서.외국어.컴퓨터.전문서적 - 슬림 텀블러/핀버튼 에코백(택1)<br/><table border=\'0\' cellpadding=\'3\' cellspacing=\'0\' height=\'20\'><tr><td width=\'113\' align=\'left\'><a href=\'http://www.aladin.co.kr/rsscenter/go.aspx?type=basket&itemId=173765745&rssType=1\' target=\'_blank\'><img src=\'http://www.aladin.co.kr/img/rss/bu_basket.gif\' border=\'0\' alt=\'장바구니담기\'/></a></td><td width=\'101\' align=\'left\'><a href=\'http://www.aladin.co.kr/rsscenter/go.aspx?type=safebasket&itemId=173765745&rssType=1\' target=\'_blank\'><img src=\'http://www.aladin.co.kr/img/rss/bu_safebasket.gif\' border=\'0\' alt=\'보관함담기\'/></a></td><td width=\'83\' align=\'left\'></td><td width=\'113\' align=\'left\'></td></tr></table></td></tr><tr><td valign=\'top\' align=\'left\'><img src="http://www.aladin.co.kr/img/book/intro_t.gif" border="0" /><br/>컴퓨터활용능력 2급 필기 시험을 준비하는 수험생들을 위해 짧은 시간 동안 효과적으로 공부할 수 있도록 구성되어 있다. [1권] 핵심이론에 수록된 핵심이론과 무료 동영상 강의를 통하여 컴퓨터활용능력 필기에 관한 내용을 확인하고, [2권] 기출문제+정답에 수록되어 있는 자주 출제되는 기출문제 120선과 최신 기출문제 10회분을 통해 시험 유형을 파악할 수 있으며, 부록으로 제공되는 최신 기출문제 시험지 2회분과 CBT 온라인 모의고사를 통해 컴퓨터활용능력 필기 시험을 완벽하게 준비할 수 있다.<br/><br/><img src="http://www.aladin.co.kr/img/book/content_t.gif" border="0" /><br/><p>[1권] 핵심이론 <BR>\n▣ 준비 단계 <BR>\n- 이기적 in 합격생의 후기<BR>\n- 시험 출제 분석표<BR>\n- 이 책의 차례<BR>\n- 시험 안내<BR>\n- 이 책의 구성<BR>\n- 자주 하는 질문 <BR>\n▣ 자주 출제되는 기능 따라하기<BR>\n- 자주 출제되는 엑셀 기능 12가지<BR>\n<BR>\n▣ 손에 잡히는 요점정리 <BR>\n- 1과목 : 컴퓨터 일반<BR>\n- 2과목 : 스프레드시트 일반 <BR>\n<BR>\n[2권] 기출문제집 <BR>\n▣ 손에 잡히는 기출문제 <BR>\n- 자주 출제되는 최신 기출문제 120선 <BR>\n- 해설과 함께 풀어보는 최신 기출문제 <BR>\n        최신 기출문제  1회<BR>\n        최신 기출문제  2회 <BR>\n        최신 기출문제  3회 <BR>\n        최신 기출문제  4회 <BR>\n        최신 기출문제  5회 <BR>\n        최신 기출문제  6회 <BR>\n        최신 기출문제  7회 <BR>\n        최신 기출문제  8회 <BR>\n        최신 기출문제  9회 <BR>\n        최신 기출문제 10회 <BR>\n▣ 최신 기출문제 정답<BR>\n▣ [부록] 최신 기출시험지 2회분(2018년 3월 3일/2018년 9월 1일)</p><br/><br/><img src="http://www.aladin.co.kr/img/book/subject_t.gif" border="0" /><br/><a href=\'http://www.aladin.co.kr/home/wbookmain.aspx\' class=\'ml\'>국내도서</a>&nbsp;>&nbsp;<a href=\'http://www.aladin.co.kr/shop/wbrowse.aspx?CID=351\' class=\'ml\'>컴퓨터/모바일</a>&nbsp;>&nbsp;<a href=\'http://www.aladin.co.kr/shop/wbrowse.aspx?CID=479\' class=\'ml\'>활용능력</a>&nbsp;>&nbsp;<a href=\'http://www.aladin.co.kr/shop/wbrowse.aspx?CID=486\' class=\'ml\'>컴퓨터활용능력</a>&nbsp;>&nbsp;<a href=\'http://www.aladin.co.kr/shop/wbrowse.aspx?CID=7006&BrowseTarget=List\' class=\'ml\'><b>컴퓨터활용능력 필기</b></a><br/><a href=\'http://www.aladin.co.kr/home/wbookmain.aspx\' class=\'ml\'>국내도서</a>&nbsp;>&nbsp;<a href=\'http://www.aladin.co.kr/shop/wbrowse.aspx?CID=1383\' class=\'ml\'>수험서/자격증</a>&nbsp;>&nbsp;<a href=\'http://www.aladin.co.kr/shop/wbrowse.aspx?CID=35777\' class=\'ml\'>컴퓨터 활용능력</a>&nbsp;>&nbsp;<a href=\'http://www.aladin.co.kr/shop/wbrowse.aspx?CID=35790\' class=\'ml\'>컴퓨터활용능력</a>&nbsp;>&nbsp;<a href=\'http://www.aladin.co.kr/shop/wbrowse.aspx?CID=35800&BrowseTarget=List\' class=\'ml\'><b>컴퓨터활용능력 필기</b></a><br/><br/></td></tr></table>',
#    'summary_detail': {'type': 'text/html',
#     'language': None,
#     'base': 'http://www.aladin.co.kr/rss/special_new/351',
#     'value': '<br/><table border=\'0\' cellpadding=\'0\' cellspacing=\'0\'><tr><td align=\'left\' valign=\'top\'><table cellspacing=\'1\' cellpadding=\'5\' border=\'0\' bgcolor=\'#dddddd\' style=\'margin-right:10px;\'><tbody><tr><td bgcolor=\'#ffffff\'><a href=\'http://www.aladin.co.kr/rsscenter/go.aspx?rssType=1&type=item&itemId=173765745\'><img src=\'https://image.aladin.co.kr/product/17376/57/cover/8931457359_1.jpg\' border=\'0\' /></a></td></tr></tbody></table><h2><a href=\'http://www.aladin.co.kr/rsscenter/go.aspx?rssType=1&type=item&itemId=173765745\'>2019 이기적 미니족보 컴퓨터활용능력 2급 필기</a></h2>영진정보연구소 지음 / 영진.com(영진닷컴) / 2018년 11월 / ISBN:<span class=\'isbn13\'>9788931457353</span><br/>정가: <span style=\'color:#FF0202\'>14,000</span>원 / 판매가: <span style=\'color:#FF0202\'>12,600</span>원 / 마일리지: <span style=\'color:#FF0202\'>49</span>원<br/><span style=\'color:#FF0202\'>이벤트</span>: 수험서.외국어.컴퓨터.전문서적 - 슬림 텀블러/핀버튼 에코백(택1)<br/><table border=\'0\' cellpadding=\'3\' cellspacing=\'0\' height=\'20\'><tr><td width=\'113\' align=\'left\'><a href=\'http://www.aladin.co.kr/rsscenter/go.aspx?type=basket&itemId=173765745&rssType=1\' target=\'_blank\'><img src=\'http://www.aladin.co.kr/img/rss/bu_basket.gif\' border=\'0\' alt=\'장바구니담기\'/></a></td><td width=\'101\' align=\'left\'><a href=\'http://www.aladin.co.kr/rsscenter/go.aspx?type=safebasket&itemId=173765745&rssType=1\' target=\'_blank\'><img src=\'http://www.aladin.co.kr/img/rss/bu_safebasket.gif\' border=\'0\' alt=\'보관함담기\'/></a></td><td width=\'83\' align=\'left\'></td><td width=\'113\' align=\'left\'></td></tr></table></td></tr><tr><td valign=\'top\' align=\'left\'><img src="http://www.aladin.co.kr/img/book/intro_t.gif" border="0" /><br/>컴퓨터활용능력 2급 필기 시험을 준비하는 수험생들을 위해 짧은 시간 동안 효과적으로 공부할 수 있도록 구성되어 있다. [1권] 핵심이론에 수록된 핵심이론과 무료 동영상 강의를 통하여 컴퓨터활용능력 필기에 관한 내용을 확인하고, [2권] 기출문제+정답에 수록되어 있는 자주 출제되는 기출문제 120선과 최신 기출문제 10회분을 통해 시험 유형을 파악할 수 있으며, 부록으로 제공되는 최신 기출문제 시험지 2회분과 CBT 온라인 모의고사를 통해 컴퓨터활용능력 필기 시험을 완벽하게 준비할 수 있다.<br/><br/><img src="http://www.aladin.co.kr/img/book/content_t.gif" border="0" /><br/><p>[1권] 핵심이론 <BR>\n▣ 준비 단계 <BR>\n- 이기적 in 합격생의 후기<BR>\n- 시험 출제 분석표<BR>\n- 이 책의 차례<BR>\n- 시험 안내<BR>\n- 이 책의 구성<BR>\n- 자주 하는 질문 <BR>\n▣ 자주 출제되는 기능 따라하기<BR>\n- 자주 출제되는 엑셀 기능 12가지<BR>\n<BR>\n▣ 손에 잡히는 요점정리 <BR>\n- 1과목 : 컴퓨터 일반<BR>\n- 2과목 : 스프레드시트 일반 <BR>\n<BR>\n[2권] 기출문제집 <BR>\n▣ 손에 잡히는 기출문제 <BR>\n- 자주 출제되는 최신 기출문제 120선 <BR>\n- 해설과 함께 풀어보는 최신 기출문제 <BR>\n        최신 기출문제  1회<BR>\n        최신 기출문제  2회 <BR>\n        최신 기출문제  3회 <BR>\n        최신 기출문제  4회 <BR>\n        최신 기출문제  5회 <BR>\n        최신 기출문제  6회 <BR>\n        최신 기출문제  7회 <BR>\n        최신 기출문제  8회 <BR>\n        최신 기출문제  9회 <BR>\n        최신 기출문제 10회 <BR>\n▣ 최신 기출문제 정답<BR>\n▣ [부록] 최신 기출시험지 2회분(2018년 3월 3일/2018년 9월 1일)</p><br/><br/><img src="http://www.aladin.co.kr/img/book/subject_t.gif" border="0" /><br/><a href=\'http://www.aladin.co.kr/home/wbookmain.aspx\' class=\'ml\'>국내도서</a>&nbsp;>&nbsp;<a href=\'http://www.aladin.co.kr/shop/wbrowse.aspx?CID=351\' class=\'ml\'>컴퓨터/모바일</a>&nbsp;>&nbsp;<a href=\'http://www.aladin.co.kr/shop/wbrowse.aspx?CID=479\' class=\'ml\'>활용능력</a>&nbsp;>&nbsp;<a href=\'http://www.aladin.co.kr/shop/wbrowse.aspx?CID=486\' class=\'ml\'>컴퓨터활용능력</a>&nbsp;>&nbsp;<a href=\'http://www.aladin.co.kr/shop/wbrowse.aspx?CID=7006&BrowseTarget=List\' class=\'ml\'><b>컴퓨터활용능력 필기</b></a><br/><a href=\'http://www.aladin.co.kr/home/wbookmain.aspx\' class=\'ml\'>국내도서</a>&nbsp;>&nbsp;<a href=\'http://www.aladin.co.kr/shop/wbrowse.aspx?CID=1383\' class=\'ml\'>수험서/자격증</a>&nbsp;>&nbsp;<a href=\'http://www.aladin.co.kr/shop/wbrowse.aspx?CID=35777\' class=\'ml\'>컴퓨터 활용능력</a>&nbsp;>&nbsp;<a href=\'http://www.aladin.co.kr/shop/wbrowse.aspx?CID=35790\' class=\'ml\'>컴퓨터활용능력</a>&nbsp;>&nbsp;<a href=\'http://www.aladin.co.kr/shop/wbrowse.aspx?CID=35800&BrowseTarget=List\' class=\'ml\'><b>컴퓨터활용능력 필기</b></a><br/><br/></td></tr></table>'}},
#   {'authors': [{'name': '알라딘', 'email': 'noSpam.rss@aladdin.co.kr'}],
#    'author': '알라딘 <noSpam.rss@aladdin.co.kr>',
#    'author_detail': {'name': '알라딘', 'email': 'noSpam.rss@aladdin.co.kr'},
#    'tags': [{'term': '국내도서>컴퓨터/모바일>컴퓨터 공학>자료구조/알고리즘',
#      'scheme': None,
#      'label': None}],
#    'title': '빅데이터 활용사전 419/윤종식 지음/데이터에듀',
#    'title_detail': {'type': 'text/plain',
#     'language': None,
#     'base': 'http://www.aladin.co.kr/rss/special_new/351',
#     'value': '빅데이터 활용사전 419/윤종식 지음/데이터에듀'},
#    'links': [{'rel': 'alternate',
#      'type': 'text/html',
#      'href': 'http://www.aladin.co.kr/rsscenter/go.aspx?rssType=1&type=item&itemId=173759446'}],
#    'link': 'http://www.aladin.co.kr/rsscenter/go.aspx?rssType=1&type=item&itemId=173759446',
#    'published': 'Mon, 12 Nov 2018 16:14:00 +0900',
#    'published_parsed': time.struct_time(tm_year=2018, tm_mon=11, tm_mday=12, tm_hour=7, tm_min=14, tm_sec=0, tm_wday=0, tm_yday=316, tm_isdst=0),
#    'id': 'http://www.aladin.co.kr/shop/wproduct.aspx?itemID=173759446',
#    'guidislink': False,
#    'summary': '<br/><table border=\'0\' cellpadding=\'0\' cellspacing=\'0\'><tr><td align=\'left\' valign=\'top\'><table cellspacing=\'1\' cellpadding=\'5\' border=\'0\' bgcolor=\'#dddddd\' style=\'margin-right:10px;\'><tbody><tr><td bgcolor=\'#ffffff\'><a href=\'http://www.aladin.co.kr/rsscenter/go.aspx?rssType=1&type=item&itemId=173759446\'><img src=\'https://image.aladin.co.kr/product/17375/94/cover/k462534597_1.jpg\' border=\'0\' /></a></td></tr></tbody></table><h2><a href=\'http://www.aladin.co.kr/rsscenter/go.aspx?rssType=1&type=item&itemId=173759446\'>빅데이터 활용사전 419</a></h2>윤종식 지음 / 데이터에듀 / 2018년 10월 / ISBN:<span class=\'isbn13\'>9791195480159</span><br/>정가: <span style=\'color:#FF0202\'>48,500</span>원 / 판매가: <span style=\'color:#FF0202\'>43,650</span>원 / 마일리지: <span style=\'color:#FF0202\'>159</span>원<br/><span style=\'color:#FF0202\'>이벤트</span>: 수험서.외국어.컴퓨터.전문서적 - 슬림 텀블러/핀버튼 에코백(택1)<br/><table border=\'0\' cellpadding=\'3\' cellspacing=\'0\' height=\'20\'><tr><td width=\'113\' align=\'left\'><a href=\'http://www.aladin.co.kr/rsscenter/go.aspx?type=basket&itemId=173759446&rssType=1\' target=\'_blank\'><img src=\'http://www.aladin.co.kr/img/rss/bu_basket.gif\' border=\'0\' alt=\'장바구니담기\'/></a></td><td width=\'101\' align=\'left\'><a href=\'http://www.aladin.co.kr/rsscenter/go.aspx?type=safebasket&itemId=173759446&rssType=1\' target=\'_blank\'><img src=\'http://www.aladin.co.kr/img/rss/bu_safebasket.gif\' border=\'0\' alt=\'보관함담기\'/></a></td><td width=\'83\' align=\'left\'></td><td width=\'113\' align=\'left\'></td></tr></table></td></tr><tr><td valign=\'top\' align=\'left\'><img src="http://www.aladin.co.kr/img/book/intro_t.gif" border="0" /><br/>기존에 흩어져있던 빅데이터 활용 사례들을 업종/목적별로 한곳에 모아 Data Insight Matrix에 맞춰 정리한 사례 모음집으로, 실질적인 빅데이터 분석 프로세스를 보다 쉽게 이해할 수 있도록 구성하였다. 추가적으로 다양한 용어 설명과 함께 도식화된 그림들을 통해 비전공자들도 쉽게 이해할 수 있도록 구성하였다.<br/><br/><img src="http://www.aladin.co.kr/img/book/content_t.gif" border="0" /><br/><p>1부 활용사례 <BR>\n공공 (case# 001~101)<BR>\n   공공 활용사례 Issue Report     014<BR>\n   주요 사례분석\t\t<BR>\n빅데이터를 통한 고용취약자 파악     020<BR>\n공간 빅데이터를 활용한 도시 양극화 분석     024<BR>\n빅데이터 기반 지능형 전기화재 예방 플랫폼 구축     028<BR>\n미세먼지 대응 표준 빅데이터 모델 개발     032<BR>\n빅데이터 기반 지능형 도시가스 배관 위험 예측     036<BR>\n동물 및 인간 감염병 확산 대응 지원 체계 구축     040<BR>\n교통사고 감소를 위한 빅데이터 예보 서비스     046<BR>\n경기 모니터링 시스템     050<BR>\n미세먼지 이슈와 빅데이터 활용방안     054<BR>\n골든 타임 확보로 응급환자 생존률 향상     058<BR>\n공동주택 부조리 분석시스템 개발     062<BR>\n사회취약계층 선제적 발견을 통해 지원     066<BR>\n의료이용지도연구를 통한 의료 정책 질 향상     070<BR>\n빅데이터로 산불 피해 최소화     074<BR>\n질병도 이젠 빅데이터로 예측하고 예방     078<BR>\n빅데이터로 위험한 도로를 피하자     082<BR>\n체납액 회수도 과학적인 방법으로     086<BR>\n개인 맞춤형 인공지능 질환예측 서비스     090<BR>\n빅데이터를 활용한 보다 안전한 도로관리     094<BR>\n빅데이터를 통한 병역면탈범죄 의심자 포착     098<BR>\n근로감독 사업장 선정 과학화     102<BR>\n빅데이터로 갈등 발생 전 예방까지     108<BR>\n국민참여형 어린이 안전 및 교통사고 원인분석     112<BR>\n실업급여 부정 수급 악용 빅데이터로 뿌리 뽑기     116<BR>\n상수도 누수지역 탐지모델     120<BR>\n빅데이터로 전기차 충전 인프라 설치 입지 선정     124<BR>\n사고 행동을 분석하여 적극적인 예방을 계획     128<BR>\n  기타 사례분석     132<BR>\n금융 (case# 102~148)<BR>\n  금융업 활용사례 Issue Report     162<BR>\n  주요 사례분석\t<BR>\n빅데이터 기반 대내외 경제기획 수립     168<BR>\n빅데이터 활용 공동주택 시세 산정 시스템     172<BR>\n빅데이터가 가져올 금융 산업계 파급 효과     178<BR>\n고객의 발자취와 목소리     182<BR>\n데이터의 융합을 통한 시의적절한 마케팅     186<BR>\n빅데이터 기반 회계 관리 시스템     190<BR>\n온라인 사기 예방도 빅데이터와 함께     194<BR>\n빅데이터 기반 자금 세탁 방지 시스템     198<BR>\n  기타 사례분석     202<BR>\n...<br/><br/><img src="http://www.aladin.co.kr/img/book/subject_t.gif" border="0" /><br/><a href=\'http://www.aladin.co.kr/home/wbookmain.aspx\' class=\'ml\'>국내도서</a>&nbsp;>&nbsp;<a href=\'http://www.aladin.co.kr/shop/wbrowse.aspx?CID=351\' class=\'ml\'>컴퓨터/모바일</a>&nbsp;>&nbsp;<a href=\'http://www.aladin.co.kr/shop/wbrowse.aspx?CID=2719\' class=\'ml\'>컴퓨터 공학</a>&nbsp;>&nbsp;<a href=\'http://www.aladin.co.kr/shop/wbrowse.aspx?CID=2732&BrowseTarget=List\' class=\'ml\'><b>자료구조/알고리즘</b></a><br/><br/></td></tr></table>',
#    'summary_detail': {'type': 'text/html',
#     'language': None,
#     'base': 'http://www.aladin.co.kr/rss/special_new/351',
#     'value': '<br/><table border=\'0\' cellpadding=\'0\' cellspacing=\'0\'><tr><td align=\'left\' valign=\'top\'><table cellspacing=\'1\' cellpadding=\'5\' border=\'0\' bgcolor=\'#dddddd\' style=\'margin-right:10px;\'><tbody><tr><td bgcolor=\'#ffffff\'><a href=\'http://www.aladin.co.kr/rsscenter/go.aspx?rssType=1&type=item&itemId=173759446\'><img src=\'https://image.aladin.co.kr/product/17375/94/cover/k462534597_1.jpg\' border=\'0\' /></a></td></tr></tbody></table><h2><a href=\'http://www.aladin.co.kr/rsscenter/go.aspx?rssType=1&type=item&itemId=173759446\'>빅데이터 활용사전 419</a></h2>윤종식 지음 / 데이터에듀 / 2018년 10월 / ISBN:<span class=\'isbn13\'>9791195480159</span><br/>정가: <span style=\'color:#FF0202\'>48,500</span>원 / 판매가: <span style=\'color:#FF0202\'>43,650</span>원 / 마일리지: <span style=\'color:#FF0202\'>159</span>원<br/><span style=\'color:#FF0202\'>이벤트</span>: 수험서.외국어.컴퓨터.전문서적 - 슬림 텀블러/핀버튼 에코백(택1)<br/><table border=\'0\' cellpadding=\'3\' cellspacing=\'0\' height=\'20\'><tr><td width=\'113\' align=\'left\'><a href=\'http://www.aladin.co.kr/rsscenter/go.aspx?type=basket&itemId=173759446&rssType=1\' target=\'_blank\'><img src=\'http://www.aladin.co.kr/img/rss/bu_basket.gif\' border=\'0\' alt=\'장바구니담기\'/></a></td><td width=\'101\' align=\'left\'><a href=\'http://www.aladin.co.kr/rsscenter/go.aspx?type=safebasket&itemId=173759446&rssType=1\' target=\'_blank\'><img src=\'http://www.aladin.co.kr/img/rss/bu_safebasket.gif\' border=\'0\' alt=\'보관함담기\'/></a></td><td width=\'83\' align=\'left\'></td><td width=\'113\' align=\'left\'></td></tr></table></td></tr><tr><td valign=\'top\' align=\'left\'><img src="http://www.aladin.co.kr/img/book/intro_t.gif" border="0" /><br/>기존에 흩어져있던 빅데이터 활용 사례들을 업종/목적별로 한곳에 모아 Data Insight Matrix에 맞춰 정리한 사례 모음집으로, 실질적인 빅데이터 분석 프로세스를 보다 쉽게 이해할 수 있도록 구성하였다. 추가적으로 다양한 용어 설명과 함께 도식화된 그림들을 통해 비전공자들도 쉽게 이해할 수 있도록 구성하였다.<br/><br/><img src="http://www.aladin.co.kr/img/book/content_t.gif" border="0" /><br/><p>1부 활용사례 <BR>\n공공 (case# 001~101)<BR>\n   공공 활용사례 Issue Report     014<BR>\n   주요 사례분석\t\t<BR>\n빅데이터를 통한 고용취약자 파악     020<BR>\n공간 빅데이터를 활용한 도시 양극화 분석     024<BR>\n빅데이터 기반 지능형 전기화재 예방 플랫폼 구축     028<BR>\n미세먼지 대응 표준 빅데이터 모델 개발     032<BR>\n빅데이터 기반 지능형 도시가스 배관 위험 예측     036<BR>\n동물 및 인간 감염병 확산 대응 지원 체계 구축     040<BR>\n교통사고 감소를 위한 빅데이터 예보 서비스     046<BR>\n경기 모니터링 시스템     050<BR>\n미세먼지 이슈와 빅데이터 활용방안     054<BR>\n골든 타임 확보로 응급환자 생존률 향상     058<BR>\n공동주택 부조리 분석시스템 개발     062<BR>\n사회취약계층 선제적 발견을 통해 지원     066<BR>\n의료이용지도연구를 통한 의료 정책 질 향상     070<BR>\n빅데이터로 산불 피해 최소화     074<BR>\n질병도 이젠 빅데이터로 예측하고 예방     078<BR>\n빅데이터로 위험한 도로를 피하자     082<BR>\n체납액 회수도 과학적인 방법으로     086<BR>\n개인 맞춤형 인공지능 질환예측 서비스     090<BR>\n빅데이터를 활용한 보다 안전한 도로관리     094<BR>\n빅데이터를 통한 병역면탈범죄 의심자 포착     098<BR>\n근로감독 사업장 선정 과학화     102<BR>\n빅데이터로 갈등 발생 전 예방까지     108<BR>\n국민참여형 어린이 안전 및 교통사고 원인분석     112<BR>\n실업급여 부정 수급 악용 빅데이터로 뿌리 뽑기     116<BR>\n상수도 누수지역 탐지모델     120<BR>\n빅데이터로 전기차 충전 인프라 설치 입지 선정     124<BR>\n사고 행동을 분석하여 적극적인 예방을 계획     128<BR>\n  기타 사례분석     132<BR>\n금융 (case# 102~148)<BR>\n  금융업 활용사례 Issue Report     162<BR>\n  주요 사례분석\t<BR>\n빅데이터 기반 대내외 경제기획 수립     168<BR>\n빅데이터 활용 공동주택 시세 산정 시스템     172<BR>\n빅데이터가 가져올 금융 산업계 파급 효과     178<BR>\n고객의 발자취와 목소리     182<BR>\n데이터의 융합을 통한 시의적절한 마케팅     186<BR>\n빅데이터 기반 회계 관리 시스템     190<BR>\n온라인 사기 예방도 빅데이터와 함께     194<BR>\n빅데이터 기반 자금 세탁 방지 시스템     198<BR>\n  기타 사례분석     202<BR>\n...<br/><br/><img src="http://www.aladin.co.kr/img/book/subject_t.gif" border="0" /><br/><a href=\'http://www.aladin.co.kr/home/wbookmain.aspx\' class=\'ml\'>국내도서</a>&nbsp;>&nbsp;<a href=\'http://www.aladin.co.kr/shop/wbrowse.aspx?CID=351\' class=\'ml\'>컴퓨터/모바일</a>&nbsp;>&nbsp;<a href=\'http://www.aladin.co.kr/shop/wbrowse.aspx?CID=2719\' class=\'ml\'>컴퓨터 공학</a>&nbsp;>&nbsp;<a href=\'http://www.aladin.co.kr/shop/wbrowse.aspx?CID=2732&BrowseTarget=List\' class=\'ml\'><b>자료구조/알고리즘</b></a><br/><br/></td></tr></table>'}},
#   {'authors': [{'name': '알라딘', 'email': 'noSpam.rss@aladdin.co.kr'}],
#    'author': '알라딘 <noSpam.rss@aladdin.co.kr>',
#    'author_detail': {'name': '알라딘', 'email': 'noSpam.rss@aladdin.co.kr'},
#    'tags': [{'term': '국내도서>컴퓨터/모바일>OS/Networking>네트워크 보안/해킹',
#      'scheme': None,
#      'label': None}],
#    'title': '보안관제와 윈도우 포렌식 실무/오재헌 지음/홍릉과학출판사',
#    'title_detail': {'type': 'text/plain',
#     'language': None,
#     'base': 'http://www.aladin.co.kr/rss/special_new/351',
#     'value': '보안관제와 윈도우 포렌식 실무/오재헌 지음/홍릉과학출판사'},
#    'links': [{'rel': 'alternate',
#      'type': 'text/html',
#      'href': 'http://www.aladin.co.kr/rsscenter/go.aspx?rssType=1&type=item&itemId=173755365'}],
#    'link': 'http://www.aladin.co.kr/rsscenter/go.aspx?rssType=1&type=item&itemId=173755365',
#    'published': 'Mon, 12 Nov 2018 15:32:00 +0900',
#    'published_parsed': time.struct_time(tm_year=2018, tm_mon=11, tm_mday=12, tm_hour=6, tm_min=32, tm_sec=0, tm_wday=0, tm_yday=316, tm_isdst=0),
#    'id': 'http://www.aladin.co.kr/shop/wproduct.aspx?itemID=173755365',
#    'guidislink': False,
#    'summary': '<br/><table border=\'0\' cellpadding=\'0\' cellspacing=\'0\'><tr><td align=\'left\' valign=\'top\'><table cellspacing=\'1\' cellpadding=\'5\' border=\'0\' bgcolor=\'#dddddd\' style=\'margin-right:10px;\'><tbody><tr><td bgcolor=\'#ffffff\'><a href=\'http://www.aladin.co.kr/rsscenter/go.aspx?rssType=1&type=item&itemId=173755365\'><img src=\'https://image.aladin.co.kr/product/17375/53/cover/k082534597_1.jpg\' border=\'0\' /></a></td></tr></tbody></table><h2><a href=\'http://www.aladin.co.kr/rsscenter/go.aspx?rssType=1&type=item&itemId=173755365\'>보안관제와 윈도우 포렌식 실무</a></h2>오재헌 지음 / 홍릉과학출판사 / 2018년 11월 / ISBN:<span class=\'isbn13\'>9791156006145</span><br/>정가: <span style=\'color:#FF0202\'>17,000</span>원 / 판매가: <span style=\'color:#FF0202\'>17,000</span>원 / 마일리지: <span style=\'color:#FF0202\'>73</span>원<br/><span style=\'color:#FF0202\'>이벤트</span>: 수험서.외국어.컴퓨터.전문서적 - 슬림 텀블러/핀버튼 에코백(택1)<br/><table border=\'0\' cellpadding=\'3\' cellspacing=\'0\' height=\'20\'><tr><td width=\'113\' align=\'left\'><a href=\'http://www.aladin.co.kr/rsscenter/go.aspx?type=basket&itemId=173755365&rssType=1\' target=\'_blank\'><img src=\'http://www.aladin.co.kr/img/rss/bu_basket.gif\' border=\'0\' alt=\'장바구니담기\'/></a></td><td width=\'101\' align=\'left\'><a href=\'http://www.aladin.co.kr/rsscenter/go.aspx?type=safebasket&itemId=173755365&rssType=1\' target=\'_blank\'><img src=\'http://www.aladin.co.kr/img/rss/bu_safebasket.gif\' border=\'0\' alt=\'보관함담기\'/></a></td><td width=\'83\' align=\'left\'></td><td width=\'113\' align=\'left\'></td></tr></table></td></tr><tr><td valign=\'top\' align=\'left\'><img src="http://www.aladin.co.kr/img/book/subject_t.gif" border="0" /><br/><a href=\'http://www.aladin.co.kr/home/wbookmain.aspx\' class=\'ml\'>국내도서</a>&nbsp;>&nbsp;<a href=\'http://www.aladin.co.kr/shop/wbrowse.aspx?CID=351\' class=\'ml\'>컴퓨터/모바일</a>&nbsp;>&nbsp;<a href=\'http://www.aladin.co.kr/shop/wbrowse.aspx?CID=363\' class=\'ml\'>OS/Networking</a>&nbsp;>&nbsp;<a href=\'http://www.aladin.co.kr/shop/wbrowse.aspx?CID=387&BrowseTarget=List\' class=\'ml\'><b>네트워크 보안/해킹</b></a><br/><br/></td></tr></table>',
#    'summary_detail': {'type': 'text/html',
#     'language': None,
#     'base': 'http://www.aladin.co.kr/rss/special_new/351',
#     'value': '<br/><table border=\'0\' cellpadding=\'0\' cellspacing=\'0\'><tr><td align=\'left\' valign=\'top\'><table cellspacing=\'1\' cellpadding=\'5\' border=\'0\' bgcolor=\'#dddddd\' style=\'margin-right:10px;\'><tbody><tr><td bgcolor=\'#ffffff\'><a href=\'http://www.aladin.co.kr/rsscenter/go.aspx?rssType=1&type=item&itemId=173755365\'><img src=\'https://image.aladin.co.kr/product/17375/53/cover/k082534597_1.jpg\' border=\'0\' /></a></td></tr></tbody></table><h2><a href=\'http://www.aladin.co.kr/rsscenter/go.aspx?rssType=1&type=item&itemId=173755365\'>보안관제와 윈도우 포렌식 실무</a></h2>오재헌 지음 / 홍릉과학출판사 / 2018년 11월 / ISBN:<span class=\'isbn13\'>9791156006145</span><br/>정가: <span style=\'color:#FF0202\'>17,000</span>원 / 판매가: <span style=\'color:#FF0202\'>17,000</span>원 / 마일리지: <span style=\'color:#FF0202\'>73</span>원<br/><span style=\'color:#FF0202\'>이벤트</span>: 수험서.외국어.컴퓨터.전문서적 - 슬림 텀블러/핀버튼 에코백(택1)<br/><table border=\'0\' cellpadding=\'3\' cellspacing=\'0\' height=\'20\'><tr><td width=\'113\' align=\'left\'><a href=\'http://www.aladin.co.kr/rsscenter/go.aspx?type=basket&itemId=173755365&rssType=1\' target=\'_blank\'><img src=\'http://www.aladin.co.kr/img/rss/bu_basket.gif\' border=\'0\' alt=\'장바구니담기\'/></a></td><td width=\'101\' align=\'left\'><a href=\'http://www.aladin.co.kr/rsscenter/go.aspx?type=safebasket&itemId=173755365&rssType=1\' target=\'_blank\'><img src=\'http://www.aladin.co.kr/img/rss/bu_safebasket.gif\' border=\'0\' alt=\'보관함담기\'/></a></td><td width=\'83\' align=\'left\'></td><td width=\'113\' align=\'left\'></td></tr></table></td></tr><tr><td valign=\'top\' align=\'left\'><img src="http://www.aladin.co.kr/img/book/subject_t.gif" border="0" /><br/><a href=\'http://www.aladin.co.kr/home/wbookmain.aspx\' class=\'ml\'>국내도서</a>&nbsp;>&nbsp;<a href=\'http://www.aladin.co.kr/shop/wbrowse.aspx?CID=351\' class=\'ml\'>컴퓨터/모바일</a>&nbsp;>&nbsp;<a href=\'http://www.aladin.co.kr/shop/wbrowse.aspx?CID=363\' class=\'ml\'>OS/Networking</a>&nbsp;>&nbsp;<a href=\'http://www.aladin.co.kr/shop/wbrowse.aspx?CID=387&BrowseTarget=List\' class=\'ml\'><b>네트워크 보안/해킹</b></a><br/><br/></td></tr></table>'}},
#   {'authors': [{'name': '알라딘', 'email': 'noSpam.rss@aladdin.co.kr'}],
#    'author': '알라딘 <noSpam.rss@aladdin.co.kr>',
#    'author_detail': {'name': '알라딘', 'email': 'noSpam.rss@aladdin.co.kr'},
#    'tags': [{'term': '국내도서>컴퓨터/모바일>OS/Networking>네트워크 보안/해킹',
#      'scheme': None,
#      'label': None}],
#    'title': '정보 보안 개론과 실습 - 시스템 해킹과 보안/양대일 지음/한빛아카데미(교재)',
#    'title_detail': {'type': 'text/plain',
#     'language': None,
#     'base': 'http://www.aladin.co.kr/rss/special_new/351',
#     'value': '정보 보안 개론과 실습 - 시스템 해킹과 보안/양대일 지음/한빛아카데미(교재)'},
#    'links': [{'rel': 'alternate',
#      'type': 'text/html',
#      'href': 'http://www.aladin.co.kr/rsscenter/go.aspx?rssType=1&type=item&itemId=173735619'}],
#    'link': 'http://www.aladin.co.kr/rsscenter/go.aspx?rssType=1&type=item&itemId=173735619',
#    'published': 'Mon, 12 Nov 2018 11:34:00 +0900',
#    'published_parsed': time.struct_time(tm_year=2018, tm_mon=11, tm_mday=12, tm_hour=2, tm_min=34, tm_sec=0, tm_wday=0, tm_yday=316, tm_isdst=0),
#    'id': 'http://www.aladin.co.kr/shop/wproduct.aspx?itemID=173735619',
#    'guidislink': False,
#    'summary': '<br/><table border=\'0\' cellpadding=\'0\' cellspacing=\'0\'><tr><td align=\'left\' valign=\'top\'><table cellspacing=\'1\' cellpadding=\'5\' border=\'0\' bgcolor=\'#dddddd\' style=\'margin-right:10px;\'><tbody><tr><td bgcolor=\'#ffffff\'><a href=\'http://www.aladin.co.kr/rsscenter/go.aspx?rssType=1&type=item&itemId=173735619\'><img src=\'https://image.aladin.co.kr/product/17373/56/cover/k902534594_1.jpg\' border=\'0\' /></a></td></tr></tbody></table><h2><a href=\'http://www.aladin.co.kr/rsscenter/go.aspx?rssType=1&type=item&itemId=173735619\'>정보 보안 개론과 실습 - 시스템 해킹과 보안</a></h2>양대일 지음 / 한빛아카데미(교재) / 2018년 11월 / ISBN:<span class=\'isbn13\'>9791156644101</span><br/>정가: <span style=\'color:#FF0202\'>27,000</span>원 / 판매가: <span style=\'color:#FF0202\'>27,000</span>원 / 마일리지: <span style=\'color:#FF0202\'>116</span>원<br/><span style=\'color:#FF0202\'>이벤트</span>: 수험서.외국어.컴퓨터.전문서적 - 슬림 텀블러/핀버튼 에코백(택1)<br/><table border=\'0\' cellpadding=\'3\' cellspacing=\'0\' height=\'20\'><tr><td width=\'113\' align=\'left\'><a href=\'http://www.aladin.co.kr/rsscenter/go.aspx?type=basket&itemId=173735619&rssType=1\' target=\'_blank\'><img src=\'http://www.aladin.co.kr/img/rss/bu_basket.gif\' border=\'0\' alt=\'장바구니담기\'/></a></td><td width=\'101\' align=\'left\'><a href=\'http://www.aladin.co.kr/rsscenter/go.aspx?type=safebasket&itemId=173735619&rssType=1\' target=\'_blank\'><img src=\'http://www.aladin.co.kr/img/rss/bu_safebasket.gif\' border=\'0\' alt=\'보관함담기\'/></a></td><td width=\'83\' align=\'left\'></td><td width=\'113\' align=\'left\'></td></tr></table></td></tr><tr><td valign=\'top\' align=\'left\'><img src="http://www.aladin.co.kr/img/book/intro_t.gif" border="0" /><br/>34개 실습 예제로 배우는 최신 해킹 기술과 시스템 보안 기법을 저술한 책. <BR>\n운영체제 기본 이론을 학습한 후 실제와 같은 실습 환경을 통해 시스템 해킹 기법을 익히고, 운영체제 종류별로 각각의 취약점과 해킹에 대비하는 침입 탐지 기법을 배운다. 보안이 중요한 게임 등의 상용 프로그램을 개발하고 싶은 분, 백신을 만들거나 시스템을 안정적으로 운영하는 업무를 하고 싶은 분이라면 이 책의 내용이 매우 유용할 것이다.<br/><br/><img src="http://www.aladin.co.kr/img/book/content_t.gif" border="0" /><br/><p><B>Part 01 시스템 해킹 기초 지식</B><BR>\nChapter 01 운영체제 이해 <BR>\n1.1 운영체제의 개념과 기능<BR>\n1.2 윈도우의 이해<BR>\n1.3 리눅스/유닉스의 이해<BR>\n요약<BR>\n연습문제 <BR>\n<BR>\nChapter 02 80x86 시스템의 이해<BR>\n2.1 80x86 시스템 CPU 구조와 레지스터 <BR>\n2.2 80x86 시스템 메모리의 구조와 동작<BR>\n2.3 어셈블리어 기본 문법과 명령<BR>\n2.4 스택을 이용한 명령 처리 과정<BR>\n요약<BR>\n연습문제 <BR>\n현장의 목소리<BR>\n<BR>\nChapter 03 계정과 권한<BR>\n3.1 리눅스/유닉스의 계정과 권한 체계<BR>\n3.2 리눅스/유닉스의 권한 상승<BR>\n3.3 윈도우의 계정과 권한 체계<BR>\n3.4 윈도우의 권한 상승<BR>\n요약<BR>\n연습문제 <BR>\n<BR>\n<B>Part 02 시스템 해킹</B><BR>\nChapter 04 패스워드 크래킹<BR>\n4.1 패스워드 크래킹의 이해<BR>\n4.2 윈도우 인증과 패스워드<BR>\n4.3 리눅스/유닉스 인증과 패스워드<BR>\n4.4 서비스 데몬 패스워드<BR>\n4.5 운영체제별 패스워드 복구<BR>\n요약<BR>\n연습문제 <BR>\n현장의 목소리<BR>\n<BR>\nChapter 05 리버스 엔지니어링<BR>\n5.1 리버스 엔지니어링의 이해<BR>\n5.2 리버스 엔지니어링 툴<BR>\n5.3 리버스 엔지니어링 공격<BR>\n5.4 리버스 엔지니어링 대응책<BR>\n요약<BR>\n연습문제 <BR>\n<BR>\nChapter 06 레이스 컨디션<BR>\n6.1 레이스 컨디션 공격의 이해<BR>\n6.2 레이스 컨디션 공격 대응책<BR>\n요약<BR>\n연습문제<BR>\n현장의 목소리<BR>\n<BR>\nChapter 07 버퍼 오버플로<BR>\n7.1 스택 버퍼 오버플로 공격<BR>\n7.2 힙 버퍼 오버플로 공격<BR>\n7.3 버퍼 오버플로 공격 대응책과 발전된 공격<BR>\n요약<BR>\n연습문제<BR>\n<BR>\nChapter 08 포맷 스트링<BR>\n8.1 포맷 스트링 공격<BR>\n8.2 포맷 스트링 공격 대응책 <BR>\n요약<BR>\n연습문제<BR>\n<BR>\nChapter 09 백도어<BR>\n9.1 백도어의 이해<BR>\n9.2 윈도우 백도어<BR>\n9.3 리눅스 백도어<BR>\n9.4 백도어 탐지 순서와 대응책<BR>\n요약<BR>\n연습문제<BR>\n현장의 목소리<BR>\n<BR>\n<B>Part 03 운영체제 보안</B><BR>\nChapter 10 윈도우 시스템 보안 설정(윈도우 서버 2016)<BR>\n10.1 계정 정책<BR>\n10.2 로컬 정책<BR>\n10.3 데몬 관리<BR>\n10.4 접근 제어<BR>\n10.5 파일과 디렉터리 관리<BR>\n10.6 기타 보안 관리<BR>\n요약<BR>\n연습문제<BR>\n<BR>\nChapter 11 ...<br/><br/><img src="http://www.aladin.co.kr/img/book/subject_t.gif" border="0" /><br/><a href=\'http://www.aladin.co.kr/home/wbookmain.aspx\' class=\'ml\'>국내도서</a>&nbsp;>&nbsp;<a href=\'http://www.aladin.co.kr/shop/wbrowse.aspx?CID=351\' class=\'ml\'>컴퓨터/모바일</a>&nbsp;>&nbsp;<a href=\'http://www.aladin.co.kr/shop/wbrowse.aspx?CID=363\' class=\'ml\'>OS/Networking</a>&nbsp;>&nbsp;<a href=\'http://www.aladin.co.kr/shop/wbrowse.aspx?CID=387&BrowseTarget=List\' class=\'ml\'><b>네트워크 보안/해킹</b></ ...
#    'summary_detail': {'type': 'text/html',
#     'language': None,
#     'base': 'http://www.aladin.co.kr/rss/special_new/351',
#     'value': '<br/><table border=\'0\' cellpadding=\'0\' cellspacing=\'0\'><tr><td align=\'left\' valign=\'top\'><table cellspacing=\'1\' cellpadding=\'5\' border=\'0\' bgcolor=\'#dddddd\' style=\'margin-right:10px;\'><tbody><tr><td bgcolor=\'#ffffff\'><a href=\'http://www.aladin.co.kr/rsscenter/go.aspx?rssType=1&type=item&itemId=173735619\'><img src=\'https://image.aladin.co.kr/product/17373/56/cover/k902534594_1.jpg\' border=\'0\' /></a></td></tr></tbody></table><h2><a href=\'http://www.aladin.co.kr/rsscenter/go.aspx?rssType=1&type=item&itemId=173735619\'>정보 보안 개론과 실습 - 시스템 해킹과 보안</a></h2>양대일 지음 / 한빛아카데미(교재) / 2018년 11월 / ISBN:<span class=\'isbn13\'>9791156644101</span><br/>정가: <span style=\'color:#FF0202\'>27,000</span>원 / 판매가: <span style=\'color:#FF0202\'>27,000</span>원 / 마일리지: <span style=\'color:#FF0202\'>116</span>원<br/><span style=\'color:#FF0202\'>이벤트</span>: 수험서.외국어.컴퓨터.전문서적 - 슬림 텀블러/핀버튼 에코백(택1)<br/><table border=\'0\' cellpadding=\'3\' cellspacing=\'0\' height=\'20\'><tr><td width=\'113\' align=\'left\'><a href=\'http://www.aladin.co.kr/rsscenter/go.aspx?type=basket&itemId=173735619&rssType=1\' target=\'_blank\'><img src=\'http://www.aladin.co.kr/img/rss/bu_basket.gif\' border=\'0\' alt=\'장바구니담기\'/></a></td><td width=\'101\' align=\'left\'><a href=\'http://www.aladin.co.kr/rsscenter/go.aspx?type=safebasket&itemId=173735619&rssType=1\' target=\'_blank\'><img src=\'http://www.aladin.co.kr/img/rss/bu_safebasket.gif\' border=\'0\' alt=\'보관함담기\'/></a></td><td width=\'83\' align=\'left\'></td><td width=\'113\' align=\'left\'></td></tr></table></td></tr><tr><td valign=\'top\' align=\'left\'><img src="http://www.aladin.co.kr/img/book/intro_t.gif" border="0" /><br/>34개 실습 예제로 배우는 최신 해킹 기술과 시스템 보안 기법을 저술한 책. <BR>\n운영체제 기본 이론을 학습한 후 실제와 같은 실습 환경을 통해 시스템 해킹 기법을 익히고, 운영체제 종류별로 각각의 취약점과 해킹에 대비하는 침입 탐지 기법을 배운다. 보안이 중요한 게임 등의 상용 프로그램을 개발하고 싶은 분, 백신을 만들거나 시스템을 안정적으로 운영하는 업무를 하고 싶은 분이라면 이 책의 내용이 매우 유용할 것이다.<br/><br/><img src="http://www.aladin.co.kr/img/book/content_t.gif" border="0" /><br/><p><B>Part 01 시스템 해킹 기초 지식</B><BR>\nChapter 01 운영체제 이해 <BR>\n1.1 운영체제의 개념과 기능<BR>\n1.2 윈도우의 이해<BR>\n1.3 리눅스/유닉스의 이해<BR>\n요약<BR>\n연습문제 <BR>\n<BR>\nChapter 02 80x86 시스템의 이해<BR>\n2.1 80x86 시스템 CPU 구조와 레지스터 <BR>\n2.2 80x86 시스템 메모리의 구조와 동작<BR>\n2.3 어셈블리어 기본 문법과 명령<BR>\n2.4 스택을 이용한 명령 처리 과정<BR>\n요약<BR>\n연습문제 <BR>\n현장의 목소리<BR>\n<BR>\nChapter 03 계정과 권한<BR>\n3.1 리눅스/유닉스의 계정과 권한 체계<BR>\n3.2 리눅스/유닉스의 권한 상승<BR>\n3.3 윈도우의 계정과 권한 체계<BR>\n3.4 윈도우의 권한 상승<BR>\n요약<BR>\n연습문제 <BR>\n<BR>\n<B>Part 02 시스템 해킹</B><BR>\nChapter 04 패스워드 크래킹<BR>\n4.1 패스워드 크래킹의 이해<BR>\n4.2 윈도우 인증과 패스워드<BR>\n4.3 리눅스/유닉스 인증과 패스워드<BR>\n4.4 서비스 데몬 패스워드<BR>\n4.5 운영체제별 패스워드 복구<BR>\n요약<BR>\n연습문제 <BR>\n현장의 목소리<BR>\n<BR>\nChapter 05 리버스 엔지니어링<BR>\n5.1 리버스 엔지니어링의 이해<BR>\n5.2 리버스 엔지니어링 툴<BR>\n5.3 리버스 엔지니어링 공격<BR>\n5.4 리버스 엔지니어링 대응책<BR>\n요약<BR>\n연습문제 <BR>\n<BR>\nChapter 06 레이스 컨디션<BR>\n6.1 레이스 컨디션 공격의 이해<BR>\n6.2 레이스 컨디션 공격 대응책<BR>\n요약<BR>\n연습문제<BR>\n현장의 목소리<BR>\n<BR>\nChapter 07 버퍼 오버플로<BR>\n7.1 스택 버퍼 오버플로 공격<BR>\n7.2 힙 버퍼 오버플로 공격<BR>\n7.3 버퍼 오버플로 공격 대응책과 발전된 공격<BR>\n요약<BR>\n연습문제<BR>\n<BR>\nChapter 08 포맷 스트링<BR>\n8.1 포맷 스트링 공격<BR>\n8.2 포맷 스트링 공격 대응책 <BR>\n요약<BR>\n연습문제<BR>\n<BR>\nChapter 09 백도어<BR>\n9.1 백도어의 이해<BR>\n9.2 윈도우 백도어<BR>\n9.3 리눅스 백도어<BR>\n9.4 백도어 탐지 순서와 대응책<BR>\n요약<BR>\n연습문제<BR>\n현장의 목소리<BR>\n<BR>\n<B>Part 03 운영체제 보안</B><BR>\nChapter 10 윈도우 시스템 보안 설정(윈도우 서버 2016)<BR>\n10.1 계정 정책<BR>\n10.2 로컬 정책<BR>\n10.3 데몬 관리<BR>\n10.4 접근 제어<BR>\n10.5 파일과 디렉터리 관리<BR>\n10.6 기타 보안 관리<BR>\n요약<BR>\n연습문제<BR>\n<BR>\nChapter 11 ...<br/><br/><img src="http://www.aladin.co.kr/img/book/subject_t.gif" border="0" /><br/><a href=\'http://www.aladin.co.kr/home/wbookmain.aspx\' class=\'ml\'>국내도서</a>&nbsp;>&nbsp;<a href=\'http://www.aladin.co.kr/shop/wbrowse.aspx?CID=351\' class=\'ml\'>컴퓨터/모바일</a>&nbsp;>&nbsp;<a href=\'http://www.aladin.co.kr/shop/wbrowse.aspx?CID=363\' class=\'ml\'>OS/Networking</a>&nbsp;>&nbsp;<a href=\'http://www.aladin.co.kr/shop/wbrowse.aspx?CID=387&BrowseTarget=List\' class=\'ml\'><b>네트워크 보안/해킹</b></a ...
#   {'authors': [{'name': '알라딘', 'email': 'noSpam.rss@aladdin.co.kr'}],
#    'author': '알라딘 <noSpam.rss@aladdin.co.kr>',
#    'author_detail': {'name': '알라딘', 'email': 'noSpam.rss@aladdin.co.kr'},
#    'tags': [{'term': '국내도서>컴퓨터/모바일>활용능력>정보처리산업기사',
#      'scheme': None,
#      'label': None}],
#    'title': '2019 이기적 정보처리산업기사 필기 기본서 & 무료 동영상 (전강 제공)/최희준.조홍만.영진정보연구소 지음/영진.com(영진닷컴)',
#    'title_detail': {'type': 'text/plain',
#     'language': None,
#     'base': 'http://www.aladin.co.kr/rss/special_new/351',
#     'value': '2019 이기적 정보처리산업기사 필기 기본서 & 무료 동영상 (전강 제공)/최희준.조홍만.영진정보연구소 지음/영진.com(영진닷컴)'},
#    'links': [{'rel': 'alternate',
#      'type': 'text/html',
#      'href': 'http://www.aladin.co.kr/rsscenter/go.aspx?rssType=1&type=item&itemId=173733949'}],
#    'link': 'http://www.aladin.co.kr/rsscenter/go.aspx?rssType=1&type=item&itemId=173733949',
#    'published': 'Mon, 12 Nov 2018 11:05:00 +0900',
#    'published_parsed': time.struct_time(tm_year=2018, tm_mon=11, tm_mday=12, tm_hour=2, tm_min=5, tm_sec=0, tm_wday=0, tm_yday=316, tm_isdst=0),
#    'id': 'http://www.aladin.co.kr/shop/wproduct.aspx?itemID=173733949',
#    'guidislink': False,
# ...
#    'summary_detail': {'type': 'text/html',
#     'language': None,
#     'base': 'http://www.aladin.co.kr/rss/special_new/351',
#     'value': '<br/><table border=\'0\' cellpadding=\'0\' cellspacing=\'0\'><tr><td align=\'left\' valign=\'top\'><table cellspacing=\'1\' cellpadding=\'5\' border=\'0\' bgcolor=\'#dddddd\' style=\'margin-right:10px;\'><tbody><tr><td bgcolor=\'#ffffff\'><a href=\'http://www.aladin.co.kr/rsscenter/go.aspx?rssType=1&type=item&itemId=173350615\'><img src=\'https://image.aladin.co.kr/product/17335/6/cover/8927428404_1.jpg\' border=\'0\' /></a></td></tr></tbody></table><h2><a href=\'http://www.aladin.co.kr/rsscenter/go.aspx?rssType=1&type=item&itemId=173350615\'>2019 All Pass 정보처리기사필기</a></h2>김대영.전진오 지음 / 예문사 / 2019년 01월 / ISBN:<span class=\'isbn13\'>9788927428404</span><br/>정가: <span style=\'color:#FF0202\'>25,000</span>원 / 판매가: <span style=\'color:#FF0202\'>22,500</span>원 / 마일리지: <span style=\'color:#FF0202\'>112</span>원<br/><span style=\'color:#FF0202\'>이벤트</span>: 수험서.외국어.컴퓨터.전문서적 - 슬림 텀블러/핀버튼 에코백(택1)<br/><table border=\'0\' cellpadding=\'3\' cellspacing=\'0\' height=\'20\'><tr><td width=\'113\' align=\'left\'><a href=\'http://www.aladin.co.kr/rsscenter/go.aspx?type=basket&itemId=173350615&rssType=1\' target=\'_blank\'><img src=\'http://www.aladin.co.kr/img/rss/bu_basket.gif\' border=\'0\' alt=\'장바구니담기\'/></a></td><td width=\'101\' align=\'left\'><a href=\'http://www.aladin.co.kr/rsscenter/go.aspx?type=safebasket&itemId=173350615&rssType=1\' target=\'_blank\'><img src=\'http://www.aladin.co.kr/img/rss/bu_safebasket.gif\' border=\'0\' alt=\'보관함담기\'/></a></td><td width=\'83\' align=\'left\'></td><td width=\'113\' align=\'left\'></td></tr></table></td></tr><tr><td valign=\'top\' align=\'left\'><img src="http://www.aladin.co.kr/img/book/intro_t.gif" border="0" /><br/>NCS 기반 정보처리 자격시험에 대비하여 최적화된 정보를 제공하도록 구성하였다. 과목별 기출문제를 분석하여 출제 경향을 파악하고 새로운 문제 유형을 키워드 중심의 이론으로 전개하여 단편적 이론이 아닌 전체 맥락을 숙지하면서 공부할 수 있도록 하였다.<br/><br/><img src="http://www.aladin.co.kr/img/book/content_t.gif" border="0" /><br/><p>제1권 목차<BR>\n<BR>\n<B>PART 01\t데이터베이스</B><BR>\nCHAPTER\t01\t데이터베이스의 개념<BR>\nCHAPTER\t02\t데이터 모델링 및 설계<BR>\nCHAPTER\t03\t관계데이터베이스와 연산<BR>\nCHAPTER\t04\t관계데이터베이스 언어<BR>\nCHAPTER\t05\t데이터베이스의 고급기능<BR>\nCHAPTER\t06\t자료구조<BR>\n<BR>\n<B>PART 02\t전자계산기 구조<BR>\nCHAPTER\t01\t논리회로</B><BR>\nCHAPTER\t02\t자료의 표현<BR>\nCHAPTER\t03\t프로세서 및 명령어<BR>\nCHAPTER\t04\t명령 실행과 제어<BR>\nCHAPTER\t05\t기억장치<BR>\nCHAPTER\t06\t입출력장치, 인터럽트<BR>\nCHAPTER\t07\t병렬 및 고성능 컴퓨터<BR>\n<BR>\n<B>PART 03\t운영체제</B><BR>\nCHAPTERCHAPTER\t01\t운영체제의 개요<BR>\nCHAPTER\t02\t프로세스(Process) 관리<BR>\nCHAPTER\t03\t기억장치 관리<BR>\nCHAPTER\t04\t파일 관리<BR>\nCHAPTER\t05\t분산 운영체제<BR>\nCHAPTER\t06\t운영체제의 실제<BR>\n<BR>\n제2권 목차<BR>\n<BR>\n<B>PART 04\t소프트웨어 공학</B><BR>\nCHAPTER\t01\t소프트웨어 공학의 개념<BR>\nCHAPTER\t02\t소프트웨어 프로젝트 관리<BR>\nCHAPTER\t03\t전통적 S/W 개발 방법론<BR>\nCHAPTER\t04\t객체지향 S/W 공학<BR>\nCHAPTER\t05\tS/W 공학의 발전적 추세<BR>\n<BR>\n<B>PART 05\t데이터 통신</B><BR>\nCHAPTER\t01\t데이터 통신 시스템<BR>\nCHAPTER\t02\t데이터 전송이론<BR>\nCHAPTER\t03\t전송 제어방식<BR>\nCHAPTER\t04\t네트워크<BR>\nCHAPTER\t05\t통신 프로토콜<BR>\n<BR>\n<B>PART 06\t기출문제</B><BR>\n2017년 1회 기사\t<BR>\n2017년 2회 기사\t<BR>\n2017년 3회 기사\t<BR>\n2018년 1회 기사\t<BR>\n2018년 2회 기사\t<BR>\n2018년 3회 기사\t</p><br/><br/><img src="http://www.aladin.co.kr/img/book/subject_t.gif" border="0" /><br/><a href=\'http://www.aladin.co.kr/home/wbookmain.aspx\' class=\'ml\'>국내도서</a>&nbsp;>&nbsp;<a href=\'http://www.aladin.co.kr/shop/wbrowse.aspx?CID=351\' class=\'ml\'>컴퓨터/모바일</a>&nbsp;>&nbsp;<a href=\'http://www.aladin.co.kr/shop/wbrowse.aspx?CID=479\' class=\'ml\'>활용능력</a>&nbsp;>&nbsp;<a href=\'http://www.aladin.co.kr/shop/wbrowse.aspx?CID=7012&BrowseTarget=List\' class=\'ml\'><b>정보처리기사</b></a><br/><a href=\'http://www.aladin.co.kr/home/wbookmain.aspx\' class=\'ml\'>국내도서</a>&nbsp;>&nbsp;<a href=\'http://www.aladin.co.kr/shop/wbrowse.aspx?CID=1383\' class=\'ml\'>수험서/자격증</a>&nbsp;>&nbsp;<a href=\'http://www.aladin.co.kr/shop/wbrowse.aspx?CID=35777\' class=\'ml\'>컴퓨터 활용능력</a>&nbsp;>&nbsp;<a href=\'http://www.aladin.co.kr/shop/wbrowse.aspx?CID=36892\' class=\'ml\'>정보처리</a>&nbsp;>&nbsp;<a href=\'http://www.aladin.co.kr ...
#   {'authors': [{'name': '알라딘', 'email': 'noSpam.rss@aladdin.co.kr'}],
#    'author': '알라딘 <noSpam.rss@aladdin.co.kr>',
#    'author_detail': {'name': '알라딘', 'email': 'noSpam.rss@aladdin.co.kr'},
#    'tags': [{'term': '국내도서>컴퓨터/모바일>활용능력>신규 자격증/자격증 기타',
#      'scheme': None,
#      'label': None}],
#    'title': '2019 전자캐드기능사 필기/문제연구회 지음/엔플북스',
#    'title_detail': {'type': 'text/plain',
#     'language': None,
#     'base': 'http://www.aladin.co.kr/rss/special_new/351',
#     'value': '2019 전자캐드기능사 필기/문제연구회 지음/엔플북스'},
#    'links': [{'rel': 'alternate',
#      'type': 'text/html',
#      'href': 'http://www.aladin.co.kr/rsscenter/go.aspx?rssType=1&type=item&itemId=173346463'}],
#    'link': 'http://www.aladin.co.kr/rsscenter/go.aspx?rssType=1&type=item&itemId=173346463',
#    'published': 'Wed, 07 Nov 2018 09:20:00 +0900',
#    'published_parsed': time.struct_time(tm_year=2018, tm_mon=11, tm_mday=7, tm_hour=0, tm_min=20, tm_sec=0, tm_wday=2, tm_yday=311, tm_isdst=0),
#    'id': 'http://www.aladin.co.kr/shop/wproduct.aspx?itemID=173346463',
#    'guidislink': False,
#    'summary': '<br/><table border=\'0\' cellpadding=\'0\' cellspacing=\'0\'><tr><td align=\'left\' valign=\'top\'><table cellspacing=\'1\' cellpadding=\'5\' border=\'0\' bgcolor=\'#dddddd\' style=\'margin-right:10px;\'><tbody><tr><td bgcolor=\'#ffffff\'><a href=\'http://www.aladin.co.kr/rsscenter/go.aspx?rssType=1&type=item&itemId=173346463\'><img src=\'https://image.aladin.co.kr/product/17334/64/cover/8968132488_1.jpg\' border=\'0\' /></a></td></tr></tbody></table><h2><a href=\'http://www.aladin.co.kr/rsscenter/go.aspx?rssType=1&type=item&itemId=173346463\'>2019 전자캐드기능사 필기</a></h2>문제연구회 지음 / 엔플북스 / 2019년 01월 / ISBN:<span class=\'isbn13\'>9788968132483</span><br/>정가: <span style=\'color:#FF0202\'>27,000</span>원 / 판매가: <span style=\'color:#FF0202\'>24,300</span>원 / 마일리지: <span style=\'color:#FF0202\'>111</span>원<br/><span style=\'color:#FF0202\'>이벤트</span>: 수험서.외국어.컴퓨터.전문서적 - 슬림 텀블러/핀버튼 에코백(택1)<br/><table border=\'0\' cellpadding=\'3\' cellspacing=\'0\' height=\'20\'><tr><td width=\'113\' align=\'left\'><a href=\'http://www.aladin.co.kr/rsscenter/go.aspx?type=basket&itemId=173346463&rssType=1\' target=\'_blank\'><img src=\'http://www.aladin.co.kr/img/rss/bu_basket.gif\' border=\'0\' alt=\'장바구니담기\'/></a></td><td width=\'101\' align=\'left\'><a href=\'http://www.aladin.co.kr/rsscenter/go.aspx?type=safebasket&itemId=173346463&rssType=1\' target=\'_blank\'><img src=\'http://www.aladin.co.kr/img/rss/bu_safebasket.gif\' border=\'0\' alt=\'보관함담기\'/></a></td><td width=\'83\' align=\'left\'></td><td width=\'113\' align=\'left\'></td></tr></table></td></tr><tr><td valign=\'top\' align=\'left\'><img src="http://www.aladin.co.kr/img/book/intro_t.gif" border="0" /><br/>전자 CAD는 단순한 설계가 아니라 설계된 회로의 오류검사와 인쇄회로기판의 배선과 그에 따른 오류의 검사 등의 작업을 수행할 수 있어, 전자산업분야에서는 기업의 경쟁력 향상과 기술력의 향상에 필요한 분야로 대두되고 있다. 따라서 전자 CAD 분야의 유능한 기능 인력의 양성을 위한 국가기술 자격이 필요하게 되어 전자캐드기능사 자격시험이 시행되게 되었다.<br/><br/><img src="http://www.aladin.co.kr/img/book/content_t.gif" border="0" /><br/><p><B>제1장 전기/전자공학</B><BR>\n  \t1. 직류 회로 <BR>\n  \t2. 전력과 열작용 <BR>\n  \t3. 축전지 및 전지의 접속 <BR>\n  \t4. 교류 회로 <BR>\n  \t5. 자기 현상 <BR>\n  \t6. 반도체(Semiconductor) <BR>\n  \t7. 정류 회로<BR>\n\t8. 증폭 회로 <BR>\n  \t9. 발진 회로(Oscillator) <BR>\n  \t10. 변복조회로 <BR>\n  \t11. 디지털 회로(Digital Circuit) <BR>\n  \t* 예상문제 <BR>\n<BR>\n<B>제2장 전자계산기 일반</B><BR>\n  \t1. 전자계산기 일반 <BR>\n  \t2. 자료의 표현과 연산 <BR>\n  \t3. 소프트웨어의 개념과 종류 <BR>\n  \t4. 마이크로프로세서의 구조와 기능<BR>\n  \t5. 명령 형식 <BR>\n  \t6. DATA 형식 <BR>\n  \t7. 주소 지정 방식(addressing mode) <BR>\n  \t8. 서브루틴(subroutine)과 스택(stack) <BR>\n\t9. 운영체제와 기본 소프트웨어<BR>\n  \t* 예상문제 <BR>\n<BR>\n<B>제3장 전자캐드 일반</B><BR>\n  \t1. 제도규약 <BR>\n\t2. 도면의 표시방법 <BR>\n\t3. 전자설계도면의 디자인 구조 <BR>\n\t4. 인쇄회로기판(PCB)의 제작 공정 <BR>\n\t5. CAD 일반 <BR>\n\t* 예상문제 <BR>\n<BR>\n부  록 과년도 문제 수록 및 상세 해설(2011~2016)<BR>\n부  록 CBT 대비 모의고사<BR>\n부  록 CBT 대비 모의고사 정답 및 해설</p><br/><br/><img src="http://www.aladin.co.kr/img/book/subject_t.gif" border="0" /><br/><a href=\'http://www.aladin.co.kr/home/wbookmain.aspx\' class=\'ml\'>국내도서</a>&nbsp;>&nbsp;<a href=\'http://www.aladin.co.kr/shop/wbrowse.aspx?CID=351\' class=\'ml\'>컴퓨터/모바일</a>&nbsp;>&nbsp;<a href=\'http://www.aladin.co.kr/shop/wbrowse.aspx?CID=2630\' class=\'ml\'>그래픽/멀티미디어</a>&nbsp;>&nbsp;<a href=\'http://www.aladin.co.kr/shop/wbrowse.aspx?CID=2648&BrowseTarget=List\' class=\'ml\'><b>CAD</b></a><br/><a href=\'http://www.aladin.co.kr/home/wbookmain.aspx\' class=\'ml\'>국내도서</a>&nbsp;>&nbsp;<a href=\'http://www.aladin.co.kr/shop/wbrowse.aspx?CID=351\' class=\'ml\'>컴퓨터/모바일</a>&nbsp;>&nbsp;<a href=\'http://www.aladin.co.kr/shop/wbrowse.aspx?CID=479\' class=\'ml\'>활용능력</a>&nbsp;>&nbsp;<a href=\'http://www.aladin.co.kr/shop/wbrowse.aspx?CID=2836&BrowseTarget=List\' class=\'ml\'><b>신규 자격증/자격증 기타</b></a><br/><a href=\'http://www.aladin.co.kr/home/wbookmain.aspx\' class=\'ml\'>국내도서</a>&nbsp;>&nbsp;<a href=\'http://www.aladin.co.kr/shop/wbrowse.aspx?CID=1383\' class=\'ml\'>수험서/자격증</a>&nbsp;>&nbsp;<a href=\'http://www.aladin.co.kr/shop/wbrowse.aspx?CID=35777\' class=\'ml\'>컴퓨터 활용능력</a>&nbsp ...
#    'summary_detail': {'type': 'text/html',
#     'language': None,
#     'base': 'http://www.aladin.co.kr/rss/special_new/351',
#     'value': '<br/><table border=\'0\' cellpadding=\'0\' cellspacing=\'0\'><tr><td align=\'left\' valign=\'top\'><table cellspacing=\'1\' cellpadding=\'5\' border=\'0\' bgcolor=\'#dddddd\' style=\'margin-right:10px;\'><tbody><tr><td bgcolor=\'#ffffff\'><a href=\'http://www.aladin.co.kr/rsscenter/go.aspx?rssType=1&type=item&itemId=173346463\'><img src=\'https://image.aladin.co.kr/product/17334/64/cover/8968132488_1.jpg\' border=\'0\' /></a></td></tr></tbody></table><h2><a href=\'http://www.aladin.co.kr/rsscenter/go.aspx?rssType=1&type=item&itemId=173346463\'>2019 전자캐드기능사 필기</a></h2>문제연구회 지음 / 엔플북스 / 2019년 01월 / ISBN:<span class=\'isbn13\'>9788968132483</span><br/>정가: <span style=\'color:#FF0202\'>27,000</span>원 / 판매가: <span style=\'color:#FF0202\'>24,300</span>원 / 마일리지: <span style=\'color:#FF0202\'>111</span>원<br/><span style=\'color:#FF0202\'>이벤트</span>: 수험서.외국어.컴퓨터.전문서적 - 슬림 텀블러/핀버튼 에코백(택1)<br/><table border=\'0\' cellpadding=\'3\' cellspacing=\'0\' height=\'20\'><tr><td width=\'113\' align=\'left\'><a href=\'http://www.aladin.co.kr/rsscenter/go.aspx?type=basket&itemId=173346463&rssType=1\' target=\'_blank\'><img src=\'http://www.aladin.co.kr/img/rss/bu_basket.gif\' border=\'0\' alt=\'장바구니담기\'/></a></td><td width=\'101\' align=\'left\'><a href=\'http://www.aladin.co.kr/rsscenter/go.aspx?type=safebasket&itemId=173346463&rssType=1\' target=\'_blank\'><img src=\'http://www.aladin.co.kr/img/rss/bu_safebasket.gif\' border=\'0\' alt=\'보관함담기\'/></a></td><td width=\'83\' align=\'left\'></td><td width=\'113\' align=\'left\'></td></tr></table></td></tr><tr><td valign=\'top\' align=\'left\'><img src="http://www.aladin.co.kr/img/book/intro_t.gif" border="0" /><br/>전자 CAD는 단순한 설계가 아니라 설계된 회로의 오류검사와 인쇄회로기판의 배선과 그에 따른 오류의 검사 등의 작업을 수행할 수 있어, 전자산업분야에서는 기업의 경쟁력 향상과 기술력의 향상에 필요한 분야로 대두되고 있다. 따라서 전자 CAD 분야의 유능한 기능 인력의 양성을 위한 국가기술 자격이 필요하게 되어 전자캐드기능사 자격시험이 시행되게 되었다.<br/><br/><img src="http://www.aladin.co.kr/img/book/content_t.gif" border="0" /><br/><p><B>제1장 전기/전자공학</B><BR>\n  \t1. 직류 회로 <BR>\n  \t2. 전력과 열작용 <BR>\n  \t3. 축전지 및 전지의 접속 <BR>\n  \t4. 교류 회로 <BR>\n  \t5. 자기 현상 <BR>\n  \t6. 반도체(Semiconductor) <BR>\n  \t7. 정류 회로<BR>\n\t8. 증폭 회로 <BR>\n  \t9. 발진 회로(Oscillator) <BR>\n  \t10. 변복조회로 <BR>\n  \t11. 디지털 회로(Digital Circuit) <BR>\n  \t* 예상문제 <BR>\n<BR>\n<B>제2장 전자계산기 일반</B><BR>\n  \t1. 전자계산기 일반 <BR>\n  \t2. 자료의 표현과 연산 <BR>\n  \t3. 소프트웨어의 개념과 종류 <BR>\n  \t4. 마이크로프로세서의 구조와 기능<BR>\n  \t5. 명령 형식 <BR>\n  \t6. DATA 형식 <BR>\n  \t7. 주소 지정 방식(addressing mode) <BR>\n  \t8. 서브루틴(subroutine)과 스택(stack) <BR>\n\t9. 운영체제와 기본 소프트웨어<BR>\n  \t* 예상문제 <BR>\n<BR>\n<B>제3장 전자캐드 일반</B><BR>\n  \t1. 제도규약 <BR>\n\t2. 도면의 표시방법 <BR>\n\t3. 전자설계도면의 디자인 구조 <BR>\n\t4. 인쇄회로기판(PCB)의 제작 공정 <BR>\n\t5. CAD 일반 <BR>\n\t* 예상문제 <BR>\n<BR>\n부  록 과년도 문제 수록 및 상세 해설(2011~2016)<BR>\n부  록 CBT 대비 모의고사<BR>\n부  록 CBT 대비 모의고사 정답 및 해설</p><br/><br/><img src="http://www.aladin.co.kr/img/book/subject_t.gif" border="0" /><br/><a href=\'http://www.aladin.co.kr/home/wbookmain.aspx\' class=\'ml\'>국내도서</a>&nbsp;>&nbsp;<a href=\'http://www.aladin.co.kr/shop/wbrowse.aspx?CID=351\' class=\'ml\'>컴퓨터/모바일</a>&nbsp;>&nbsp;<a href=\'http://www.aladin.co.kr/shop/wbrowse.aspx?CID=2630\' class=\'ml\'>그래픽/멀티미디어</a>&nbsp;>&nbsp;<a href=\'http://www.aladin.co.kr/shop/wbrowse.aspx?CID=2648&BrowseTarget=List\' class=\'ml\'><b>CAD</b></a><br/><a href=\'http://www.aladin.co.kr/home/wbookmain.aspx\' class=\'ml\'>국내도서</a>&nbsp;>&nbsp;<a href=\'http://www.aladin.co.kr/shop/wbrowse.aspx?CID=351\' class=\'ml\'>컴퓨터/모바일</a>&nbsp;>&nbsp;<a href=\'http://www.aladin.co.kr/shop/wbrowse.aspx?CID=479\' class=\'ml\'>활용능력</a>&nbsp;>&nbsp;<a href=\'http://www.aladin.co.kr/shop/wbrowse.aspx?CID=2836&BrowseTarget=List\' class=\'ml\'><b>신규 자격증/자격증 기타</b></a><br/><a href=\'http://www.aladin.co.kr/home/wbookmain.aspx\' class=\'ml\'>국내도서</a>&nbsp;>&nbsp;<a href=\'http://www.aladin.co.kr/shop/wbrowse.aspx?CID=1383\' class=\'ml\'>수험서/자격증</a>&nbsp;>&nbsp;<a href=\'http://www.aladin.co.kr/shop/wbrowse.aspx?CID=35777\' class=\'ml\'>컴퓨터 활용능력</a>&nbsp; ...
#  'bozo': 0,
#  'headers': {'Cache-Control': 'private',
#   'Content-Type': 'text/xml; charset=utf-8',
#   'Content-Encoding': 'gzip',
#   'Last-Modified': 'Tue, 13 Nov 2018 22:01:39 GMT',
#   'ETag': '288-a45c-75c6-29',
#   'Vary': 'Accept-Encoding',
#   'Server': 'Microsoft-IIS/7.5',
#   'Set-Cookie': 'AladdinUS=ZKrK%2boUzjBg%3d&USA=1; domain=aladin.co.kr; expires=Sun, 14-Nov-2038 00:50:52 GMT; path=/',
#   'X-Powered-By': 'ASP.NET',
#   'P3P': "CP='CAO PSA CONi OTR OUR DEM ONL'",
#   'Date': 'Wed, 14 Nov 2018 00:50:52 GMT',
#   'Connection': 'close',
#   'Content-Length': '36818'},
#  'etag': '288-a45c-75c6-29',
#  'updated': 'Tue, 13 Nov 2018 22:01:39 GMT',
#  'updated_parsed': time.struct_time(tm_year=2018, tm_mon=11, tm_mday=13, tm_hour=22, tm_min=1, tm_sec=39, tm_wday=1, tm_yday=317, tm_isdst=0),
#  'href': 'http://www.aladin.co.kr/rss/special_new/351',
#  'status': 200,
#  'encoding': 'utf-8',
#  'version': 'rss20',
#  'namespaces': {}}

# %%
entry = d.entries[0]
entry
# Out:
# {'authors': [{'name': '알라딘', 'email': 'noSpam.rss@aladdin.co.kr'}],
#  'author': '알라딘 <noSpam.rss@aladdin.co.kr>',
#  'author_detail': {'name': '알라딘', 'email': 'noSpam.rss@aladdin.co.kr'},
#  'tags': [{'term': '국내도서>컴퓨터/모바일>프로그래밍 언어>파이썬',
#    'scheme': None,
#    'label': None}],
#  'title': '마인크래프트와 함께 즐겁게 파이썬/최일선 지음/비제이퍼블릭',
#  'title_detail': {'type': 'text/plain',
#   'language': None,
#   'base': 'http://www.aladin.co.kr/rss/special_new/351',
#   'value': '마인크래프트와 함께 즐겁게 파이썬/최일선 지음/비제이퍼블릭'},
#  'links': [{'rel': 'alternate',
#    'type': 'text/html',
#    'href': 'http://www.aladin.co.kr/rsscenter/go.aspx?rssType=1&type=item&itemId=173766231'}],
#  'link': 'http://www.aladin.co.kr/rsscenter/go.aspx?rssType=1&type=item&itemId=173766231',
#  'published': 'Mon, 12 Nov 2018 17:35:00 +0900',
#  'published_parsed': time.struct_time(tm_year=2018, tm_mon=11, tm_mday=12, tm_hour=8, tm_min=35, tm_sec=0, tm_wday=0, tm_yday=316, tm_isdst=0),
#  'id': 'http://www.aladin.co.kr/shop/wproduct.aspx?itemID=173766231',
#  'guidislink': False,
#  'summary': '<br/><table border=\'0\' cellpadding=\'0\' cellspacing=\'0\'><tr><td align=\'left\' valign=\'top\'><table cellspacing=\'1\' cellpadding=\'5\' border=\'0\' bgcolor=\'#dddddd\' style=\'margin-right:10px;\'><tbody><tr><td bgcolor=\'#ffffff\'><a href=\'http://www.aladin.co.kr/rsscenter/go.aspx?rssType=1&type=item&itemId=173766231\'><img src=\'https://image.aladin.co.kr/product/17376/62/cover/k492534698_1.jpg\' border=\'0\' /></a></td></tr></tbody></table><h2><a href=\'http://www.aladin.co.kr/rsscenter/go.aspx?rssType=1&type=item&itemId=173766231\'>마인크래프트와 함께 즐겁게 파이썬</a></h2>최일선 지음 / 비제이퍼블릭 / 2018년 11월 / ISBN:<span class=\'isbn13\'>9791186697733</span><br/>정가: <span style=\'color:#FF0202\'>26,000</span>원 / 판매가: <span style=\'color:#FF0202\'>23,400</span>원 / 마일리지: <span style=\'color:#FF0202\'>94</span>원<br/><span style=\'color:#FF0202\'>이벤트</span>: 수험서.외국어.컴퓨터.전문서적 - 슬림 텀블러/핀버튼 에코백(택1)<br/><table border=\'0\' cellpadding=\'3\' cellspacing=\'0\' height=\'20\'><tr><td width=\'113\' align=\'left\'><a href=\'http://www.aladin.co.kr/rsscenter/go.aspx?type=basket&itemId=173766231&rssType=1\' target=\'_blank\'><img src=\'http://www.aladin.co.kr/img/rss/bu_basket.gif\' border=\'0\' alt=\'장바구니담기\'/></a></td><td width=\'101\' align=\'left\'><a href=\'http://www.aladin.co.kr/rsscenter/go.aspx?type=safebasket&itemId=173766231&rssType=1\' target=\'_blank\'><img src=\'http://www.aladin.co.kr/img/rss/bu_safebasket.gif\' border=\'0\' alt=\'보관함담기\'/></a></td><td width=\'83\' align=\'left\'></td><td width=\'113\' align=\'left\'></td></tr></table></td></tr><tr><td valign=\'top\' align=\'left\'><img src="http://www.aladin.co.kr/img/book/intro_t.gif" border="0" /><br/>게임을 하면서 코딩도 배우는 일석이조의 경험을 제공한다. 실제 업무에서 사용하는 파이썬을 초등학생 때부터 공부할 수 있다. 파이썬은 전 세계적으로 가장 많이 쓰이는 프로그래밍 언어 중 하나이면서 초등학생도 익힐 수 있는 쉬운 문법을 지니고 있다.<br/><br/><img src="http://www.aladin.co.kr/img/book/content_t.gif" border="0" /><br/><p>1장 마인크래프트 만나기<BR>\n<BR>\n1-1 마인크래프트와 파이썬의 만남<BR>\n<BR>\n1-2 마인크래프트 설치하기<BR>\n<BR>\n1-3 마인크래프트 1.12.1 서버 설치하기<BR>\n<BR>\n1-4 서버설정<BR>\n<BR>\n1-5 파이썬과 MCPI 설치하기<BR>\n<BR>\n1-6 헬로, 마인크래프트!<BR>\n<BR>\n1-7 멀티플레이로 MCPI 즐기기<BR>\n<BR>\n1-8 게임 접속하기<BR>\n<BR>\n1-9 게임 인터페이스<BR>\n<BR>\n1-10 게임 단축키<BR>\n<BR>\n1-11 아이템 조합 튜토리얼<BR>\n<BR>\n1-12 첫날밤 생존 계획<BR>\n<BR>\n1-13 꼭 알아야 하는 마인크래프트 명령어<BR>\n<BR>\n <BR>\n<BR>\n2장 파이썬 시작하기<BR>\n<BR>\n           2-1 헬로, 파이썬!<BR>\n<BR>\n           2-2 파이썬, 덧셈과 뺄셈을 부탁해!<BR>\n<BR>\n           2-3 간단한 계산기 프로그램 만들기<BR>\n<BR>\n <BR>\n<BR>\n3장 마인크래프트 파이썬 입문<BR>\n<BR>\n           3-1 postToChat:파이썬으로 마인크래프트에 외치다!<BR>\n<BR>\n           3-2 getPos:플레이어 위치 조회 서비스<BR>\n<BR>\n           3-3 setPos:플레이어 위치 변경 서비스<BR>\n<BR>\n           3-4 setBlock:블록 생성하기<BR>\n<BR>\n           3-5 setBlocks:블록 여러 개 생성하기<BR>\n<BR>\n           3-6 getBlock:블록 데이터 얻기<BR>\n<BR>\n3-7 getBlockWithData:블록 데이터 얻기<BR>\n<BR>\n3-8 정리<BR>\n<BR>\n <BR>\n<BR>\n4장 초급 텔레포트<BR>\n<BR>\n           4-1 더하기 함수 만들기<BR>\n<BR>\n           4-2 위치 보정 함수 만들기<BR>\n<BR>\n           4-3 집으로 텔레포트 함수 만들기<BR>\n<BR>\n           4-4 단거리 이동 텔레포트<BR>\n<BR>\n           4-5 타이밍 텔레포트<BR>\n<BR>\n           4-6 마인크래프트 건축물 일일투어!<BR>\n<BR>\n <BR>\n<BR>\n5장 고급 텔레포트<BR>\n<BR>\n           5-1 반복 작업 자동화를 위한 list<BR>\n<BR>\n           5-2 반복 작업 자동화를 위한 for문<BR>\n<BR>\n           5-3 자동 텔레포트<BR>\n<BR>\n           5-4 If를 활용한 제어:만약에<BR>\n<BR>\n           5-5 while문을 사용한 반복 작업 수행하기<BR>\n<BR>\n           5-6 집으로 가는 워프 만들기<BR>\n<BR>\n           5-7 감옥 만들기<BR>\n<BR>\n5-8 지하 탈출 텔레포트<BR>\n<BR>\n5-9 자석 텔레포트:다른 모든 플레이어 소환하기<BR>\n<BR>\n <...<br/><br/><img src="http://www.aladin.co.kr/img/book/subject_t.gif" border="0" /><br/><a href=\'http://www.aladin.co.kr/home/wbookmain.aspx\' class=\'ml\'>국내도서</a>&nbsp;>&nbsp;<a href=\'http://www.aladin.co.kr/shop/wbrowse.aspx?CID=351\' class=\'ml\'>컴퓨터/모바일</a>&nbsp;>&nbsp;<a href=\'http://www.aladin.co.kr/shop/wbrowse.aspx?CID=2613\' class=\'ml\'>PC/게임/디지털 카메라</a>&nbsp;>&nbsp;<a href=\'http://www.aladin.co.kr/shop/wbrowse.aspx?CID=6346&BrowseTarget=List\' class=\'ml\'><b>게임</b></a><br/> ...
#  'summary_detail': {'type': 'text/html',
#   'language': None,
#   'base': 'http://www.aladin.co.kr/rss/special_new/351',
#   'value': '<br/><table border=\'0\' cellpadding=\'0\' cellspacing=\'0\'><tr><td align=\'left\' valign=\'top\'><table cellspacing=\'1\' cellpadding=\'5\' border=\'0\' bgcolor=\'#dddddd\' style=\'margin-right:10px;\'><tbody><tr><td bgcolor=\'#ffffff\'><a href=\'http://www.aladin.co.kr/rsscenter/go.aspx?rssType=1&type=item&itemId=173766231\'><img src=\'https://image.aladin.co.kr/product/17376/62/cover/k492534698_1.jpg\' border=\'0\' /></a></td></tr></tbody></table><h2><a href=\'http://www.aladin.co.kr/rsscenter/go.aspx?rssType=1&type=item&itemId=173766231\'>마인크래프트와 함께 즐겁게 파이썬</a></h2>최일선 지음 / 비제이퍼블릭 / 2018년 11월 / ISBN:<span class=\'isbn13\'>9791186697733</span><br/>정가: <span style=\'color:#FF0202\'>26,000</span>원 / 판매가: <span style=\'color:#FF0202\'>23,400</span>원 / 마일리지: <span style=\'color:#FF0202\'>94</span>원<br/><span style=\'color:#FF0202\'>이벤트</span>: 수험서.외국어.컴퓨터.전문서적 - 슬림 텀블러/핀버튼 에코백(택1)<br/><table border=\'0\' cellpadding=\'3\' cellspacing=\'0\' height=\'20\'><tr><td width=\'113\' align=\'left\'><a href=\'http://www.aladin.co.kr/rsscenter/go.aspx?type=basket&itemId=173766231&rssType=1\' target=\'_blank\'><img src=\'http://www.aladin.co.kr/img/rss/bu_basket.gif\' border=\'0\' alt=\'장바구니담기\'/></a></td><td width=\'101\' align=\'left\'><a href=\'http://www.aladin.co.kr/rsscenter/go.aspx?type=safebasket&itemId=173766231&rssType=1\' target=\'_blank\'><img src=\'http://www.aladin.co.kr/img/rss/bu_safebasket.gif\' border=\'0\' alt=\'보관함담기\'/></a></td><td width=\'83\' align=\'left\'></td><td width=\'113\' align=\'left\'></td></tr></table></td></tr><tr><td valign=\'top\' align=\'left\'><img src="http://www.aladin.co.kr/img/book/intro_t.gif" border="0" /><br/>게임을 하면서 코딩도 배우는 일석이조의 경험을 제공한다. 실제 업무에서 사용하는 파이썬을 초등학생 때부터 공부할 수 있다. 파이썬은 전 세계적으로 가장 많이 쓰이는 프로그래밍 언어 중 하나이면서 초등학생도 익힐 수 있는 쉬운 문법을 지니고 있다.<br/><br/><img src="http://www.aladin.co.kr/img/book/content_t.gif" border="0" /><br/><p>1장 마인크래프트 만나기<BR>\n<BR>\n1-1 마인크래프트와 파이썬의 만남<BR>\n<BR>\n1-2 마인크래프트 설치하기<BR>\n<BR>\n1-3 마인크래프트 1.12.1 서버 설치하기<BR>\n<BR>\n1-4 서버설정<BR>\n<BR>\n1-5 파이썬과 MCPI 설치하기<BR>\n<BR>\n1-6 헬로, 마인크래프트!<BR>\n<BR>\n1-7 멀티플레이로 MCPI 즐기기<BR>\n<BR>\n1-8 게임 접속하기<BR>\n<BR>\n1-9 게임 인터페이스<BR>\n<BR>\n1-10 게임 단축키<BR>\n<BR>\n1-11 아이템 조합 튜토리얼<BR>\n<BR>\n1-12 첫날밤 생존 계획<BR>\n<BR>\n1-13 꼭 알아야 하는 마인크래프트 명령어<BR>\n<BR>\n <BR>\n<BR>\n2장 파이썬 시작하기<BR>\n<BR>\n           2-1 헬로, 파이썬!<BR>\n<BR>\n           2-2 파이썬, 덧셈과 뺄셈을 부탁해!<BR>\n<BR>\n           2-3 간단한 계산기 프로그램 만들기<BR>\n<BR>\n <BR>\n<BR>\n3장 마인크래프트 파이썬 입문<BR>\n<BR>\n           3-1 postToChat:파이썬으로 마인크래프트에 외치다!<BR>\n<BR>\n           3-2 getPos:플레이어 위치 조회 서비스<BR>\n<BR>\n           3-3 setPos:플레이어 위치 변경 서비스<BR>\n<BR>\n           3-4 setBlock:블록 생성하기<BR>\n<BR>\n           3-5 setBlocks:블록 여러 개 생성하기<BR>\n<BR>\n           3-6 getBlock:블록 데이터 얻기<BR>\n<BR>\n3-7 getBlockWithData:블록 데이터 얻기<BR>\n<BR>\n3-8 정리<BR>\n<BR>\n <BR>\n<BR>\n4장 초급 텔레포트<BR>\n<BR>\n           4-1 더하기 함수 만들기<BR>\n<BR>\n           4-2 위치 보정 함수 만들기<BR>\n<BR>\n           4-3 집으로 텔레포트 함수 만들기<BR>\n<BR>\n           4-4 단거리 이동 텔레포트<BR>\n<BR>\n           4-5 타이밍 텔레포트<BR>\n<BR>\n           4-6 마인크래프트 건축물 일일투어!<BR>\n<BR>\n <BR>\n<BR>\n5장 고급 텔레포트<BR>\n<BR>\n           5-1 반복 작업 자동화를 위한 list<BR>\n<BR>\n           5-2 반복 작업 자동화를 위한 for문<BR>\n<BR>\n           5-3 자동 텔레포트<BR>\n<BR>\n           5-4 If를 활용한 제어:만약에<BR>\n<BR>\n           5-5 while문을 사용한 반복 작업 수행하기<BR>\n<BR>\n           5-6 집으로 가는 워프 만들기<BR>\n<BR>\n           5-7 감옥 만들기<BR>\n<BR>\n5-8 지하 탈출 텔레포트<BR>\n<BR>\n5-9 자석 텔레포트:다른 모든 플레이어 소환하기<BR>\n<BR>\n <...<br/><br/><img src="http://www.aladin.co.kr/img/book/subject_t.gif" border="0" /><br/><a href=\'http://www.aladin.co.kr/home/wbookmain.aspx\' class=\'ml\'>국내도서</a>&nbsp;>&nbsp;<a href=\'http://www.aladin.co.kr/shop/wbrowse.aspx?CID=351\' class=\'ml\'>컴퓨터/모바일</a>&nbsp;>&nbsp;<a href=\'http://www.aladin.co.kr/shop/wbrowse.aspx?CID=2613\' class=\'ml\'>PC/게임/디지털 카메라</a>&nbsp;>&nbsp;<a href=\'http://www.aladin.co.kr/shop/wbrowse.aspx?CID=6346&BrowseTarget=List\' class=\'ml\'><b>게임</b></a><br/>< ...

# %%
entry.keys()
# Out:
# dict_keys(['authors', 'author', 'author_detail', 'tags', 'title', 'title_detail', 'links', 'link', 'published', 'published_parsed', 'id', 'guidislink', 'summary', 'summary_detail'])

# %%
entry.title
# Out:
# '마인크래프트와 함께 즐겁게 파이썬/최일선 지음/비제이퍼블릭'

# %%
entry.link
# Out:
# 'http://www.aladin.co.kr/rsscenter/go.aspx?rssType=1&type=item&itemId=173766231'

# %%
entry.tags
# Out:
# [{'term': '국내도서>컴퓨터/모바일>프로그래밍 언어>파이썬', 'scheme': None, 'label': None}]

# %%
entry.tags[0]['term']
# Out:
# '국내도서>컴퓨터/모바일>프로그래밍 언어>파이썬'

# %% [markdown]
# ## 데이터베이스에 저장
# > - MySQL
# - MongoDB

# %% [markdown]
# **c3-04_save_mysql **
# > MySQL에 저장
#
# > - SQLite와 달리 클리이언트/서버형 아키텍처 채용
# - 즉, connection 객체 생성할 때, 사용자계정정보(ID/PW) 정보가 필요하다

# %% [raw]
# import MySQLdb
#
# # MySQL 서버에 접속하고 연결을 변수에 저장합니다.
# # 사용자 이름과 비밀번호를 지정한 뒤 scraping 데이터베이스를 사용(USE)합니다.
# # 접속에 사용할 문자 코드는 utf8mb4로 지정합니다.
# conn = MySQLdb.connect(db='scraping', user='scraper', passwd='password', charset='utf8mb4')
#
# # 커서를 추출합니다.
# c = conn.cursor()
#
# # execute() 메서드로 SQL 구문을 실행합니다.
# # 스크립트를 여러 번 사용해도 같은 결과를 출력할 수 있게 cities 테이블이 존재하는 경우 제거합니다.
# c.execute('DROP TABLE IF EXISTS cities')
#
# # cities 테이블을 생성합니다.
# c.execute('''
#     CREATE TABLE cities (
#         rank integer,
#         city text,
#         population integer
#     )
# ''')
#
# # execute() 메서드의 두 번째 매개변수에는 파라미터를 지정할 수 있습니다.
# # SQL 내부에서 파라미터로 변경할 부분(플레이스홀더)은 %s로 지정합니다.
# c.execute('INSERT INTO cities VALUES (%s, %s, %s)', (1, '상하이', 24150000))
#
# # 파라미터가 딕셔너리일 때는 플레이스홀더를 %(<이름>)s 형태로 지정합니다.
# c.execute('INSERT INTO cities VALUES (%(rank)s, %(city)s, %(population)s)',
#           {'rank': 2, 'city': '카라치', 'population': 23500000})
#
# # executemany() 메서드를 사용하면 여러 개의 파라미터를 리스트로 지정해서
# # 여러 개(현재 예제에서는 3개)의 SQL 구문을 실행할 수 있습니다.
# c.executemany('INSERT INTO cities VALUES (%(rank)s, %(city)s, %(population)s)', [
#     {'rank': 3, 'city': '베이징', 'population': 21516000},
#     {'rank': 4, 'city': '텐진', 'population': 14722100},
#     {'rank': 5, 'city': '이스탄불', 'population': 14160467},
# ])
#
# # 변경사항을 커밋(저장)합니다.
# conn.commit()
#     # 변경사항의 commit이 꼭 필요하다.
#
#
# # 저장한 데이터를 추출합니다.
# c.execute('SELECT * FROM cities')
# # 쿼리의 결과는 fetchall() 메서드로 추출할 수 있습니다.
# for row in c.fetchall():
#     # 추출한 데이터를 출력합니다.
#     print(row)
#
# # 연결을 닫습니다.
# conn.close()

# %% [markdown]
# ### MongoDB 개요
# > NoSQL 의 일종, 문서형 데이터베이스(NoSQL = Not only SQL)
#
# > - 오픈소스 소프트웨어로 공개
# - 유연한 데이터 구조, 높은 쓰기 성능, 사용하기 쉽다.
#
# > - MongoDB의 데이터 구조
# - \- 하나의 데이터베이스는 여러개의 콜렉션을 가지며,
# - \- 하나의 콜렉션은 여러 개의 문서를 갖는다.
# - \- 문서는 BSON 이라고 부르는 JSON의 바이너리 형식으로 다룬다.
# - \- 미리 데이터 구조를 정의할 필요없고, 문서마다 다른 데이터 구조를 가질 수 있다.

# %% [markdown]
# ### MongoDB 설치
# > MongoDB Install in Windows
#
# > - Manual : https://docs.mongodb.com/manual/tutorial/install-mongodb-on-windows/
# - Download : https://www.mongodb.com/download-center/community?jmp=homepage

# %% [markdown]
# ### MongoDB 실행
# > 설치 디렉토리 하단의 bin에서 mongod.exe, mongo.exe 실행(보통 bin폴더에 실행파일들 다 들어가 있다. 파이썬은 예외적으로  script 폴더)
#
# > - mongod.exe : MongoDB 서버 실행파일
# - mongo.exe   : MongoDB를 조작할수 있는 MongoDB Shell 프로그램
#
# > - \- 먼저 MongoDB Shell을 실행하기 전에 MongoDB 서버를 실행시켜야 한다.
# - \- 탐색기에서 실행파일 Shift+우클릭을 통해 메뉴창을 연다.
# - \- 여기에서 명령창 열기(W)를 눌러서 현재 폴더에서 윈도우 명령프롬프트(cmd)를 실행한다.

# %% [markdown]
# **c3-05_save_mongo**
# > MongoDB에 저장
#
# > - 파이썬 바인딩인 PyMongo 를 사용
# - 모듈설치 : pip install pymongo

# %%
# ! pip install pymongo

# %% [raw]
# import lxml.html
# from pymongo import MongoClient
#
# # HTML 파일을 읽어 들이고
# # getroot() 메서드를 사용해 HtmlElement 객체를 추출합니다.
# tree = lxml.html.parse('data/full_book_list.html')
# html = tree.getroot()
#
# client = MongoClient('localhost', 27017) (ip와 port를 정해준다. 27017이 port인 것.)
# db = client.scraping   # scraping 데이터베이스를 추출합니다.
# collection = db.links  # links 콜렉션을 추출합니다.
#
# # 스크립트를 여러 번 사용해도 같은 결과를 출력할 수 있게 콜렉션의 문서를 제거합니다.
# collection.delete_many({})
#
# # cssselect() 메서드로 a 요소의 목록을 추출합니다.(이것들이 BSON(JSON과 같다고 봐도 됨)으로 저장된다)
# for a in html.cssselect('a'):
#     # href 속성과 링크의 글자를 추출해서 저장합니다.
#     collection.insert_one({
#         'url': a.get('href'),
#         'title': a.text.strip(),
#     })
#
# # 콜렉션의 모든 문서를 _id 순서로 정렬해서 추출합니다.
# for link in collection.find().sort('_id'):
#     print(link['_id'], link['url'], link['title'])

# %% [markdown]
# > cf> Rdb는 만들 때 구조가 만들어져 있다. 들어갈 때 구조가 다 동일하다.
# 그러나 몽고db의 경우에는 구조가 다양하므로 구조 역시도 다양하게 만들 수 있다.

# %% [markdown]
# ## 파이썬 크롤러
# > - 목록 페이지에서 URL 목록 추출
# - 상세페이지 스크레이핑
# - 상세페이지 크롤링
# - 스크레이핑 데이터 저장
# - 최종 크롤러 생성

# %% [markdown]
# **c3-06_python_crawler_1**
# > 목록 페이지에서 URL 목록 추출(1)

# %%
import requests
import lxml.html

response = requests.get('http://www.hanbit.co.kr/store/books/new_book_list.html')
root = lxml.html.fromstring(response.content)
for a in root.cssselect('.view_box a'):
    url = a.get('href')
    print(url)
# Out:
# /store/books/look.php?p_code=B6994299591
# javascript:;
# /store/books/look.php?p_code=B6994299591
# /store/books/look.php?p_code=B8463831992
# javascript:;
# /store/books/look.php?p_code=B8463831992
# /store/books/look.php?p_code=B9515842027
# javascript:;
# /store/books/look.php?p_code=B9515842027
# /store/books/look.php?p_code=B3283906872
# javascript:;
# /store/books/look.php?p_code=B3283906872
# /store/books/look.php?p_code=B2486465157
# javascript:;
# /store/books/look.php?p_code=B2486465157
# /store/books/look.php?p_code=B4851649517
# javascript:;
# /store/books/look.php?p_code=B4851649517
# /store/books/look.php?p_code=B8608817158
# javascript:;
# /store/books/look.php?p_code=B8608817158
# /store/books/look.php?p_code=B1266184916
# javascript:;
# /store/books/look.php?p_code=B1266184916
# /store/books/look.php?p_code=B8718279503
# javascript:;
# /store/books/look.php?p_code=B8718279503
# /store/books/look.php?p_code=B3696148245
# javascript:;
# /store/books/look.php?p_code=B3696148245
# /store/books/look.php?p_code=B6727651495
# javascript:;
# /store/books/look.php?p_code=B6727651495
# /store/books/look.php?p_code=B5331040931
# javascript:;
# /store/books/look.php?p_code=B5331040931
# /store/books/look.php?p_code=B1401258166
# javascript:;
# /store/books/look.php?p_code=B1401258166
# /store/books/look.php?p_code=B9796997266
# javascript:;
# /store/books/look.php?p_code=B9796997266
# /store/books/look.php?p_code=B4559886540
# javascript:;
# /store/books/look.php?p_code=B4559886540
# /store/books/look.php?p_code=B7076585695
# javascript:;
# /store/books/look.php?p_code=B7076585695
# /store/books/look.php?p_code=B3202466252
# javascript:;
# /store/books/look.php?p_code=B3202466252
# /store/books/look.php?p_code=B1052483362
# javascript:;
# /store/books/look.php?p_code=B1052483362
# /store/books/look.php?p_code=B7473583156
# javascript:;
# /store/books/look.php?p_code=B7473583156
# /store/books/look.php?p_code=B7883656935
# javascript:;
# /store/books/look.php?p_code=B7883656935

# %% [markdown]
# **c3-07_python_crawler_2**
# > 목록 페이지에서 URL 목록 추출(2)

# %%
import requests
import lxml.html

response = requests.get('http://www.hanbit.co.kr/store/books/new_book_list.html')
root = lxml.html.fromstring(response.content)

# 모든 링크를 절대 URL로 변환합니다.
root.make_links_absolute(response.url)

# 선택자를 추가해서 명확한 선택을 할 수 있게 합니다.
for a in root.cssselect('.view_box .book_tit a'):
    url = a.get('href')
    print(url)
# Out:
# http://www.hanbit.co.kr/store/books/look.php?p_code=B7198274060
# http://www.hanbit.co.kr/store/books/look.php?p_code=B6994299591
# http://www.hanbit.co.kr/store/books/look.php?p_code=B6734602013
# http://www.hanbit.co.kr/store/books/look.php?p_code=B8463831992
# http://www.hanbit.co.kr/store/books/look.php?p_code=B9515842027
# http://www.hanbit.co.kr/store/books/look.php?p_code=B3283906872
# http://www.hanbit.co.kr/store/books/look.php?p_code=B2486465157
# http://www.hanbit.co.kr/store/books/look.php?p_code=B4851649517
# http://www.hanbit.co.kr/store/books/look.php?p_code=B8608817158
# http://www.hanbit.co.kr/store/books/look.php?p_code=B1266184916
# http://www.hanbit.co.kr/store/books/look.php?p_code=B8718279503
# http://www.hanbit.co.kr/store/books/look.php?p_code=B3696148245
# http://www.hanbit.co.kr/store/books/look.php?p_code=B6727651495
# http://www.hanbit.co.kr/store/books/look.php?p_code=B5331040931
# http://www.hanbit.co.kr/store/books/look.php?p_code=B1401258166
# http://www.hanbit.co.kr/store/books/look.php?p_code=B9796997266
# http://www.hanbit.co.kr/store/books/look.php?p_code=B4559886540
# http://www.hanbit.co.kr/store/books/look.php?p_code=B7076585695
# http://www.hanbit.co.kr/store/books/look.php?p_code=B3202466252
# http://www.hanbit.co.kr/store/books/look.php?p_code=B1052483362

# %% [markdown]
# **c3-08_python_crawler_3 **
# > 목록 페이지에서 URL 목록 추출(3)

# %%
import requests
import lxml.html

def main():
    """
    크롤러의 메인 처리
    """
    # 여러 페이지에서 크롤링할 것이므로 Session을 사용합니다.
    session = requests.Session()  
    
    # scrape_list_page() 함수를 호출해서 제너레이터를 추출합니다.
    response = session.get('http://www.hanbit.co.kr/store/books/new_book_list.html')
    urls = scrape_list_page(response)
    # 제너레이터는 list처럼 사용할 수 있습니다.
    for url in urls:
        print(url)

def scrape_list_page(response):
    root = lxml.html.fromstring(response.content)
    root.make_links_absolute(response.url)
    for a in root.cssselect('.view_box .book_tit a'):
        url = a.get('href')
        # yield 구문으로 제너레이터의 요소 반환
        yield url

if __name__ == '__main__':
    main()
# Out:
# http://www.hanbit.co.kr/store/books/look.php?p_code=B7198274060
# http://www.hanbit.co.kr/store/books/look.php?p_code=B6994299591
# http://www.hanbit.co.kr/store/books/look.php?p_code=B6734602013
# http://www.hanbit.co.kr/store/books/look.php?p_code=B8463831992
# http://www.hanbit.co.kr/store/books/look.php?p_code=B9515842027
# http://www.hanbit.co.kr/store/books/look.php?p_code=B3283906872
# http://www.hanbit.co.kr/store/books/look.php?p_code=B2486465157
# http://www.hanbit.co.kr/store/books/look.php?p_code=B4851649517
# http://www.hanbit.co.kr/store/books/look.php?p_code=B8608817158
# http://www.hanbit.co.kr/store/books/look.php?p_code=B1266184916
# http://www.hanbit.co.kr/store/books/look.php?p_code=B8718279503
# http://www.hanbit.co.kr/store/books/look.php?p_code=B3696148245
# http://www.hanbit.co.kr/store/books/look.php?p_code=B6727651495
# http://www.hanbit.co.kr/store/books/look.php?p_code=B5331040931
# http://www.hanbit.co.kr/store/books/look.php?p_code=B1401258166
# http://www.hanbit.co.kr/store/books/look.php?p_code=B9796997266
# http://www.hanbit.co.kr/store/books/look.php?p_code=B4559886540
# http://www.hanbit.co.kr/store/books/look.php?p_code=B7076585695
# http://www.hanbit.co.kr/store/books/look.php?p_code=B3202466252
# http://www.hanbit.co.kr/store/books/look.php?p_code=B1052483362

# %% [markdown]
# **c3-09_python_crawler_4 **
# > 상세페이지 스크레이핑(1)

# %%
import requests
import lxml.html

def main():
    # 여러 페이지에서 크롤링할 것이므로 Session을 사용합니다.
    session = requests.Session()  
    response = session.get('http://www.hanbit.co.kr/store/books/new_book_list.html')
    urls = scrape_list_page(response)

    for url in urls:
        response = session.get(url)  # Session을 사용해 상세 페이지를 추출합니다.
        ebook = scrape_detail_page(response)  # 상세 페이지에서 상세 정보를 추출합니다.
        print(ebook)  # 책 관련 정보를 출력합니다.
        break  # 책 한 권이 제대로 되는지 확인하고 종료합니다.

def scrape_list_page(response):
    root = lxml.html.fromstring(response.content)
    root.make_links_absolute(response.url)
    for a in root.cssselect('.view_box .book_tit a'):
        url = a.get('href')
        yield url

def scrape_detail_page(response):
    """
    상세 페이지의 Response에서 책 정보를 dict로 추출합니다.
    """
    root = lxml.html.fromstring(response.content)
    ebook = {
        'url': response.url,
        'title': root.cssselect('.store_product_info_box h3')[0].text_content(),
        'price': root.cssselect('.pbr strong')[0].text_content(),
        'content': [p.text_content()\
            for p in root.cssselect('#tabs_3 .hanbit_edit_view p')]
    }
    return ebook

if __name__ == '__main__':
    main()
# Out:
# {'url': 'http://www.hanbit.co.kr/store/books/look.php?p_code=B7198274060', 'title': '재미있고 빠른 한글 1권 : 기본 모음과 자음', 'price': '6,300', 'content': ['', '\r\n\t\t\t\t\t\t1권. 기본 모음과 자음\r\n', '01 모음 ㅇ (이아야어여)', '02 자음 ㄱ (기가갸거겨)', '03 자음 ㅋ (키카캬커켜)', '04 자음 ㄴ (니나냐너녀)', '05 자음 ㄷ (디다댜더뎌)', '06 자음 ㅌ (티타탸터텨)', '07 자음 ㄹ (리라랴러려)', '08 자음 ㅁ (미마먀머며)', '09 자음 ㅂ (비바뱌버벼)', '10 자음 ㅍ (피파퍄퍼펴)', '\xa0', '\r\n\t\t\t\t\t\t2권. 기본 자음과 쌍자음\r\n', '01 자음 ㅅ (시사샤서셔)', '02 자음 ㅈ (지자쟈저져)', '03 자음 ㅊ (치차챠처쳐)', '04 자음 ㅎ (히하햐허혀)', '05 쌍자음 ㄲ (끼까꺄꺼껴)', '06 쌍자음 ㄸ (띠따땨떠뗘)', '07 쌍자음 ㅃ (삐빠뺘뻐뼈)', '08 쌍자음 ㅆ (씨싸쌰써쎠)', '09 쌍자음 ㅉ (찌짜쨔쩌쪄)', '10 1~2권 확인학습 1~2', '\xa0', '\r\n\t\t\t\t\t\t3권. 받침\r\n', '01 받침 ㅇ', '02 받침 ㄱ ㅋ\xa0', '03 받침 ㄴ', '04 받침 ㄹ', '05 받침 ㅁ', '06 받침 ㅂ ㅍ', '07 받침 ㅅ', '08 받침 ㄷ ㅌ ㅈ ㅊ ㅎ', '09 확인학습 1~4 / 신나는 한글 놀이 1~3', '\xa0', '\r\n\t\t\t\t\t\t4권. 복잡한 모음\r\n', '01 복잡한 모음 애', '02 복잡한 모음 에', '03 복잡한 모음 외', '04 복잡한 모음 위', '05 복잡한 모음 얘 예', '06 복잡한 모음 와 의', '07 복잡한 모음 워', '08 복잡한 모음 왜 웨', '09 확인학습 1~4']}

# %% [markdown]
# **c3-10_python_crawler_5 **
# > 상세페이지 스크레이핑(2)

# %% [markdown]
# ### Regular Expression 관련 사이트
# - Text 정보를 re로 테스트
# - 작성된 re를 다이어그램으로 표현

# %%
import requests
import lxml.html
import re

def main():
    # 여러 페이지에서 크롤링할 것이므로 Session을 사용합니다.
    session = requests.Session()  
    response = session.get('http://www.hanbit.co.kr/store/books/new_book_list.html')
    urls = scrape_list_page(response)
    for url in urls:
        response = session.get(url)  # Session을 사용해 상세 페이지를 추출합니다.
        ebook = scrape_detail_page(response)  # 상세 페이지에서 상세 정보를 추출합니다.
        print(ebook)  # 책 관련 정보를 출력합니다.
        break  # 책 한 권이 제대로 되는지 확인하고 종료합니다.

def scrape_list_page(response):
    root = lxml.html.fromstring(response.content)
    root.make_links_absolute(response.url)
    for a in root.cssselect('.view_box .book_tit a'):
        url = a.get('href')
        yield url

def scrape_detail_page(response):
    """
    상세 페이지의 Response에서 책 정보를 dict로 추출합니다.
    """
    root = lxml.html.fromstring(response.content)
    ebook = {
        'url': response.url,
        'title': root.cssselect('.store_product_info_box h3')[0].text_content(),
        'price': root.cssselect('.pbr strong')[0].text_content(),
        'content': [normalize_spaces(p.text_content())
            for p in root.cssselect('#tabs_3 .hanbit_edit_view p')
            if normalize_spaces(p.text_content()) != '']
    }
    return ebook

def normalize_spaces(s):
    """
    연결돼 있는 공백을 하나의 공백으로 변경합니다.
    """
    return re.sub(r'\s+', ' ', s).strip()

if __name__ == '__main__':
    main()
# Out:
# {'url': 'http://www.hanbit.co.kr/store/books/look.php?p_code=B7198274060', 'title': '재미있고 빠른 한글 1권 : 기본 모음과 자음', 'price': '6,300', 'content': ['1권. 기본 모음과 자음', '01 모음 ㅇ (이아야어여)', '02 자음 ㄱ (기가갸거겨)', '03 자음 ㅋ (키카캬커켜)', '04 자음 ㄴ (니나냐너녀)', '05 자음 ㄷ (디다댜더뎌)', '06 자음 ㅌ (티타탸터텨)', '07 자음 ㄹ (리라랴러려)', '08 자음 ㅁ (미마먀머며)', '09 자음 ㅂ (비바뱌버벼)', '10 자음 ㅍ (피파퍄퍼펴)', '2권. 기본 자음과 쌍자음', '01 자음 ㅅ (시사샤서셔)', '02 자음 ㅈ (지자쟈저져)', '03 자음 ㅊ (치차챠처쳐)', '04 자음 ㅎ (히하햐허혀)', '05 쌍자음 ㄲ (끼까꺄꺼껴)', '06 쌍자음 ㄸ (띠따땨떠뗘)', '07 쌍자음 ㅃ (삐빠뺘뻐뼈)', '08 쌍자음 ㅆ (씨싸쌰써쎠)', '09 쌍자음 ㅉ (찌짜쨔쩌쪄)', '10 1~2권 확인학습 1~2', '3권. 받침', '01 받침 ㅇ', '02 받침 ㄱ ㅋ', '03 받침 ㄴ', '04 받침 ㄹ', '05 받침 ㅁ', '06 받침 ㅂ ㅍ', '07 받침 ㅅ', '08 받침 ㄷ ㅌ ㅈ ㅊ ㅎ', '09 확인학습 1~4 / 신나는 한글 놀이 1~3', '4권. 복잡한 모음', '01 복잡한 모음 애', '02 복잡한 모음 에', '03 복잡한 모음 외', '04 복잡한 모음 위', '05 복잡한 모음 얘 예', '06 복잡한 모음 와 의', '07 복잡한 모음 워', '08 복잡한 모음 왜 웨', '09 확인학습 1~4']}

# %% [markdown]
# **c3-11_python_crawler_6 **
# > 상세페이지 크롤링

# %%
import time # time 모듈을 임포트합니다.
import re 
import requests
import lxml.html

def main():
    session = requests.Session()
    response = session.get('http://www.hanbit.co.kr/store/books/new_book_list.html')
    urls = scrape_list_page(response)
    for url in urls:
        time.sleep(1) # 1초 동안 휴식합니다.
        response = session.get(url)
        ebook = scrape_detail_page(response)
        print(ebook)

def scrape_list_page(response):
    root = lxml.html.fromstring(response.content)
    root.make_links_absolute(response.url)
    for a in root.cssselect('.view_box .book_tit a'):
        url = a.get('href')
        yield url

def scrape_detail_page(response):
    """
    상세 페이지의 Response에서 책 정보를 dict로 추출합니다.
    """
    root = lxml.html.fromstring(response.content)
    ebook = {
        'url': response.url,
        'title': root.cssselect('.store_product_info_box h3')[0].text_content(),
        'price': root.cssselect('.pbr strong')[0].text_content(),
        'content': [normalize_spaces(p.text_content())
            for p in root.cssselect('#tabs_3 .hanbit_edit_view p')
            if normalize_spaces(p.text_content()) != '']
    }
    return ebook

def normalize_spaces(s):
    """
    연결돼 있는 공백을 하나의 공백으로 변경합니다.
    """
    return re.sub(r'\s+', ' ', s).strip()

if __name__ == '__main__':
    main()
# Out:
# {'url': 'http://www.hanbit.co.kr/store/books/look.php?p_code=B7198274060', 'title': '재미있고 빠른 한글 1권 : 기본 모음과 자음', 'price': '6,300', 'content': ['1권. 기본 모음과 자음', '01 모음 ㅇ (이아야어여)', '02 자음 ㄱ (기가갸거겨)', '03 자음 ㅋ (키카캬커켜)', '04 자음 ㄴ (니나냐너녀)', '05 자음 ㄷ (디다댜더뎌)', '06 자음 ㅌ (티타탸터텨)', '07 자음 ㄹ (리라랴러려)', '08 자음 ㅁ (미마먀머며)', '09 자음 ㅂ (비바뱌버벼)', '10 자음 ㅍ (피파퍄퍼펴)', '2권. 기본 자음과 쌍자음', '01 자음 ㅅ (시사샤서셔)', '02 자음 ㅈ (지자쟈저져)', '03 자음 ㅊ (치차챠처쳐)', '04 자음 ㅎ (히하햐허혀)', '05 쌍자음 ㄲ (끼까꺄꺼껴)', '06 쌍자음 ㄸ (띠따땨떠뗘)', '07 쌍자음 ㅃ (삐빠뺘뻐뼈)', '08 쌍자음 ㅆ (씨싸쌰써쎠)', '09 쌍자음 ㅉ (찌짜쨔쩌쪄)', '10 1~2권 확인학습 1~2', '3권. 받침', '01 받침 ㅇ', '02 받침 ㄱ ㅋ', '03 받침 ㄴ', '04 받침 ㄹ', '05 받침 ㅁ', '06 받침 ㅂ ㅍ', '07 받침 ㅅ', '08 받침 ㄷ ㅌ ㅈ ㅊ ㅎ', '09 확인학습 1~4 / 신나는 한글 놀이 1~3', '4권. 복잡한 모음', '01 복잡한 모음 애', '02 복잡한 모음 에', '03 복잡한 모음 외', '04 복잡한 모음 위', '05 복잡한 모음 얘 예', '06 복잡한 모음 와 의', '07 복잡한 모음 워', '08 복잡한 모음 왜 웨', '09 확인학습 1~4']}
# {'url': 'http://www.hanbit.co.kr/store/books/look.php?p_code=B6994299591', 'title': '재미있고 빠른 한글 2권 : 기본 자음과 쌍자음', 'price': '6,300', 'content': ['1권. 기본 모음과 자음', '01 모음 ㅇ (이아야어여)', '02 자음 ㄱ (기가갸거겨)', '03 자음 ㅋ (키카캬커켜)', '04 자음 ㄴ (니나냐너녀)', '05 자음 ㄷ (디다댜더뎌)', '06 자음 ㅌ (티타탸터텨)', '07 자음 ㄹ (리라랴러려)', '08 자음 ㅁ (미마먀머며)', '09 자음 ㅂ (비바뱌버벼)', '10 자음 ㅍ (피파퍄퍼펴)', '2권. 기본 자음과 쌍자음', '01 자음 ㅅ (시사샤서셔)', '02 자음 ㅈ (지자쟈저져)', '03 자음 ㅊ (치차챠처쳐)', '04 자음 ㅎ (히하햐허혀)', '05 쌍자음 ㄲ (끼까꺄꺼껴)', '06 쌍자음 ㄸ (띠따땨떠뗘)', '07 쌍자음 ㅃ (삐빠뺘뻐뼈)', '08 쌍자음 ㅆ (씨싸쌰써쎠)', '09 쌍자음 ㅉ (찌짜쨔쩌쪄)', '10 1~2권 확인학습 1~2', '3권. 받침', '01 받침 ㅇ', '02 받침 ㄱ ㅋ', '03 받침 ㄴ', '04 받침 ㄹ', '05 받침 ㅁ', '06 받침 ㅂ ㅍ', '07 받침 ㅅ', '08 받침 ㄷ ㅌ ㅈ ㅊ ㅎ', '09 확인학습 1~4 / 신나는 한글 놀이 1~3', '4권. 복잡한 모음', '01 복잡한 모음 애', '02 복잡한 모음 에', '03 복잡한 모음 외', '04 복잡한 모음 위', '05 복잡한 모음 얘 예', '06 복잡한 모음 와 의', '07 복잡한 모음 워', '08 복잡한 모음 왜 웨', '09 확인학습 1~4']}
# {'url': 'http://www.hanbit.co.kr/store/books/look.php?p_code=B6734602013', 'title': '재미있고 빠른 한글 3권 : 받침', 'price': '6,300', 'content': ['1권. 기본 모음과 자음', '01 모음 ㅇ (이아야어여)', '02 자음 ㄱ (기가갸거겨)', '03 자음 ㅋ (키카캬커켜)', '04 자음 ㄴ (니나냐너녀)', '05 자음 ㄷ (디다댜더뎌)', '06 자음 ㅌ (티타탸터텨)', '07 자음 ㄹ (리라랴러려)', '08 자음 ㅁ (미마먀머며)', '09 자음 ㅂ (비바뱌버벼)', '10 자음 ㅍ (피파퍄퍼펴)', '2권. 기본 자음과 쌍자음', '01 자음 ㅅ (시사샤서셔)', '02 자음 ㅈ (지자쟈저져)', '03 자음 ㅊ (치차챠처쳐)', '04 자음 ㅎ (히하햐허혀)', '05 쌍자음 ㄲ (끼까꺄꺼껴)', '06 쌍자음 ㄸ (띠따땨떠뗘)', '07 쌍자음 ㅃ (삐빠뺘뻐뼈)', '08 쌍자음 ㅆ (씨싸쌰써쎠)', '09 쌍자음 ㅉ (찌짜쨔쩌쪄)', '10 1~2권 확인학습 1~2', '3권. 받침', '01 받침 ㅇ', '02 받침 ㄱ ㅋ', '03 받침 ㄴ', '04 받침 ㄹ', '05 받침 ㅁ', '06 받침 ㅂ ㅍ', '07 받침 ㅅ', '08 받침 ㄷ ㅌ ㅈ ㅊ ㅎ', '09 확인학습 1~4 / 신나는 한글 놀이 1~3', '4권. 복잡한 모음', '01 복잡한 모음 애', '02 복잡한 모음 에', '03 복잡한 모음 외', '04 복잡한 모음 위', '05 복잡한 모음 얘 예', '06 복잡한 모음 와 의', '07 복잡한 모음 워', '08 복잡한 모음 왜 웨', '09 확인학습 1~4']}
# {'url': 'http://www.hanbit.co.kr/store/books/look.php?p_code=B8463831992', 'title': '재미있고 빠른 한글 4권 : 복잡한 모음', 'price': '6,300', 'content': ['1권. 기본 모음과 자음', '01 모음 ㅇ (이아야어여)', '02 자음 ㄱ (기가갸거겨)', '03 자음 ㅋ (키카캬커켜)', '04 자음 ㄴ (니나냐너녀)', '05 자음 ㄷ (디다댜더뎌)', '06 자음 ㅌ (티타탸터텨)', '07 자음 ㄹ (리라랴러려)', '08 자음 ㅁ (미마먀머며)', '09 자음 ㅂ (비바뱌버벼)', '10 자음 ㅍ (피파퍄퍼펴)', '2권. 기본 자음과 쌍자음', '01 자음 ㅅ (시사샤서셔)', '02 자음 ㅈ (지자쟈저져)', '03 자음 ㅊ (치차챠처쳐)', '04 자음 ㅎ (히하햐허혀)', '05 쌍자음 ㄲ (끼까꺄꺼껴)', '06 쌍자음 ㄸ (띠따땨떠뗘)', '07 쌍자음 ㅃ (삐빠뺘뻐뼈)', '08 쌍자음 ㅆ (씨싸쌰써쎠)', '09 쌍자음 ㅉ (찌짜쨔쩌쪄)', '10 1~2권 확인학습 1~2', '3권. 받침', '01 받침 ㅇ', '02 받침 ㄱ ㅋ', '03 받침 ㄴ', '04 받침 ㄹ', '05 받침 ㅁ', '06 받침 ㅂ ㅍ', '07 받침 ㅅ', '08 받침 ㄷ ㅌ ㅈ ㅊ ㅎ', '09 확인학습 1~4 / 신나는 한글 놀이 1~3', '4권. 복잡한 모음', '01 복잡한 모음 애', '02 복잡한 모음 에', '03 복잡한 모음 외', '04 복잡한 모음 위', '05 복잡한 모음 얘 예', '06 복잡한 모음 와 의', '07 복잡한 모음 워', '08 복잡한 모음 왜 웨', '09 확인학습 1~4']}
# {'url': 'http://www.hanbit.co.kr/store/books/look.php?p_code=B9515842027', 'title': '하루 3줄 영어 습관', 'price': '13,500', 'content': []}
# {'url': 'http://www.hanbit.co.kr/store/books/look.php?p_code=B3283906872', 'title': 'IT CookBook, 시스템 해킹과 보안(3판)', 'price': '27,000', 'content': ['Part 01 시스템 해킹 기초 지식', 'Chapter 01 운영체제 이해', '1.1 운영체제의 개념과 기능', '1.2 윈도우의 이해', '1.3 리눅스/유닉스의 이해', '요약', '연습문제', 'Chapter 02 80x86 시스템의 이해', '2.1 80x86 시스템 CPU 구조와 레지스터', '2.2 80x86 시스템 메모리의 구조와 동작', '2.3 어셈블리어 기본 문법과 명령', '2.4 스택을 이용한 명령 처리 과정', '요약', '연습문제', '현장의 목소리', 'Chapter 03 계정과 권한', '3.1 리눅스/유닉스의 계정과 권한 체계', '3.2 리눅스/유닉스의 권한 상승', '3.3 윈도우의 계정과 권한 체계', '3.4 윈도우의 권한 상승', '요약', '연습문제', 'Part 02 시스템 해킹', 'Chapter 04 패스워드 크래킹', '4.1 패스워드 크래킹의 이해', '4.2 윈도우 인증과 패스워드', '4.3 리눅스/유닉스 인증과 패스워드', '4.4 서비스 데몬 패스워드', '4.5 운영체제별 패스워드 복구', '요약', '연습문제', '현장의 목소리', 'Chapter 05 리버스 엔지니어링', '5.1 리버스 엔지니어링의 이해', '5.2 리버스 엔지니어링 툴', '5.3 리버스 엔지니어링 공격', '5.4 리버스 엔지니어링 대응책', '요약', '연습문제', 'Chapter 06 레이스 컨디션', '6.1 레이스 컨디션 공격의 이해', '6.2 레이스 컨디션 공격 대응책', '요약', '연습문제', '현장의 목소리', 'Chapter 07 버퍼 오버플로', '7.1 스택 버퍼 오버플로 공격', '7.2 힙 버퍼 오버플로 공격', '7.3 버퍼 오버플로 공격 대응책과 발전된 공격', '요약', '연습문제', 'Chapter 08 포맷 스트링', '8.1 포맷 스트링 공격', '8.2 포맷 스트링 공격 대응책', '요약', '연습문제', 'Chapter 09 백도어', '9.1 백도어의 이해', '9.2 윈도우 백도어', '9.3 리눅스 백도어', '9.4 백도어 탐지 순서와 대응책', '요약', '연습문제', '현장의 목소리', 'Part 03 운영체제 보안', 'Chapter 10 윈도우 시스템 보안 설정(윈도우 서버 2016)', '10.1 계정 정책', '10.2 로컬 정책', '10.3 데몬 관리', '10.4 접근 제어', '10.5 파일과 디렉터리 관리', '10.6 기타 보안 관리', '요약', '연습문제', 'Chapter 11 리눅스 시스템 보안 설정(솔라리스 11)', '11.1 계정 관리', '11.2 서비스 관리', '11.3 접근 제어', '11.4 파일과 디렉터리 관리', '11.5 업데이트', '요약', '연습문제', '현장의 목소리', 'Chapter 12 침해사고와 로그', '12.1 침해사고가 발생할 때 대응 절차', '12.2 로그 관련 기본 개념', '12.3 윈도우 시스템 로그 분석과 설정', '12.4 리눅스 로그 분석과 설정']}
# {'url': 'http://www.hanbit.co.kr/store/books/look.php?p_code=B2486465157', 'title': 'IT CookBook, 자바 프로그래밍 for Beginner', 'price': '26,000', 'content': ['Chapter 01 JAVA 들여다보기', 'SECTION 01 JAVA의 개요', 'SECTION 02 JAVA 개발 환경 구축', 'SECTION 03 JAVA 프로그램 맛보기', 'Chapter 02 JAVA 프로그래밍 시작하기', 'SECTION 01 실무에서 사용하는 JAVA 개발 환경', 'SECTION 02 JAVA 프로그램 작성', 'SECTION 03 계산기 프로그램', 'Chapter 03 변수와 데이터 형식', 'SECTION 01 System.out의 기본', 'SECTION 02 System.out.printf( ) 메소드의 서식 지정', 'SECTION 03 변수', 'SECTION 04 데이터 형식과 배열', 'Chapter 04 연산자', 'SECTION 01 산술 연산자', 'SECTION 02 관계 연산자', 'SECTION 03 논리 연산자', 'SECTION 04 비트 연산자', 'SECTION 05 연산자 우선순위', 'Chapter 05 조건문', 'SECTION 01 if 문', 'SECTION 02 중첩 if 문', 'SECTION 03 switch~case 문', 'Chapter 06 반복문의 기본, for 문', 'SECTION 01 단순 for 문', 'SECTION 02 중첩 for 문', 'SECTION 03 기타 for 문', 'Chapter 07 반복문의 심화, while 문', 'SECTION 01 while 문', 'SECTION 02 do~while 문', 'SECTION 03 기타 제어문', 'Chapter 08 배열', 'SECTION 01 배열의 이해', 'SECTION 02 2차원 배열', 'SECTION 03 배열의 활용 : 스택', 'Chapter 09 문자열과 메소드', 'SECTION 01 문자열', 'SECTION 02 메소드', 'SECTION 03 지역변수와 전역변수', 'SECTION 04 메소드의 반환 값과 매개변수', 'Chapter 10 예외 처리와 파일 입출력', 'SECTION 01 예외 처리', 'SECTION 02 표준 입출력', 'SECTION 03 파일 입출력', 'Chapter 11 객체지향 프로그래밍의 기초', 'SECTION 01 클래스', 'SECTION 02 생성자', 'SECTION 03 인스턴스 변수와 클래스 변수', 'Chapter 12 객체지향 프로그래밍의 응용', 'SECTION 01 클래스의 상속', 'SECTION 02 추상 클래스', 'SECTION 03 인터페이스', 'Chapter 13 GUI 프로그래밍', 'SECTION 01 GUI 화면 구성', 'SECTION 02 GUI 이벤트 처리', 'SECTION 03 GUI 메뉴와 툴바', 'Chapter 14 고급 프로그래머로 나아가기', 'SECTION 01 패키지', 'SECTION 02 JAVA 클래스 라이브러리', 'SECTION 03 스레드', 'Chapter 15 실전 프로젝트', 'SECTION 01 친구 연락처 관리 프로그램', 'SECTION 02 사진 처리 프로그램']}
# {'url': 'http://www.hanbit.co.kr/store/books/look.php?p_code=B4851649517', 'title': 'Accelerated C++', 'price': '27,000', 'content': ['CHAPTER 0 C++ 시작하기', '0.1 주석', '0.2 #include', '0.3 main 함수', '0.4 중괄호', '0.5 표준 라이브러리를 사용한 출력', '0.6 반환문', '0.7 더 깊이 살펴보기', '0.8 핵심 정리', '연습문제', 'CHAPTER 1 문자열 사용', '1.1 입력', '1.2 테두리', '1.3 핵심 정리', '연습문제', 'CHAPTER 2 반복문과 카운팅', '2.1 해결해야 하는 문제', '2.2 전체적인 구조', '2.3 주어진 개수만큼 행 출력하기', '2.4 행 출력하기', '2.5 프로그램 완성하기', '2.6 카운팅', '2.7 핵심 정리', '연습문제', 'CHAPTER 3 데이터 일괄 처리', '3.1 학생의 최종 점수 계산하기', '3.2 평균값 대신 중앙값 사용하기', '3.3 핵심 정리', '연습문제', 'CHAPTER 4 프로그램 및 데이터 구조화', '4.1 연산 구조화', '4.2 데이터 구조화', '4.3 프로그램 통합하기', '4.4 성적 산출 프로그램 분할하기', '4.5 수정된 성적 산출 프로그램', '4.6 핵심 정리', '연습문제', 'CHAPTER 5 순차 컨테이너와 문자열 분석', '5.1 학생 분류', '5.2 반복자', '5.3 인덱스 대신 반복자 사용하기', '5.4 더 나은 성능을 위한 데이터 구조', '5.5 리스트 타입', '5.6 문자열 분할', '5.7 split 함수 테스트', '5.8 문자열 결합', '5.9 핵심 정리', '연습문제', 'CHAPTER 6 라이브러리 알고리즘', '6.1 문자열 분석', '6.2 성적 산출 방식 비교', '6.3 학생 분류 다시 살펴보기', '6.4 알고리즘, 컨테이너, 반복자', '6.5 핵심 정리', '연습문제', 'CHAPTER 7 연관 컨테이너', '7.1 효율적인 탐색을 위한 컨테이너', '7.2 단어의 빈도', '7.3 상호 참조 테이블', '7.4 문장 만들기', '7.5 성능에 대한 참고 사항', '7.6 핵심 정리', '연습문제', 'CHAPTER 8 제네릭 함수', '8.1 제네릭 함수', '8.2 데이터 구조 독립성', '8.3 입력 및 출력 반복자', '8.4 융통성을 위한 반복자 사용', '8.5 핵심 정리', '연습문제', 'CHAPTER 9 새로운 타입 정의', '9.1 Student_info 다시 살펴보기', '9.2 클래스 타입', '9.3 보호 레이블', '9.4 Student_info 클래스', '9.5 생성자', '9.6 Student_info 클래스 사용하기', '9.7 핵심 정리', '연습문제', 'CHAPTER 10 메모리 관리 및 저수준 데이터 구조', '10.1 포인터와 배열', '10.2 문자열 리터럴 다시 살펴보기', '10.3 문자 포인터 배열의 초기화', '10.4 main 함수의 인수', '10.5 파일 읽기 및 쓰기', '10.6 메모리 관리', '10.7 핵심 정리', '연습문제', 'CHAPTER 11 추상 데이터 타입', '11.1 Vec 클래스', '11.2 Vec 클래스 구현하기', '11.3 복사 제어', '11.4 동적인 Vec', '11.5 유연한 메모리 관리', '11.6 핵심 정리', '연습문제', 'CHAPTER 12 값처럼 동작하는 클래스 객체', '12.1 간단한 문자열 클래스', '12.2 자동 변환', '12.3 Str 연산', '12.4 주의해야 할 변환', '12.5 변환 연산자', '12.6 변환 및 메모리 관리', '12.7 핵심 정리', '연습문제', 'CHAPTER 13 상속과 동적 바인딩', '13.1 상속', '13.2 다형성과 가상 함수', '13.3 상속을 사용하여 문제 해결하기', '13.4 핸들 클래스', '13.5 핸들 클래스 사용하기', '13.6 미묘한 사항들', '13.7 핵심 정리', '연습문제', 'CHAPTER 14 메모리 관리 자동화', '14.1 핸들 클래스', '14.2 참조 카운트', '14.3 데이터 공유를 결정할 수 있는 핸들 클래스', '14.4 Ptr 핸들 클래스 개선하기', '14.5 핵심 정리', '연습문제', 'CHAPTER 15 문자 그림 다시 살펴보기', '15.1 설계', '15.2 구현', '15.3 핵심 정리', '연습문제', 'CHAPTER 16 앞으로 나아갈 방향', '16.1 추상화 사용하기', '16.2 다음 학습 단계', '연습문제', 'APPENDIX A C++ 세부 사항', 'A.1 선언문', 'A.2 타입', 'A.3 표현식', 'A.4 실행문', 'APPENDIX B 라이브러리 요약', 'B.1 입출력', 'B.2 컨테이너와 반복자', 'B.3 알고리즘']}
# {'url': 'http://www.hanbit.co.kr/store/books/look.php?p_code=B8608817158', 'title': 'IT 트렌드 스페셜 리포트 2019', 'price': '16,020', 'content': ['프롤로그', '1장. 인공지능 : 비즈니스의 경쟁력을 만들어내는 기반 기술', '01. 비즈니스에 미치는 영향', '02. 유용한 활용처', '03. 주목해야 하는 회사', '04. 실패 사례로 보는 한계점', '05. 전망', '06. 핵심 키워드 요약', '[테크 리포트] 솔리드웨어 : 세계가 인정하는 머신러닝 자동화 솔루션', '2장. 5G : 무지연 비즈니스 플랫폼의 탄생', '01. 4G가 만드는 비즈니스 변화', '02. 5G 탄생', '03. 5G를 활용한 모바일 서비스 변화', '04. 모바일 서비스 시나리오', '05. 국내 주요 사업자 동향', '06. 해외 동향', '07. 제약 사항', '08. 전망', '09. 핵심 키워드 요약', '[테크 리포트] SK텔레콤 : 5G 시대 선도 전략', '3장. 로봇 : 산업 현장을 넘어 일상으로', '01. 비즈니스 가치와 원인', '02. 활용 사례', '03. 주목해야 하는 회사', '04. 국가별 현황', '05. 주요 쟁점', '06. 전망', '07. 핵심 키워드 요약', '[테크 리포트] 뉴로메카 : RaaS로서의 협동로봇', '4장. 드론 : 지능형 드론 시대의 개막', '01. 비즈니스 가치와 원인', '02. 농업에서 우주 개발까지', '03. 주목할 만한 회사', '04. 유인 드론, 꿈이 현실로', '05. 인공지능, 드론을 진화시키다', '06. 전망', '07. 핵심 키워드 요약', '[테크 리포트] (주)엑스드론 : 다목적 임무용 무인기 상용화', '5장. 대화형 플랫폼 : 새로운 사용자 경험의 탄생', '01. 비즈니스 가치와 원인', '02. 대화형 플랫폼의 응용 사례', '03. 주목해야 하는 회사', '04. 한계점, 제약 사항', '05. 전망', '06. 핵심 키워드 요약', '[테크 리포트] 마인즈랩 : 고객접점 서비스의 미래, AI 컨택 센터', '6장. 실감형 미디어 : 포스트 중심기기로서 가능성', '01. 비즈니스 가치와 원인', '02. 활용 사례', '03. 주목해야 하는 회사', '04. 주요 쟁점 / 한계점과 제약 사항', '05. 전망', '06. 핵심 키워드 요약', '[테크 리포트] (주)살린 : VR 소셜 TV 플랫폼, 에픽라이브', '7장. 블록체인 : 생태 지도와 차세대 기술', '01. 실물 경제 시스템의 패러다임 변화', '02. 국내 블록체인 생태 지도', '03. 혁신 경제 시스템으로서의 쟁점', '04. 블록체인 채용 적합성 판단', '05. 블록체인 기술의 4가지 과제', '06. 합의 알고리즘 문제', '07. 오라클 문제', '08. 전망', '09. 핵심 키워드 요약', '[테크 리포트] ICON : 국내 최초의 본격적인 DApp 플랫폼']}
# {'url': 'http://www.hanbit.co.kr/store/books/look.php?p_code=B1266184916', 'title': '한 권으로 끝내는 딥러닝 텐서플로', 'price': '21,600', 'content': ['CHAPTER 1 딥러닝 소개', '1.1 머신러닝이 컴퓨터 과학을 집어삼키다', '1.2 딥러닝 기본 요소', '1.3 딥러닝 아키텍처', '1.4 딥러닝 프레임워크', '1.5 마치며', 'CHAPTER 2 텐서플로 기초 소개', '2.1 텐서 소개', '2.2 텐서플로 기초 계산', '2.3 명령형과 선언형 프로그래밍', '2.4 마치며', 'CHAPTER 3 텐서플로를 사용한 선형 및 로지스틱 회귀', '3.1 수학 복습', '3.2 텐서플로를 사용한 학습', '3.3 텐서플로에서 선형 모델 및 로지스틱 모델 학습하기', '3.4 마치며', 'CHAPTER 4 완전연결 딥 네트워크', '4.1 완전연결 딥 네트워크란?', '4.2 완전연결 네트워크에서의 ‘뉴런’', '4.3 완전연결 신경망 학습', '4.4 텐서플로 구현', '4.5 마치며', 'CHAPTER 5 하이퍼파라미터 최적화', '5.1 모델 평가 및 하이퍼파라미터 최적화', '5.2 지표, 지표, 지표', '5.3 하이퍼파라미터 최적화 알고리즘', '5.4 마치며', 'CHAPTER 6 합성곱 신경망', '6.1 합성곱 아키텍처 소개', '6.2 합성곱 네트워크 애플리케이션', '6.3 텐서플로 합성곱 네트워크 학습', '6.4 마치며', 'CHAPTER 7 순환 신경망', '7.1 순환 아키텍처 개요', '7.2 순환 셀', '7.3 순환 모델 애플리케이션', '7.4 신경 튜링머신', '7.5 순환 신경망을 사용하여 실제 작업하기', '7.6 펜 트리뱅크 말뭉치 처리하기', '7.7 마치며', 'CHAPTER 8 강화학습', '8.1 마르코프 결정 과정', '8.2 강화학습 알고리즘', '8.3 강화학습의 한계', '8.4 틱택토 게임', '8.5 A3C 알고리즘', '8.6 마치며', 'CHAPTER 9 대규모 딥 네트워크 학습', '9.1 딥 네트워크를 위한 커스텀 하드웨어', '9.2 CPU 학습', '9.3 분산 딥 네트워크 학습', '9.4 다중 GPU를 사용한 CIFAR-10 데이터 병렬 학습', '9.5 마치며', 'CHAPTER 10 딥러닝의 미래', '10.1 기술 산업 밖의 딥러닝', '10.2 윤리적인 딥러닝 사용', '10.3 인공일반지능이 곧 도래할까요?', '10.4 이제 무엇을 해야 할까요?']}
# {'url': 'http://www.hanbit.co.kr/store/books/look.php?p_code=B8718279503', 'title': '파이썬으로 배우는 머신러닝의 교과서', 'price': '26,100', 'content': ['CHAPTER 1 머신러닝의 준비', '1.1 머신러닝에 대해서', '1.2 파이썬 설치', '1.3 주피터 노트북', '1.4 케라스와 텐서플로 설치', 'CHAPTER 2 파이썬 기본', '2.1 사칙 연산', '2.2 변수', '2.3 자료형', '2.4 print 문', '2.5 list', '2.6 tuple', '2.7 if 문', '2.8 for 문', '2.9 벡터', '2.10 행렬', '2.11 행렬(ndarray)의 사칙 연산', '2.12 슬라이싱', '2.13 조건을 만족하는 데이터의 수정', '2.14 Help', '2.15 함수', '2.16 파일 저장', 'CHAPTER 3 그래프 그리기', '3.1 2차원 그래프 그리기', '3.2 3차원 그래프 그리기', 'CHAPTER 4 머신러닝에 필요한 수학의 기본', '4.1 벡터', '4.2 합의 기호', '4.3 곱의 기호', '4.4 미분', '4.5 편미분', '4.6 행렬', '4.7 지수 함수와 로그 함수', 'CHAPTER 5 지도 학습: 회귀', '5.1 1차원 입력 직선 모델', '5.2 2차원 입력면 모델', '5.3 D차원 선형 회귀 모델', '5.4 선형 기저 함수 모델', '5.5 오버피팅의 문제', '5.6 새로운 모델의 생성', '5.7 모델의 선택', '5.8 정리', 'CHAPTER 6 지도 학습: 분류', '6.1 1차원 입력 2클래스 분류', '6.2 2차원 입력 2클래스 분류', '6.3 2차원 입력 3클래스 분류', 'CHAPTER 7 신경망•딥러닝', '7.1 뉴런 모델', '7.2 신경망 모델', '7.3 케라스로 신경망 모델 구현', 'CHAPTER 8 신경망•딥러닝의 응용(필기체 숫자 인식)', '8.1 MNIST 데이터베이스', '8.2 2층 피드 포워드 네트워크 모델', '8.3 ReLU 활성화 함수', '8.4 공간 필터', '8.5 합성곱 신경망', '8.6 풀링', '8.7 드롭아웃', '8.8 MNIST 인식 네트워크 모델', 'CHAPTER 9 비지도 학습', '9.1 2차원 입력 데이터', '9.2 K-means 기법', '9.3 가우시안 혼합 모델', 'APPENDIX 머신러닝에 도움되는 파이썬 명령집']}
# {'url': 'http://www.hanbit.co.kr/store/books/look.php?p_code=B3696148245', 'title': '2019 전기기사 필기 7개년 기출문제', 'price': '19,800', 'content': ['이제는 합격이다', '- 동영상 강좌 안내', '- 시험 안내', '- 이 책의 학습 방법', '- 한눈에 보는 출제 분석표', '- 실력에 맞는 유형별 학습 로드맵', '- 회차별 학습 체크 리스트', '- 편저자의 말', '과년도 기출문제', '- 2018년 전기기사 1회', '- 2018년 전기기사 2회', '- 2018년 전기기사 3회', '- 2017년 전기기사 1회', '- 2017년 전기기사 2회', '- 2017년 전기기사 3회', '- 2016년 전기기사 1회', '- 2016년 전기기사 2회', '- 2016년 전기기사 3회', '- 2015년 전기기사 1회', '- 2015년 전기기사 2회', '- 2015년 전기기사 3회', '- 2014년 전기기사 1회', '- 2014년 전기기사 2회', '- 2014년 전기기사 3회', '- 2013년 전기기사 1회', '- 2013년 전기기사 2회', '- 2013년 전기기사 3회', '- 2012년 전기기사 1회', '- 2012년 전기기사 2회', '- 2012년 전기기사 3회']}
# {'url': 'http://www.hanbit.co.kr/store/books/look.php?p_code=B6727651495', 'title': '2019 전기산업기사 필기 7개년 기출문제', 'price': '19,800', 'content': ['이제는 합격이다', '- 동영상 강좌 안내', '- 시험 안내', '- 이 책의 학습 방법', '- 한눈에 보는 출제 분석표', '- 실력에 맞는 유형별 학습 로드맵', '- 회차별 학습 체크 리스트', '- 편저자의 말', '과년도 기출문제', '- 2018년 전기산업기사 1회', '- 2018년 전기산업기사 2회', '- 2018년 전기산업기사 3회', '- 2017년 전기산업기사 1회', '- 2017년 전기산업기사 2회', '- 2017년 전기산업기사 3회', '- 2016년 전기산업기사 1회', '- 2016년 전기산업기사 2회', '- 2016년 전기산업기사 3회', '- 2015년 전기산업기사 1회', '- 2015년 전기산업기사 2회', '- 2015년 전기산업기사 3회', '- 2014년 전기산업기사 1회', '- 2014년 전기산업기사 2회', '- 2014년 전기산업기사 3회', '- 2013년 전기산업기사 1회', '- 2013년 전기산업기사 2회', '- 2013년 전기산업기사 3회', '- 2012년 전기산업기사 1회', '- 2012년 전기산업기사 2회', '- 2012년 전기산업기사 3회']}
# {'url': 'http://www.hanbit.co.kr/store/books/look.php?p_code=B5331040931', 'title': '좋은 사진을 만드는 ZAKO의 여행 사진 잘 찍는 법', 'price': '19,800', 'content': ['PART 01 여행에서 배우는 사진 황금률 7', 'STUDY 01 미리 조사하고 계획하라', 'STUDY 02 변화무쌍한 빛의 힘을 읽어라', 'STUDY 03 좋은 사진은 좋은 장비가 아니라 좋은 시선에서 나온다', 'STUDY 04 찍고, 또 찍고, 계속 찍어라', 'STUDY 05 고르고 보정하는 것은 찍는 것만큼 중요하다', 'STUDY 06 사진을 객관적으로 평가하라', 'STUDY 07 안전하게 저장하고 공유하라', 'PART 02 여행에서 꼭 찍어야 할 사진 100', '[THEME] 01 거리', 'RECIPE 01 도시의 거리', 'RECIPE 02 골목 안 동네 책방', 'RECIPE 03 거리의 가판대', 'RECIPE 04 한적한 골목', '[SHOT & TIP] 프레임 디자인', '[THEME] 02 간판과 광고판', 'RECIPE 05 간판이 빽빽한 유흥가 골목', 'RECIPE 06 북적이는 다운타운', 'RECIPE 07 자연색이 묻어나는 사진', 'RECIPE 08 사람이 배경이 되는 광고판', '[SHOT & TIP] 빛에 대한 민감도를 나타내는 ISO(감도) 이해하기', '[THEME] 03 유리창', 'RECIPE 09 자동차 앞 유리창', 'RECIPE 10 관능적인 마네킹', 'RECIPE 11 스크린처럼 펼쳐진 전망대', 'RECIPE 12 비에 젖은 유리창', '[SHOT & TIP] 자유로운 후보정을 위한 RAW 파일 사용하기', '[THEME] 04 관광객', 'RECIPE 13 신나게 노는 아이들', 'RECIPE 14 다정한 친구', 'RECIPE 15 풍경과 어우러진 관광객', 'RECIPE 16 해변의 연인', '[SHOT & TIP] 셔터 속도로 움직임 표현하기', '[THEME] 05 계단', 'RECIPE 17 곡선을 찾아 나선 여행', 'RECIPE 18 하늘로 가는 계단', 'RECIPE 19 에스컬레이터9', '[THEME] 06 구름', 'RECIPE 20 도시를 덮은 하얀 솜사탕', 'RECIPE 21 천사의 날개', 'RECIPE 22 햇빛이 선사하는 마술, 빛 내림', '[THEME] 07 그림자', 'RECIPE 23 그림자 벽화', 'RECIPE 24 해변과 야자수 그늘', 'RECIPE 25 바닥에 그려진 그림자 무늬', '[SHOT & TIP] 피사체에 맞는 적절한 노출값 찾기', '[THEME] 08 기차와 역', 'RECIPE 26 인적 없는 간이역', 'RECIPE 27 움직이는 광고판', 'RECIPE 28 철로가 보이는 전철 기관실', '[SHOT & TIP] 시선을 유도하는 3가지 요소', '[THEME] 09 나무와 꽃', 'RECIPE 29 고고히 서 있는 고목', 'RECIPE 30 튤립과 연등', 'RECIPE 31 자작나무숲', 'RECIPE 32 야자수', '[THEME] 10 날씨', 'RECIPE 33 눈 내리는 거리', 'RECIPE 34 무지개', 'RECIPE 35 폭설 내린 도로', 'RECIPE 36 파란 하늘', '[SHOT & TIP] 나에게 맞는 노출 모드 찾기', '[THEME] 11 다리', 'RECIPE 37 다른 세상으로 통하는 문, 아치형 교각', 'RECIPE 38 웅장한 현수교의 야경', '[SHOT & TIP] 흔들림 없는 사진을 위한 릴리즈 활용하기', '[THEME] 12 동물', 'RECIPE 39 고양이', 'RECIPE 40 갈매기', 'RECIPE 41 조랑말', 'RECIPE 42 도마뱀', '[SHOT & TIP] 조리개 조절해 초점의 선명한 범위 결정하기', '[THEME] 13 랜드마크와 건축물', 'RECIPE 43 자유의 여신상', 'RECIPE 44 브루클린과 맨해튼 다리', 'RECIPE 45 웅장한 쇼핑몰', 'RECIPE 46 균형과 대칭', '[THEME] 14 레저 스포츠', 'RECIPE 47 서핑보드', 'RECIPE 48 점핑 락', 'RECIPE 49 기구', 'RECIPE 50 수영', '[SHOT & TIP] 연사 모드로 원하는 장면 포착하기', '[THEME] 15 물, 호수와 바다', 'RECIPE 51 우윳빛 호수', 'RECIPE 52 요트 선착장', 'RECIPE 53 물보라 치는 바닷가', '[SHOT & TIP] 사진을 돋보이게 하는 빛의 방향 읽기', '[THEME] 16 벽과 문', 'RECIPE 54 벽화 골목', 'RECIPE 55 낡은 신호등과 벽화', 'RECIPE 56 기념품 가게', 'RECIPE 57 벽에 기댄 마네킹', '[THEME] 17 광장', 'RECIPE 58 동상이 있는 풍경', 'RECIPE 59 관광객으로 가득한 광장', 'RECIPE 60 거리 공연', '[SHOT & TIP] 망원렌즈로 원근감 압축해서 찍기', '[THEME] 18 비행기와 공항', 'RECIPE 61 항공사 마크가 있는 꼬리 날개', 'RECIPE 62 다른 세상으로 향하는 날개', 'RECIPE 63 공항 대합실', '[THEME] 19 산과 들', 'RECIPE 64 황금빛 하늘과 초록 들판', 'RECIPE 65 정상으로 가는 길', 'RECIPE 66 등산객', '[SHOT & TIP] 깨끗하고 독특한 이미지를 위한 필터 선택하기', '[THEME] 20 스카이라인', 'RECIPE 67 역광을 머금은 거대 빌딩들', '[SHOT & TIP] 여행에서 스마트폰 카메라의 장점 6가지', '[THEME] 21 야간 불빛', 'RECIPE 68 은하수를 지키는 등대', 'RECIPE 69 조형물의 불빛', 'RECIPE 70 도시 야경', '[SHOT & TIP] 삼각대 효과적으로 활용하기', '[THEME] 22 음식의 연출', 'RECIPE 71 김이 모락모락 피어오르는 음식', 'RECIPE 72 뜨거운 주방', 'RECIPE 73 요리를 완성하는 토핑', 'RECIPE 74 윤기와 질감이 느껴지는 음식', '[SHOT & TIP] 화이트밸런스 맞춰 정확한 색 표현하기', '[THEME] 23 인테리어와 소품', 'RECIPE 75 고급스러운 쇼핑몰', 'RECIPE 76 아름다운 천장등', 'RECIPE 77 카페 분위기 살리는 꽃병', '[THEME] 24 자동차', 'RECIPE 78 이국적인 모양과 색상의 버스', 'RECIPE 79 도시의 아이콘, 택시', 'RECIPE 80 클래식 자동차', 'RECIPE 81 푸드 트럭', '[THEME] 25 종교 건축물', 'RECIPE 82 조용한 절집', 'RECIPE 83 벽돌로 지은 수도원', 'RECIPE 84 장엄한 성당 입구', '[SHOT & TIP] 광각렌즈로 가깝고 넓은 공간 한눈에 담기', '[THEME] 26 지붕', 'RECIPE 85 유럽 중세 마을', 'RECIPE 86 눈 쌓인 지붕', 'RECIPE 87 빨간 지붕과 파란 바다', 'RECIPE 88 3개의 눈을 가진 집', '[SHOT & TIP] 노출을 결정하는 또 다른 변수, 측광 방식 살펴보기', '[THEME] 27 지는 해', 'RECIPE 89 수평선에 걸린 태양', 'RECIPE 90 저녁 햇빛에 붉게 물든 구름', 'RECIPE 91 구름을 뚫고 퍼지는 햇살', '[SHOT & TIP] 환상의 색으로 물드는 매직아워 활용하기', '[THEME] 28 축제', 'RECIPE 92 함께 어우러지는 축제', 'RECIPE 93 불꽃놀이', '[THEME] 29 공원', 'RECIPE 94 공원에서의 낮잠', 'RECIPE 95 잠들지 않는 해변 공원', 'RECIPE 96 비보이의 열정', '[SHOT & TIP] 앵글에 따라 달라지는 사진의 느낌', '[THEME] 30 현지인의 일상', 'RECIPE 97 치성을 드리는 사람들', 'RECIPE 98 결혼식', 'RECIPE 99 춤추는 뉴요커', 'RECIPE 100 강아 ...
# {'url': 'http://www.hanbit.co.kr/store/books/look.php?p_code=B1401258166', 'title': '(무료동영상) 2019 전기기사 필기', 'price': '32,400', 'content': ['이제는 합격이다', '- 동영상 강좌 안내', '- 시험 안내', '- 이 책의 학습 방법', '- 한눈에 보는 출제 분석표', '- 실력에 맞는 유형별 학습 로드맵', '- 회차별 학습 체크 리스트', '- 편저자의 말', '과년도 기출문제 1권', '- 2018년 전기기사 1회', '- 2018년 전기기사 2회', '- 2018년 전기기사 3회', '- 2017년 전기기사 1회', '- 2017년 전기기사 2회', '- 2017년 전기기사 3회', '- 2016년 전기기사 1회', '- 2016년 전기기사 2회', '- 2016년 전기기사 3회', '- 2015년 전기기사 1회', '- 2015년 전기기사 2회', '- 2015년 전기기사 3회', '- 2014년 전기기사 1회', '- 2014년 전기기사 2회', '- 2014년 전기기사 3회', '- 2013년 전기기사 1회', '- 2013년 전기기사 2회', '- 2013년 전기기사 3회', '- 2012년 전기기사 1회', '- 2012년 전기기사 2회', '- 2012년 전기기사 3회', '과년도 기출문제 2권', '- 2011년 전기기사 1회', '- 2011년 전기기사 2회', '- 2011년 전기기사 3회', '- 2010년 전기기사 1회', '- 2010년 전기기사 2회', '- 2010년 전기기사 3회', '- 2009년 전기기사 1회', '- 2009년 전기기사 2회', '- 2009년 전기기사 3회', '- 2008년 전기기사 1회', '- 2008년 전기기사 2회', '- 2008년 전기기사 3회', '- 2007년 전기기사 1회', '- 2007년 전기기사 2회', '- 2007년 전기기사 3회', '- 2006년 전기기사 1회', '- 2006년 전기기사 2회', '- 2006년 전기기사 3회', '- 2005년 전기기사 1회', '- 2005년 전기기사 2회', '- 2005년 전기기사 3회', '- 2004년 전기기사 1회', '- 2004년 전기기사 2회', '- 2004년 전기기사 3회']}
# {'url': 'http://www.hanbit.co.kr/store/books/look.php?p_code=B9796997266', 'title': '(무료동영상) 2019 전기산업기사 필기', 'price': '32,400', 'content': ['이제는 합격이다', '- 동영상 강좌 안내', '- 시험 안내', '- 이 책의 학습 방법', '- 한눈에 보는 출제 분석표', '- 실력에 맞는 유형별 학습 로드맵', '- 회차별 학습 체크 리스트', '- 편저자의 말', '과년도 기출문제 1권', '- 2018년 전기산업기사 1회', '- 2018년 전기산업기사 2회', '- 2018년 전기산업기사 3회', '- 2017년 전기산업기사 1회', '- 2017년 전기산업기사 2회', '- 2017년 전기산업기사 3회', '- 2016년 전기산업기사 1회', '- 2016년 전기산업기사 2회', '- 2016년 전기산업기사 3회', '- 2015년 전기산업기사 1회', '- 2015년 전기산업기사 2회', '- 2015년 전기산업기사 3회', '- 2014년 전기산업기사 1회', '- 2014년 전기산업기사 2회', '- 2014년 전기산업기사 3회', '- 2013년 전기산업기사 1회', '- 2013년 전기산업기사 2회', '- 2013년 전기산업기사 3회', '- 2012년 전기산업기사 1회', '- 2012년 전기산업기사 2회', '- 2012년 전기산업기사 3회', '과년도 기출문제 2권', '- 2011년 전기산업기사 1회', '- 2011년 전기산업기사 2회', '- 2011년 전기산업기사 3회', '- 2010년 전기산업기사 1회', '- 2010년 전기산업기사 2회', '- 2010년 전기산업기사 3회', '- 2009년 전기산업기사 1회', '- 2009년 전기산업기사 2회', '- 2009년 전기산업기사 3회', '- 2008년 전기산업기사 1회', '- 2008년 전기산업기사 2회', '- 2008년 전기산업기사 3회', '- 2007년 전기산업기사 1회', '- 2007년 전기산업기사 2회', '- 2007년 전기산업기사 3회', '- 2006년 전기산업기사 1회', '- 2006년 전기산업기사 2회', '- 2006년 전기산업기사 3회', '- 2005년 전기산업기사 1회', '- 2005년 전기산업기사 2회', '- 2005년 전기산업기사 3회', '- 2004년 전기산업기사 1회', '- 2004년 전기산업기사 2회', '- 2004년 전기산업기사 3회']}
# {'url': 'http://www.hanbit.co.kr/store/books/look.php?p_code=B4559886540', 'title': '리얼 블라디보스톡  PLUS 우수리스크 [2019~2020년 최신판]', 'price': '12,150', 'content': ['작가의 말', '미리 보기', '여행 웹사이트 & 애플리케이션', 'PART 01 한눈에 보는 블라디보스톡', '숫자로 보는 블라디보스톡', '이토록 가까운 블라디보스톡', '블라디보스톡 한눈에 보기', '구역별로 만나는 블라디보스톡', '여행 키워드 5', '필수 여행지 7', '음식 베스트 5', '쇼핑 베스트 5', '역사 키워드 9', '블라디보스톡 여행 정보', '추천 여행 코스', '블라디보스톡 여행의 정석 베이직 코스| 가장 기본적이면서도 알찬 2박 3일, 3박 4일 일정', '맞춤옷을 입은 듯 딱! 테마 여행 코스 | 가족 여행 코스, 역사 탐방 코스, 시즌 투어(여름, 겨울)', '여행의 꿀팁을 다 모았다 리얼 가이드', '한눈에 보는 시베리아 횡단열차 │ 사계절 내내 화려한 블라디보스톡 축제 │ 여행의 피로를 풀어주는 러시아 보드카 베스트 5 │ 실전에서 바로 통하는 러시아 음식 용어 │ 여행 고수가 추천하는 추다데이 vs 이브로쉐 베스트 아이템 5 │ 저렴한 가격에 구매하는 약국 베스트 아이템 4 │ 알뜰살뜰 즐기는 쇼핑의 재미! 슈퍼마켓 쇼핑 아이템 베스트 7 │ 마린스키 극장 제대로 즐기기 │ 블라디보스톡에서 우수리스크 가는 방법 │ 근교도시 아르쫌의 숨겨진 스폿들', '여행에 깊이를 한층 더해주는 리얼 스토리', '여행 전 알아두면 좋을 러시아 문화 7 │ 블라디보스톡의 시즌별 오락거리 │ 알고 보면 더 재밌는 러시아 발레와 오페라 이야기 │ 처음 접해보는 특별함 유제품과 전통음료 │ 러시아인의 식후 음료 러시아의 홍차 문화 │ 블라디보스톡 대표 동상 12 │ 샤슬릭과 함께하면 더 좋은 맥주와 와인 이야기 │ 아는 만큼 보인다! 연해주 항일독립운동', 'PART 02 한 걸음 더, 테마로 즐기는 블라디보스톡', 'THEME 나만을 위한 맞춤 여행', '체험 여행 | 바다 유람선 투어부터 개썰매와 스파까지', '이색 여행 | 러시아 문화예술의 향연', '박물관과 미술관 | 극동시베리아의 역사와 예술을 보다', '골목과 도심공원 | 고풍스러운 유럽 건축 양식', '크래프트 맥주 투어 | 신나는 공연과 함께 즐기는', '현지 시장 | 시베리아의 진기한 식재료 탐방', '힐링 여행 | 자연을 그대로 담은 루스키 섬을 걷다', 'FOOD 입이 즐거운 블라디보스톡 요리', '샤슬릭 | 입맛대로 골라먹는 노릇노릇한 꼬치구이', '스테이크 | 고소한 육즙과 풍미가 살아 있는', '수제버거 | 푸짐한 재료와 부드러운 식감의 향연', '킹크랩과 곰새우 | 크기도 두 배, 쫄깃한 식감도 두 배', '생선요리 | 입안에서 살살 녹는 바다의 맛', '길거리 음식 | 저렴한 가격에 든든한 한 끼!', '러시아식 만두 | 굽고 찌고 튀기고! 만두의 다양한 매력', '디저트 카페 베스트 5 | 입이 행복해지는 달달함', '차와 커피 베스트 5 | 여행 중 즐기는 한잔의 휴식', 'SHOPPING 비행깃값 버는 블라디보스톡 쇼핑 완전 정복', '화장품 매장 베스트 5 | 싱그러운 유럽의 향기를 가득 담다', '약국 | 몸과 마음이 건강해지는', '기념품 전문점 베스트 4 | 블라디보스톡을 기념하는 모든 것', '복합 쇼핑몰 베스트 5 | 패션부터 라이프스타일까지!', '대형마트 베스트 5 | 쇼핑의 즐거움을 담다', 'PART 03 진짜 블라디보스톡을 만나는 시간', '블라디보스톡 대중교통', '블라디보스톡 여행의 시작, 블라디보스톡 기차역 & 아무르 만 해변', '추천 코스 & 상세 지도', 'SEE & EAT & SHOP | 추천 스폿', 'REAL SPOT | 토카렙스키 등대', '젊음의 열기가 샘솟는 도시의 심장, 블라디보스톡 중심부', '추천 코스', '섹션 A 혁명광장 & 아르바트 거리', '상세 지도', 'SEE & EAT & SHOP | 추천 스폿', '섹션 B 금각만 주변 & 독수리전망대', '상세 지도', 'SEE & EAT & SHOP | 추천 스폿', '현지의 역사와 문화를 엿보다, 빠끄롭스키 정교회 사원', '추천 코스 & 상세 지도', 'SEE & EAT & SHOP | 추천 스폿', 'PART 04 블라디보스톡 근교 여행', '01 자연이 깎아낸 바람의 섬, 루스키 섬', '추천 코스 & 상세 지도', 'SEE & EAT | 추천 스폿', '02 러시아에서 현지인처럼 주말 보내기, 마콥스키 대로 & 샤마라 해변', '추천 코스 & 상세 지도', 'SEE & EAT & SHOP | 추천 스폿', '03 이야기를 품은 고즈넉한 도시, 우수리스크', '추천 코스 & 상세 지도', 'SEE & EAT | 추천 스폿', 'PART 05 쉽고 즐거운 여행 준비하기', '01 여행이 쉬워지는 준비 편', '02 망설임 없이 따라하는 실전 편', '03 아는 만큼 편해지는 숙소 편', 'INDEX']}
# {'url': 'http://www.hanbit.co.kr/store/books/look.php?p_code=B7076585695', 'title': '만화로 배우는 곤충의 진화', 'price': '16,020', 'content': ['1화 고생대편', '2화 중생대편', '3화 대멸종과 신생대편', '4화 곤충이란 무엇인가', '5화 날개의 진화', '6화 날개와 환원 불가능한 복잡성', '7화 외골격의 장점', '8화 외골격의 단점', '9화 진화론에 관한 오해 1', '10화 진화론에 관한 오해 2', '11화 진화와 성(Sex)', '12화 초기 곤충의 성생활', '13화 원시 날개의 성생활', '14화 곤충의 프러포즈 선물', '15화 곤충의 이상한 성생활', '16화 획득된 행동 양식', '17화 바퀴벌레의 역사', '18화 바퀴벌레의 퇴치와 기원', '19화 모기', '20화 곤충과 식물의 공진화', '21화 꽃의 전략', '22화 개미', '23화 필연적인 사회성', '24화 곤충과 균', '25화 유전자 발현 조절과 후성유전', '26화 곤충의 행성', '맺음말', '참고문헌']}
# {'url': 'http://www.hanbit.co.kr/store/books/look.php?p_code=B3202466252', 'title': '퇴근길 인문학 수업 : 전진', 'price': '15,300', 'content': ['프롤로그│퇴근길 인문학 수업을 열며', 'PART1│문학과 문장', '제1강 문장의 재발견 │김나정', '월요일 벌레가 되고서야 벌레였음을 알다 _ 프란츠 카프카 《변신》', '화요일 마음도 해부가 되나요? _ 나쓰메 소세키 《마음》', '수요일 겨울 나무에서 봄 나무로 _ 박완서 《나목》', '목요일 사진사의 실수, 떠버리의 누설 _ 발자크 《고리오 영감》', '금요일 일생토록 사춘기 _ 헤르만 헤세 《데미안》', '제2강 괴물, 우리 안의 타자 혹은 이방인 │윤민정', '월요일 인간의 경계는 어디까지인가 _ 괴물의 탄생', '화요일 우리 안의 천사 혹은 괴물 _ 메리 셸리 《프랑켄슈타인》', '수요일 내 안의 친밀하고도 낯선 이방인 _ 로버트 L. 스티븐슨 《지킬 박사와 하이드 씨의 기이한 사례》', '목요일 공포와 매혹이 공존하는 잔혹동화 _ 브람 스토커 《드라큘라》', '금요일 괴물이 던져준 기묘한 미학적 체험', '제3강 나를 찾아가는 글쓰기 │최옥정', '월요일 말과 글이 삶을 바꾼다', '화요일 독서, 글쓰기에 연료를 공급하는 일', '수요일 소설가의 독서법', '목요일 어쨌든 문장이다', '금요일 마음을 다잡는 글쓰기의 기술', 'PART2│건축과 공간', '제4강 가로와 세로의 건축 │박선욱', '월요일 광장, 사람과 건축물이 평등한 가로의 공간', '화요일 철강과 유리, 세로의 건축을 실현하다', '수요일 근대 건축을 이끈 사람들', '목요일 해체주의와 자연 중심적 건축의 새로운 시도', '금요일 인간이 주인이 되는 미래의 건축', '제5강 시간과 공간으로 풀어낸 서울 건축문화사 │박희용', '월요일 태종과 박자청, 세계문화유산을 건축하다', '화요일 조선 궁궐의 정전과 당가', '수요일 대한제국과 정동, 그리고 하늘제사 건축', '목요일 대한제국과 메이지의 공간 충돌, 장충단과 박문사', '금요일 궁궐의 변화, 도시의 변화', '제6강 건축가의 시선 │정현정', '월요일 빛, 어둠에 맞서 공간을 만들다', '화요일 색, 볼륨과 생동감을 더하다', '수요일 선, 움직임과 방향을 제시하다', '목요일 틈과 여백, 공간에 사색을 허락하다', '금요일 파사드, 건물이 시작되다', 'PART3│클래식과 의식', '제7강 클래식, 문학을 만나다 │나성인', '월요일 작곡가의 상상 속에 녹아든 괴테의 문학 _ 〈파우스트〉', '화요일 셰익스피어의 언어, 음악이 되다 _ 〈한여름 밤의 꿈〉', '수요일 자유를 갈망하는 시대정신의 증언자, 빅토르 위고 _ 〈리골레토〉', '목요일 신화의 해석, 혁명의 서막 _ 오르페우스와 프로메테우스', '금요일 바이블 인 뮤직 _ 루터와 바흐의 수난곡', '제8강 오래된 것들의 지혜 │김최은영', '월요일 오래되어야 아름다운 것들 _ 노경老境', '화요일 겨울 산에 홀로 서다 _ 고봉孤峰', '수요일 굽은 길 위의 삶, 그 삶의 예술 _ 곡경曲境', '목요일 고요해야 얻어지는 _ 공허空虛', '금요일 소멸, 그 후 _ 박복剝復', '제9강 시간이 만든 완성품 │민혜련', '월요일 스토리텔링과 장인 정신으로 명품이 탄생하다', '화요일 그 남자가 누구인지 알고 싶다면 _ 말과 자동차', '수요일 패션, 여성을 완성하다 337', '목요일 시간과 자연이 빚은 최고의 액체 _ 와인', '금요일 인류를 살찌운 식문화의 꽃 _ 발효음식', 'PART4│융합과 이상', '제10강 조선의 과학과 정치 │안나미', '월요일 백성의 삶, 시간에 있다', '화요일 모두가 만족하는 답을 구하라 _ 수학', '수요일 억울한 죽음이 없어야 한다 _ 화학', '목요일 하늘의 운행을 알아내다 _ 천문학', '금요일 빙고氷庫로 백성의 고통까지 얼리다 _ 열역학', '제11강 ‘나’는 어디에 있는가 │장형진', '월요일 별에서 온 그대', '화요일 우주에서 나의 위치는?', '수요일 나는 어떻게 여기에 왔을까?', '목요일 나의 조상은 누구인가', '금요일 마음은 무엇일까?', '제12강 제4의 물결 │오준호', '월요일 평민이 왕의 목을 친 최초의 시민혁명 _ 영국혁명', '화요일 천 년 넘은 신분 제도를 끝장낸 대사건 _ 프랑스대혁명', '수요일 빵·토지·평화를 위한 노동자의 혁명 _ 러시아혁명', '목요일 나라의 주인이 누구인지 보여준 독립 혁명 _ 베트남혁명', '금요일 민주주의 역사를 다시 쓰다 _ 대한민국 촛불혁명', '참고문헌']}
# {'url': 'http://www.hanbit.co.kr/store/books/look.php?p_code=B1052483362', 'title': '프라이드', 'price': '15,300', 'content': ['프롤로그', '나의 조직 프라이드는 어느 정도일까?', '1장 조직 그리고 나', '1-1 폼생폼사의 원리', '1-2 서울대와 하버드대', '1-3 패배하지 않는 길', '1-4 이성적 인간, 감정적 인간', '1-5 프라이드란 무엇인가?', '1-6 조직과 나는 하나', '1-7 남들과 다르지 않다', '1-8 애착 그리고 프라이드', '2장 프라이드 : 조직의 원동력', '2-1 일을 잘하려면', '2-2 조직의 목표는 생존에 있다', '2-3 의도의 역설', '2-4 대기업과 스타트업', '2-5 조직을 평가하는 개인', '2-6 프라이드를 높여야 산다', '2-7 프라이드, 조직을 움직이는 힘', '3장 볼 수 없는 자산을 만든다 : 평판과 브랜드', '3-1 볼 수 없는 자산', '3-2 평판은 프라이드를 만든다', '3-3 현재, 미래 그리고 브랜드', '3-4 계속 그것을 소유하고 싶다', '3-5 어디서 무엇을 했는가', '3-6 현대카드 이야기', '4장 최고를 만들어낸다 : 상품과 서비스', '4-1 최고의 제품과 서비스', '4-2 대리만족과 이기적 편향', '4-3 최고라 불리고 싶다', '4-4 세계 일류기업에서 일하기', '4-5 최고를 만드는 방법', '5장 세상의 빛과 소금이 된다 : 사회적 공헌과 기업 투명성', '5-1 아름다운 기부', '5-2 이윤추구와 사회적 책임', '5-3 소셜벤처, 가치를 만들다', '5-4 기업윤리와 투명경영', '5-5 공정함이란 무엇인가?', '5-6 처음보다 끝이 중요하다', '6장 일을 잘하도록 만든다 : 성취감과 동료', '6-1 해병대 정신 효과', '6-2 목적에 따라 결과가 다르다', '6-3 뉴욕 양키스의 이름 없는 유니폼', '6-4 비즈니스 사관학교', '6-5 작은 성공과 큰 성공', '6-6 객관적 성취와 주관적 성취', '7장 존경을 만든다 : 리더와의 비전 공유', '7-1 일본 경영의 신', '7-2 리더들의 위기', '7-3 리더십은 항상 작동한다', '7-4 마크롱, 트럼프 그리고 문재인', '7-5 가치를 추구하라', '7-6 자신의 일에 최선을 다한다', '7-7 끊임없이 학습하는 리더', '8장 독특함을 제공한다 : 보상과 대우', '8-1 인정과 보상', '8-2 칼퇴근을 하고 싶다', '8-3 존중, 통제인가 자율인가?', '8-4 직원들은 알고 있다', '8-5 배려하는 회사', '9장 프라이드 높이기', '9-1 왜 프라이드를 말하지 않는가?', '9-2 프라이드를 인식하는 차이', '9-3 프라이드 강화 방법론', '9-4 프라이드 강화를 위한 7가지 팁', '9-5 함께해야 성장한다', '참고문헌']}

# %% [markdown]
# **c3-12_python_crawler_final **
# > MongoDB 저장기능 추가한 최종적인 크롤러

# %% [raw]
# %%writefile  ./modules/python_crawler_final.py
#
# import time
# import re
# import requests
# import lxml.html
# from pymongo import MongoClient
#
# def main():
#     """
#     크롤러의 메인 처리
#     """
#     # 크롤러 호스트의 MongoDB에 접속합니다.
#     client = MongoClient('localhost', 27017)
#
#     # scraping 데이터베이스의 ebooks 콜렉션
#     collection = client.scraping.ebooks
#
#     # 데이터를 식별할 수 있는 유일키를 저장할 key 필드에 인덱스를 생성합니다.
#     collection.create_index('key', unique=True)
#
#     # 목록 페이지를 추출합니다.
#     response = requests.get('http://www.hanbit.co.kr/store/books/new_book_list.html')
#
#     # 상세 페이지의 URL 목록을 추출합니다.
#     urls = scrape_list_page(response)
#     for url in urls:
#         # URL로 키를 추출합니다.
#         key = extract_key(url)
#
#         # MongoDB에서 key에 해당하는 데이터를 검색합니다.
#         ebook = collection.find_one({'key': key})
#
#         # MongoDB에 존재하지 않는 경우만 상세 페이지를 크롤링합니다.
#         if not ebook:
#             time.sleep(1)
#             response = requests.get(url)
#             ebook = scrape_detail_page(response)
#             # 책 정보를 MongoDB에 저장합니다.
#             collection.insert_one(ebook)
#
#         # 책 정보를 출력합니다.
#         print(ebook)
#
# def scrape_list_page(response):
#     """
#     목록 페이지의 Response에서 상세 페이지의 URL을 추출합니다.
#     """
#     root = lxml.html.fromstring(response.content)
#     root.make_links_absolute(response.url)
#     for a in root.cssselect('.view_box .book_tit a'):
#         url = a.get('href')
#         yield url
#
# def scrape_detail_page(response):
#     """
#     상세 페이지의 Response에서 책 정보를 dict로 추출합니다.
#     """
#     root = lxml.html.fromstring(response.content)
#     ebook = {
#         'url': response.url,
#         'key': extract_key(response.url),
#         'title': root.cssselect('.store_product_info_box h3')[0].text_content(),
#         'price': root.cssselect('.pbr strong')[0].text_content(),
#         'content': "생략"
#     }
#     return ebook
#
# def extract_key(url):
#     """
#     URL에서 키(URL 끝의 p_code)를 추출합니다.
#     """
#     m = re.search(r"p_code=(.+)", url)
#     return m.group(1)
#
# def normalize_spaces(s):
#     """
#     연결돼 있는 공백을 하나의 공백으로 변경합니다.
#     """
#     return re.sub(r'\s+', ' ', s).strip()
#
# if __name__ == '__main__':
#     main()

# %%
# 크롤러 실행
# % run modules/python_crawler_final.py
