# %%
import pandas as pd
import re

# %%
# 경제
tmp1 = pd.read_csv('./teample_1_result/segye_economy_commonword_(2018.01.01 - 2018.03.31).csv', sep=(','), encoding='utf-8')
tmp2 = pd.read_csv('./teample_1_result/segye_economy_commonword_(2018.04.01 - 2018.06.30).csv', sep=(','), encoding ='utf-8')
tmp3 = pd.read_csv('./teample_1_result/segye_economy_commonword_(2018.07.01 - 2018.09.30).csv', sep=(','), encoding='utf-8')
tmp4 = pd.read_csv('./teample_1_result/segye_economy_commonword_(2018.10.01 - 2018.11.15).csv', sep=(','), encoding='utf-8')


# # 사회
# tmp1 = pd.read_csv('./teample_1_result/segye_society_commonword_(2018.01.01 - 2018.03.31).csv', sep=(','), encoding='utf-8')
# tmp2 = pd.read_csv('./teample_1_result/segye_society_commonword_(2018.04.01 - 2018.06.30).csv', sep=(','), encoding ='utf-8')
# tmp3 = pd.read_csv('./teample_1_result/segye_society_commonword_(2018.07.01 - 2018.09.30).csv', sep=(','), encoding='utf-8')
# tmp4 = pd.read_csv('./teample_1_result/segye_society_commonword_(2018.10.01 - 2018.11.15).csv', sep=(','), encoding='utf-8')


# # 정치
# tmp1 = pd.read_csv('./teample_1_result/segye_politics_commonword_(2018.01.01 - 2018.03.31).csv', sep=(','), encoding='utf-8')
# tmp2 = pd.read_csv('./teample_1_result/segye_politics_commonword_(2018.04.01 - 2018.06.30).csv', sep=(','), encoding ='utf-8')
# tmp3 = pd.read_csv('./teample_1_result/segye_politics_commonword_(2018.07.01 - 2018.09.30).csv', sep=(','), encoding='utf-8')
# tmp4 = pd.read_csv('./teample_1_result/segye_politics_commonword_(2018.10.01 - 2018.11.15).csv', sep=(','), encoding='utf-8')

# %% [markdown]
# #### 데이터프레임화

# %%
tmp1_df = pd.DataFrame(tmp1)
tmp2_df = pd.DataFrame(tmp2)
tmp3_df = pd.DataFrame(tmp3)
tmp4_df = pd.DataFrame(tmp4)

# %% [markdown]
# #### 불필요한 열 제거

# %%
tmp1_df.drop('Unnamed: 0',axis=1, inplace=True)
tmp2_df.drop('Unnamed: 0',axis=1, inplace=True)
tmp3_df.drop('Unnamed: 0',axis=1, inplace=True)
tmp4_df.drop('Unnamed: 0',axis=1, inplace=True)

# %% [markdown]
# #### 컬럼 명 변경

# %%
# 경제
tmp1_df.rename(columns={'단어명':'단어명', '빈도수':'빈도수'}, inplace=True)
tmp2_df.rename(columns={'단어명':'단어명', '빈도수':'빈도수'}, inplace=True)
tmp3_df.rename(columns={'단어명':'단어명', '빈도수':'빈도수'}, inplace=True)
tmp4_df.rename(columns={'단어명':'단어명', '빈도수':'빈도수'}, inplace=True)

# # 사회
# tmp1_df.rename(columns={'단어명':'단어명', '빈도수':'사회1분기빈도수'}, inplace=True)
# tmp2_df.rename(columns={'단어명':'단어명', '빈도수':'사회2분기빈도수'}, inplace=True)
# tmp3_df.rename(columns={'단어명':'단어명', '빈도수':'사회3분기빈도수'}, inplace=True)
# tmp4_df.rename(columns={'단어명':'단어명', '빈도수':'사회4분기빈도수'}, inplace=True)

# # 정치
# tmp1_df.rename(columns={'단어명':'단어명', '빈도수':'정치1분기빈도수'}, inplace=True)
# tmp2_df.rename(columns={'단어명':'단어명', '빈도수':'정치2분기빈도수'}, inplace=True)
# tmp3_df.rename(columns={'단어명':'단어명', '빈도수':'정치3분기빈도수'}, inplace=True)
# tmp4_df.rename(columns={'단어명':'단어명', '빈도수':'정치4분기빈도수'}, inplace=True)

# %% [markdown]
# #### 통째로 세로합치기

# %%
tmp2_df.head()
len(tmp2_df)
# Out:
# 4638

# %%
df_append = tmp1_df.append(tmp2_df).append(tmp3_df).append(tmp4_df)
len(df_append)
# Out:
# 17053

# %%
df_append.sort_values('빈도수', ascending=False)
# Out:
#         단어명  빈도수
# 0        삼성  114
# 0        가상  113
# 1        화폐  110
# 0        삼성   86
# 1      최저임금   82
# 2        톡톡   81
# 3        일상   79
# 2        지원   78
# 4        삼성   72
# 3       브리핑   72
# 4        경제   70
# 1       브리핑   70
# 2        금융   70
# 4        톡톡   69
# 5        투자   69
# 3        코노   69
# 6        인상   69
# 5       타이어   69
# 7        코노   68
# 7        금융   68
# 5        일상   68
# 6        대출   68
# 8       브리핑   68
# 8        코노   67
# 9        고용   64
# 11     최저임금   64
# 10       투자   64
# 9        금호   64
# 13       지원   62
# 12      일자리   62
# ...     ...  ...
# 3269     향년    1
# 3270     큰손    1
# 3271   성공사례    1
# 3272   노동시장    1
# 3273    칼텍스    1
# 3274    조원태    1
# 3275     직함    1
# 3276     옵션    1
# 3277    소신발    1
# 3260    구인회    1
# 3259     지다    1
# 3258     조문    1
# 3248     존경    1
# 3241   글로비스    1
# 3242     전성    1
# 3243     음매    1
# 3244     포천    1
# 3245    기업가    1
# 3246     비보    1
# 3247     애통    1
# ...

# %%
df_merge.to_csv('./teample_1_result/word_freq_df.csv', sep=(','), encoding='utf-8')

# %% [markdown]
# #### 중복 데이터 합치면서 결합하기

# %%
pd.merge(tmp1_df, tmp2_df, how='inner', on='단어명')
# Out:
#          단어명  빈도수_x  빈도수_y
# 0         가상    113     15
# 1         화폐    110     17
# 2         톡톡     81     69
# 3         일상     79     68
# 4         삼성     72    114
# 5        타이어     69      9
# 6         인상     69     38
# 7         코노     68     69
# 8        브리핑     68     70
# 9         금호     64      7
# 10        투자     64     33
# 11      최저임금     64     26
# 12       일자리     62     41
# 13        지원     62     49
# 14       김동연     59     52
# 15        시장     58     37
# 16        금융     57     70
# 17        해외     54     27
# 18        경영     51     21
# 19        롯데     50     25
# 20        금리     49     30
# 21        수출     48     37
# 22        관세     48     22
# 23        사업     47     35
# 24        최고     45     30
# 25        사회     44     13
# 26       플러스     43     37
# 27        산업     42     31
# 28        은행     42     23
# 29        매각     41     11
# ...      ...    ...    ...
# 2417  인베스트먼트      1      1
# 2418      부합      1      1
# ...

# %%
? pd.merge

# %% [markdown]
# #### '단어명' 기준으로 병합

# %%
from functools import reduce
import pandas as pd
dfs = [tmp1_df, tmp2_df, tmp3_df, tmp4_df]
df_merge = reduce(lambda left, right: pd.merge(left, right, on='단어명'), dfs)

# %%
df_merge[:50]
# Out:
#        단어명  정치빈도수  경제빈도수  사회빈도수
# 0       남북    380     39     95
# 1       회담    278      6      6
# 2      김정은    263      1      8
# 3       평화    218      5    123
# 4       국회    209     23     44
# 5      민주당    209      5    117
# 6       평양    188     11     31
# 7       북한    181     26     61
# 8       선언    179      7     48
# 9       자유    167      5     64
# 10    정상회담    153      4     17
# 11      합의    130     24     52
# 12     위원장    128     27     54
# 13     비핵화    122      1      3
# 14      정상    110      5     18
# 15      국민    104     25     92
# 16     정의당     98      1     13
# 17      장관     94     36     48
# 18      선거     92      5    137
# 19     문재인     91     27     40
# 20     한반도     89      9     38
# 21      북미     89      6      5
# 22      대화     89     15     28
# 23      민주     85      3     80
# 24      고위     84      4     17
# 25     트럼프     84     32      2
# 26      여야     82      2     13
# 27      미국     81     79     35
# ...

# %%
df_merge.to_csv('./teample_1_result/word_freq_df.csv', sep=(','), encoding='utf-8')

# %%
word_freq = pd.read_csv('./teample_1_result/word_freq_df.csv', sep=(','), encoding='utf-8')

# %%
word_freq
# Out:
#       Unnamed: 0   단어명  정치빈도수  경제빈도수  사회빈도수
# 0              0    남북    380     39     95
# 1              1    회담    278      6      6
# 2              2   김정은    263      1      8
# 3              3    평화    218      5    123
# 4              4    국회    209     23     44
# 5              5   민주당    209      5    117
# 6              6    평양    188     11     31
# 7              7    북한    181     26     61
# 8              8    선언    179      7     48
# 9              9    자유    167      5     64
# 10            10  정상회담    153      4     17
# 11            11    합의    130     24     52
# 12            12   위원장    128     27     54
# 13            13   비핵화    122      1      3
# 14            14    정상    110      5     18
# 15            15    국민    104     25     92
# 16            16   정의당     98      1     13
# 17            17    장관     94     36     48
# 18            18    선거     92      5    137
# 19            19   문재인     91     27     40
# ...

# %%
word_freq.drop('Unnamed: 0', axis=1, inplace=True)

# %%
word_freq['총빈도수'] = word_freq['정치빈도수'] + word_freq['경제빈도수'] + word_freq['사회빈도수']

# %%
word_freq.sort_values('총빈도수', ascending=False)
# Out:
#        단어명  정치빈도수  경제빈도수  사회빈도수  총빈도수
# 124     검찰     33     22    485   540
# 152     삼성     29    335    166   530
# 0       남북    380     39     95   514
# 173     경찰     26      8    466   500
# 41      의혹     64     38    346   448
# 50      단독     54    126    257   437
# 39      수사     67     18    337   422
# 61      인사     49     18    344   411
# 70      조사     44     66    265   375
# 29      논란     77     86    186   349
# 3       평화    218      5    123   346
# 5      민주당    209      5    117   331
# 159     재판     28      7    257   292
# 1       회담    278      6      6   290
# 4       국회    209     23     44   276
# 2      김정은    263      1      8   272
# 77      여성     41     26    204   271
# 7       북한    181     26     61   268
# 453     혐의     13     24    229   266
# 60      지원     49    111    104   264
# 769     인천      8      9    241   258
# 350     노조     16     54    185   255
# 646     법원      9     12    233   254
# 56     박근혜     50      5    192   247
# ...
